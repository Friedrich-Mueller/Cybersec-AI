# %% [markdown]
# #### Imports

# %%
import os
import logging
from dotenv import find_dotenv, load_dotenv
import pandas as pd
from newspaper import Article

# %% [markdown]
# #### Scrape GermanFakeNC Titles and Bodies
# This uses the GermanFakeNC and crawls through its entries to receive title and body from each samples URL

# %%
# Functions
def extract_title(url):
    article = Article(url)
    try:
        article.download()
        logger.info('Article title downloaded from %s' % url)
        article.parse()
    except:
        article.title = 'No title'

    return article.title


def extract_text(url):
    article = Article(url)
    try:
        article.download()
        logger.info('Article text downloaded from %s' % url)
        article.parse()
    except:
        article.text = 'No text'

    return article.text


log_fmt = '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
logging.basicConfig(level=logging.INFO, format=log_fmt)
logger = logging.getLogger()

# Load .env file
load_dotenv(find_dotenv())

# INPUTFILE = os.path.join(os.getenv('PROJECT_DIR'),
#                          'data',
#                          'raw',
#                          'GermanFakeNC.json')

INTERIMFILE = os.path.join('GermanFakeNC_interim_titel_or_text_existing.csv')

df = pd.read_json("germanfakenc.json")
logger.info('Head of dataframe: \n%s' % df.head())

# %% We only take News with an overall rating of at least 0.5
#overall_rating_mask = df['Overall_Rating'] >= 0.5
##ratio_mask = df['Ratio_of_Fake_Statements'].isin([3, 4])
#df_fake = df[overall_rating_mask & ratio_mask].reset_index()

df['titel'] = df['URL'].apply(extract_title)
df['text'] = df['URL'].apply(extract_text)

logger.info('Head of dataframe after parsing: \n%s' % df.head())

# Create mask to filter rows with no information (titel or text)
no_info_mask = (df['titel'] != 'No title') & (df['text'] != 'No text')
df_final = df[no_info_mask]

logger.info('Shape of final dataframe: %s' % str(df_final.shape))
logger.info('dtypes: \n%s' % str(df_final.dtypes))
logger.info('Rows with null values: \n%s' % df_final.isnull().sum())

# Save as csv
try:
    df_final.to_csv(INTERIMFILE, index=False)
    logger.info("CSV was saved to disk")
except Exception:
    logger.exception("Couldn't save CSV to disc \n", exc_info=True)
# Out:
# 2021-12-07 08:24:36,220 - root - INFO - Head of dataframe:
#         Date                                                URL  \
# 0 2017-08-30  https://schluesselkindblog.com/2017/08/30/proz...
# 1 2017-12-18  http://blauerbote.com/2017/12/18/bild-journali...
# 2 2017-06-02  http://blauerbote.com/2017/06/02/angela-merkel...
# 3 2017-09-25  http://smopo.ch/deutschlands-neonazis-waehlen-...
# 4 2018-02-17  http://www.truth24.net/gruppenvergewaltigung-s...
#
#   False_Statement_1_Location False_Statement_1_Index  \
# 0                       Text                 213-237
# 1                       Text                   13-36
# 2                      Title                     1-7
# 3                      Title                     1-5
# 4                      Title                     1-1
#
#   False_Statement_2_Location False_Statement_2_Index  \
# 0
# 1                       Text                   52-81
# 2                       Text                   70-94
# 3                       Text                   28-53
# 4                      Title                     3-4
#
#   False_Statement_3_Location False_Statement_3_Index  \
# 0
# 1
# 2                       Text                 121-153
# 3                       Text                 127-141
# 4                      Title                     6-7
#
#    Ratio_of_Fake_Statements  Overall_Rating
# 0                         1             0.7
# 1                         3             0.8
# 2                         3             0.7
# 3                         3             0.8
# 4                         1             0.4
# 2021-12-07 08:24:36,256 - root - INFO - Article title downloaded from https://schluesselkindblog.com/2017/08/30/prozess-beginnt-mord-an-heidelberger-studentin/
# 2021-12-07 08:24:36,762 - root - INFO - Article title downloaded from http://blauerbote.com/2017/12/18/bild-journalist-julian-roepcke-und-seine-nazifreunde/
# 2021-12-07 08:24:37,424 - root - INFO - Article title downloaded from http://blauerbote.com/2017/06/02/angela-merkel-laesst-rock-am-ring-abbrechen/
# 2021-12-07 08:24:37,862 - root - INFO - Article title downloaded from http://smopo.ch/deutschlands-neonazis-waehlen-den-untergang/
# 2021-12-07 08:24:38,983 - root - INFO - Article title downloaded from http://www.truth24.net/gruppenvergewaltigung-sex-jihadisten-vergewaltigen-junge-deutsche-auf-heimweg/
# 2021-12-07 08:24:40,427 - root - INFO - Article title downloaded from http://www.rapefugees.net/ozapft-is-tuerke-versucht-koreanerin-auf-die-wiesn-zu-vergewaltigen-oktoberfest-startet-dreckig-muenchen/
# 2021-12-07 08:24:40,493 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/dresden-wieder-kind-durch-fluechtling-brutal-vergewaltigt-wie-lange-noch/
# 2021-12-07 08:24:41,180 - root - INFO - Article title downloaded from https://www.unzensuriert.at/content/0026189-Katalonien-100-Tage-Diktatur-des-spanischen-Zentralstaats
# 2021-12-07 08:24:42,598 - root - INFO - Article title downloaded from http://www.guidograndt.de/2018/01/22/kollegenbeitrag-waehler-verraeter-spd/
# 2021-12-07 08:24:42,852 - root - INFO - Article title downloaded from https://de.sott.net/article/31971-Umfrage-92-der-Ukrainer-wollen-russischen-Fuhrer-zuruck-Schnauze-voll-von-Poroschenko
# 2021-12-07 08:24:43,750 - root - INFO - Article title downloaded from http://info-direkt.eu/2018/02/17/staedte-voller-leerer-menschen/
# 2021-12-07 08:24:43,841 - root - INFO - Article title downloaded from http://smopo.ch/neues-referendum-ueber-die-abschaffung-der-schweiz/
# 2021-12-07 08:24:43,894 - root - INFO - Article title downloaded from http://smopo.ch/ungarische-stadt-zu-weiss-fuer-kulturhauptstadt-europas/
# 2021-12-07 08:24:43,910 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/allahu-helau-massive-sexuelle-uebergriffe-durch-fluechtlinge-zu-karnevalsbeginn-in-koeln/
# 2021-12-07 08:24:44,371 - root - INFO - Article title downloaded from https://opposition24.com/unfassbar-euro-sachschaden-asylbewerber/369326
# 2021-12-07 08:24:48,903 - root - INFO - Article title downloaded from http://www.pi-news.net/hamburg-pakistaner-schaechtet-zweijaehrige-tochter/
# 2021-12-07 08:24:50,046 - root - INFO - Article title downloaded from http://www.guidograndt.de/2018/01/30/verschwiegen-vom-mainstream-superman-putin-diese-unglaublichen-erfolge-hat-der-russische-praesident-vorzuweisen/
# 2021-12-07 08:24:50,267 - root - INFO - Article title downloaded from https://de.sott.net/article/32015-Die-meisten-Forschungsergebnisse-sind-falsch-Interessenskonflikte-in-wissenschaftlicher-Forschung
# 2021-12-07 08:24:51,377 - root - INFO - Article title downloaded from http://www.journalistenwatch.com/2017/12/14/mehrere-festnahmen-bei-islamisten-razzia-in-berlin/
# 2021-12-07 08:24:51,387 - root - INFO - Article title downloaded from https://schluesselkindblog.com/2018/02/21/gauland-zusammenarbeit-mit-pegida-ist-moeglich/
# 2021-12-07 08:24:51,644 - root - INFO - Article title downloaded from https://philosophia-perennis.com/2018/02/05/unter-wahrnehmungschwelle/
# 2021-12-07 08:24:51,945 - root - INFO - Article title downloaded from http://www.epochtimes.de/politik/deutschland/viersen-seniorin-65-beim-friedhof-vergewaltigt-polizei-verhaftet-mann-psychiater-haelt-taeter-fuer-unterentwickelt-a2349624.html
# 2021-12-07 08:24:52,645 - root - INFO - Article title downloaded from https://www.bayern-depesche.de/medien/zdf-heute-show-die-unertr%C3%A4gliche-hetze-des-oliver-welke.html
# 2021-12-07 08:24:53,659 - root - INFO - Article title downloaded from http://www.rapefugees.net/ekelhaft-schwarzafrikaner-vergewaltigt-frau-vor-den-augen-des-partners-auf-zeltplatz/
# 2021-12-07 08:25:00,717 - root - INFO - Article title downloaded from http://new.euro-med.dk/20180103-eu-luftbrucke-fur-tausende-von-niedrig-iq-muslimen-aus-nordafrika-nach-europa-skandinavische-iq-sinkt-nun-um-6-5-pro-generation.php
# 2021-12-07 08:25:01,245 - root - INFO - Article title downloaded from http://blauerbote.com/2017/04/02/pfefferspray-gegen-sitzblockade-polizeigewalt-in-thueringen/
# 2021-12-07 08:25:01,689 - root - INFO - Article title downloaded from http://www.allesroger.at/artikel/armut-in-oesterreich
# 2021-12-07 08:25:02,667 - root - INFO - Article title downloaded from http://www.journalistenwatch.com/2018/01/11/sondierungen-oder-des-kaisers-neue-kleider/
# 2021-12-07 08:25:03,714 - root - INFO - Article title downloaded from http://noch.info/2017/12/deutschland-und-europa-befinden-sich-im-von-merkelco-verursachten-krieg/
# 2021-12-07 08:25:05,534 - root - INFO - Article title downloaded from http://www.epochtimes.de/politik/deutschland/ex-ard-moderatorin-historischer-babyboom-durch-massenmigration-verursacht-a2166046.html
# 2021-12-07 08:25:07,205 - root - INFO - Article title downloaded from https://dieunbestechlichen.com/2017/12/zum-fest-der-liebe-eu-bonzen-fuellen-sich-die-taschen-rentner-betteln-an-den-tafeln/
# 2021-12-07 08:25:07,841 - root - INFO - Article title downloaded from http://www.guidograndt.de/2017/08/19/teenager-amok-einer-der-barcelona-terroristen-ist-ein-minderjaehriger-marokkaner-in-deutschland-zigtausende-auch-junge-fluechtlinge-unidentifiziert-oder-verschwunden/
# 2021-12-07 08:25:08,910 - root - INFO - Article title downloaded from http://www.journalistenwatch.com/2017/12/31/230-millionen-steuergelder-fuer-saubere-strassen-in-jordanien/
# 2021-12-07 08:25:09,446 - root - INFO - Article title downloaded from http://www.guidograndt.de/2018/02/06/kollegenbeitrag-verschworene-verschwoerung-man-will-ihnen-bestimmen-was-wahr-ist/
# 2021-12-07 08:25:10,071 - root - INFO - Article title downloaded from http://www.guidograndt.de/2018/02/26/kandel-afghanen-fluechtling-erstach-15-jaehrige-so-wurden-sie-von-den-gez-medien-fuer-dumm-verkauft/
# 2021-12-07 08:25:10,690 - root - INFO - Article title downloaded from http://www.guidograndt.de/2017/12/19/gender-wahn-ausser-kontrolle-gefaehrliche-pubertaetsblocker-fuer-jugendliche/
# 2021-12-07 08:25:10,762 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/fasching-in-deutschland-vergewaltigungsorgien-durch-fluechtlinge-im-akkord/
# 2021-12-07 08:25:11,218 - root - INFO - Article title downloaded from https://opposition24.com/schamlos-antidemokratisch-unionsfraktion-verteidigt-netzdg/392739
# 2021-12-07 08:25:11,449 - root - INFO - Article title downloaded from https://philosophia-perennis.com/2018/01/29/kandel-demo/
# 2021-12-07 08:25:11,745 - root - INFO - Article title downloaded from https://philosophia-perennis.com/2017/10/24/anti-afd-demo/
# 2021-12-07 08:25:12,671 - root - INFO - Article title downloaded from http://www.truth24.net/armutsmigrant-onaniert-vor-junger-frau-mitten-in-deren-wohnheim-essen/
# 2021-12-07 08:25:13,477 - root - INFO - Article title downloaded from http://noch.info/2017/11/merkel-co-versuchen-mit-allen-moeglichen-maassnahmen-an-der-macht-zu-bleiben/
# 2021-12-07 08:25:14,925 - root - INFO - Article title downloaded from http://www.noislam.de/bundesarbeitsagentur-faelscht-statistik-62-aller-hartz-iv-empfaenger-als-nicht-arbeitslos-ausgewiesen/
# 2021-12-07 08:25:15,399 - root - INFO - Article title downloaded from https://opposition24.com/schulz-ziel-gruenes-licht/397742
# 2021-12-07 08:25:16,469 - root - INFO - Article title downloaded from http://www.journalistenwatch.com/2017/11/30/glyphosat-deutsche-demokratische-bananenrepublik/
# 2021-12-07 08:25:16,967 - root - INFO - Article title downloaded from http://news-for-friends.de/polizeihund-beisst-vergewaltiger-fluechtling-in-eier-linke-erstatten-anzeige-gegen-polizei/
# 2021-12-07 08:25:19,109 - root - INFO - Article title downloaded from https://netzfrauen.org/2017/11/05/education/#more-53491
# 2021-12-07 08:25:19,427 - root - INFO - Article title downloaded from https://philosophia-perennis.com/2018/01/30/iris-masson-1/
# 2021-12-07 08:25:21,743 - root - INFO - Article title downloaded from https://www.berlinjournal.biz/arabische-grossfamilien-berlins-polizei/
# 2021-12-07 08:25:23,910 - root - INFO - Article title downloaded from https://dieunbestechlichen.com/2018/02/soros-warnt-vor-zusammenbruch-der-eu-und-schwaermt-von-der-nazi-herrschaft/
# 2021-12-07 08:25:25,385 - root - INFO - Article title downloaded from https://dieunbestechlichen.com/2017/12/berlin-72-jaehriger-im-u-bahnhof-krankenhausreif-getreten/
# 2021-12-07 08:25:26,065 - root - INFO - Article title downloaded from https://perspektive-online.net/2018/02/erneut-angriffe-auf-demonstrationen-in-solidaritaet-mit-kurden/
# 2021-12-07 08:25:26,253 - root - INFO - Article title downloaded from http://smopo.ch/oesterreich-skandal-praesident-poebelt-gegen-mehrheit-der-briten/
# 2021-12-07 08:25:33,270 - root - INFO - Article title downloaded from http://new.euro-med.dk/20180219-merkel-preist-italien-weil-es-immigranten-holt-wir-haben-enge-zusammenarbeit-merkel-fliegt-klammheimlich-die-migranten-aus-italien-nach-deutschland-cia-untertreibt-grob-deutsche-netto-einwanderu.php
# 2021-12-07 08:25:33,732 - root - INFO - Article title downloaded from https://opposition24.com/weihnachtsfeier-kopftuchmaedchen-netz-lueneburger/383663
# 2021-12-07 08:25:34,294 - root - INFO - Article title downloaded from http://blauerbote.com/2017/05/28/ard-sags-mir-ins-gesicht-gerne/
# 2021-12-07 08:25:34,442 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/reservate-schutzzonen-zum-vergewaltigungsschutz-vor-schutzsuchenden-fluechtlingen/
# 2021-12-07 08:25:35,261 - root - INFO - Article title downloaded from http://info-direkt.eu/2018/02/22/blamage-fuer-medien-gruenes-licht-fuer-kongress/
# 2021-12-07 08:25:35,312 - root - INFO - Article title downloaded from http://www.allesroger.at/artikel/rechtliche-loesungen-fuer-das-asylantenproblem
# 2021-12-07 08:25:35,322 - root - INFO - Article title downloaded from https://schluesselkindblog.com/2017/12/30/angst-vor-silvester-sicherheitszonen-fuer-frauen/
# 2021-12-07 08:25:35,722 - root - INFO - Article title downloaded from https://opposition24.com/merkelmussweg-antifa-droht-heute-knallts/407298
# 2021-12-07 08:25:35,727 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/fluechtling-klaut-in-s-bahn-schlafender-wiesn-kellnerin-6500-euro-tageseinahmen/
# 2021-12-07 08:25:35,940 - root - INFO - Article title downloaded from https://philosophia-perennis.com/2018/02/02/christenverfolgung-deutschland/
# 2021-12-07 08:25:36,161 - root - INFO - Article title downloaded from https://de.sott.net/article/23750-Das-amerikanische-Imperium-Deutscher-Abgasskandal-ist-eine-bockige-Aktion-von-Industriesabotage
# 2021-12-07 08:25:37,104 - root - INFO - Article title downloaded from http://www.truth24.net/ich-dich-toeten-araber-bedroht-zugbegleiterin-und-spuckt-ihr-ins-gesicht/
# 2021-12-07 08:25:37,599 - root - INFO - Article title downloaded from https://opposition24.com/stuttgart-frau-stadtbahn-nafri/388303
# 2021-12-07 08:25:44,769 - root - INFO - Article title downloaded from http://zuerst.de/2018/01/29/drittweltland-oder-industrienation-gruene-orstvorsteherin-sucht-nach-tieren-fuer-esel-taxi-als-ersatz-fuer-busverkehr/
# 2021-12-07 08:25:45,280 - root - INFO - Article title downloaded from http://blauerbote.com/2017/09/10/angela-merkel-und-die-christenmoerder/
# 2021-12-07 08:25:47,380 - root - INFO - Article title downloaded from http://zuerst.de/2017/11/03/walldorf-aggressiver-mob-wirft-molotowcocktails-auf-rathaus/
# 2021-12-07 08:25:47,408 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/gegen-die-langeweile-bundesregierung-will-jugendliche-terroristen-nach-deutschland-holen/
# 2021-12-07 08:25:47,977 - root - INFO - Article title downloaded from https://www.bayern-depesche.de/medien/bayerischer-rundfunk-geht-juristisch-gegen-dvd-zum-buch-der-„der-links-staat“-vor.html
# 2021-12-07 08:25:48,493 - root - INFO - Article title downloaded from https://www.unzensuriert.at/content/0025635-Fregatte-Mecklenburg-Vorpommern-kooperiert-mit-NGO-Schiffen-als-Migranten-Taxi
# 2021-12-07 08:25:49,453 - root - INFO - Article title downloaded from http://www.anonymousnews.ru/2017/10/13/gefaengnisse-abschaffen-gruene-wollen-90-prozent-der-haeftlinge-in-offenen-vollzug-entlassen/
# 2021-12-07 08:25:49,729 - root - INFO - Article title downloaded from http://www.epochtimes.de/politik/europa/polizeichef-von-schweden-warnt-die-regierung-hat-die-kontrolle-ueber-das-land-verloren-integration-gescheitert-a2156608.html
# 2021-12-07 08:25:49,788 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/bestialischer-ueberfall-fluechtling-enthauptet-oma-98-beim-klau-der-halskette-fast/
# 2021-12-07 08:25:49,790 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/rezession-beendet-keine-arbeitslosigkeit-mehr-betteln-ist-arbeit/
# 2021-12-07 08:25:50,359 - root - INFO - Article title downloaded from http://zuerst.de/2017/11/30/linksextremisten-drohen-afd-wir-werden-da-reingehen-und-den-parteitag-abbrechen/
# 2021-12-07 08:25:50,387 - root - INFO - Article title downloaded from https://schluesselkindblog.com/2017/12/01/keine-groko-gespraeche-wie-die-luegenpresse-das-wahlergebnis-manipuliert/
# 2021-12-07 08:25:57,397 - root - INFO - Article title downloaded from http://new.euro-med.dk/20180227-judischer-harvard-elitist-in-ard-erklart-uns-versuchskaninchen-der-illuminaten-freimaurer-wir-fuhren-ein-experiment-aus-wobei-wir-eine-monoethnische-demokratie-in-eine-multiethnische-umgestalten.php
# 2021-12-07 08:25:58,229 - root - INFO - Article title downloaded from http://www.truth24.net/tuerke-versucht-schuelerin-15-mitten-auf-der-strasse-zu-vergewaltigen-wetzlar/
# 2021-12-07 08:25:58,283 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/gruene-wollen-esel-taxis-in-deutschland-etablieren/
# 2021-12-07 08:25:59,280 - root - INFO - Article title downloaded from https://www.journalistenwatch.com/2017/09/22/bka-studie-fluechtlinge-begehen-628-000-straftaten/
# 2021-12-07 08:25:59,283 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/heidelberg-schwarzer-fluechtling-reibt-erigierten-penis-an-25jaehriger-und-raubt-sie-aus/
# 2021-12-07 08:25:59,285 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/um-unglaeubige-zu-toeten-afrika-fluechtling-schleppt-offene-tbc-in-schule-88-infizierte/
# 2021-12-07 08:25:59,385 - root - INFO - Article title downloaded from https://de.sott.net/article/31198-Trotz-versuchter-Verhinderung-90-der-Katalanen-stimmen-fur-die-Unabhangigkeit
# 2021-12-07 08:26:00,255 - root - INFO - Article title downloaded from http://noch.info/2017/10/tabuthema-die-fluechtlingskosten-in-deutschland-sind-astronomisch-hoch/
# 2021-12-07 08:26:02,143 - root - INFO - Article title downloaded from http://zuerst.de/2017/12/15/auslaendergewalt-einzelfaelle-von-mord-ueber-versuchten-toschlag-bis-hin-zu-massenschlaegerei/
# 2021-12-07 08:26:02,990 - root - INFO - Article title downloaded from http://www.anonymousnews.ru/2017/10/31/merkel-regime-im-jahr-1849-war-in-deutschland-mehr-meinungsfreiheit-garantiert-als-heute/
# 2021-12-07 08:26:03,091 - root - INFO - Article title downloaded from http://smopo.ch/rassismus-eklat-bei-nato-uebung/
# 2021-12-07 08:26:03,098 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/hund-rettet-oma-60-bei-ueberfall-durch-schwarzhaeutigen-fluechtling-vergewaltigung-vereitelt/
# 2021-12-07 08:26:03,100 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/rentnerin-vs-refugee-kruecke-als-vergewaltigungs-und-raubschutz/
# 2021-12-07 08:26:03,104 - root - INFO - Article title downloaded from http://www.allesroger.at/artikel/islamkindergaerten-keine-spur-von-integration
# 2021-12-07 08:26:03,107 - root - INFO - Article title downloaded from http://www.noislam.de/multikulti-pulverfass-explodiert-in-schweden-tobt-bereits-der-buergerkrieg-medien-schweigen/
# 2021-12-07 08:26:03,959 - root - INFO - Article title downloaded from http://www.truth24.net/integrationsturnier-armutsfluechtlinge-ruecken-mit-familienclans-und-messern-an/
# 2021-12-07 08:26:05,721 - root - INFO - Article title downloaded from https://www.compact-online.de/asyl-skandal-vor-der-wahl-merkel-will-fluechtlingsdeal-mit-libyen/
# 2021-12-07 08:26:06,292 - root - INFO - Article title downloaded from http://www.guidograndt.de/2018/02/14/vorbereitung-zu-neuer-false-flag-in-syrien-russland-warnt-provozierter-giftgas-angriff-von-terroristen-weisshelme-cnn-verwickelt/
# 2021-12-07 08:26:06,359 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/82jaehrige-glueck-gehabt-dass-fluechtling-grad-nicht-geil-war-nur-auf-friedhof-ausgeraubt/
# 2021-12-07 08:26:07,363 - root - INFO - Article title downloaded from https://www.journalistenwatch.com/2018/01/29/wen-verdammt-noch-mal-haben-wir-eigentlich-in-unser-land-gelassen/
# 2021-12-07 08:26:10,909 - root - INFO - Article title downloaded from http://zuerst.de/2017/10/25/angriff-auf-patriotisches-hausprojekt/
# 2021-12-07 08:26:10,943 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/sockenlose-bundeswehr-soldaten-in-islam-sekten-moschee-zwangsislamisiert/
# 2021-12-07 08:26:10,945 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/vergewaltigungs-jihad-gruppenvergewaltigung-am-s-bahnhof-stellingen/
# 2021-12-07 08:26:11,526 - root - INFO - Article title downloaded from http://www.guidograndt.de/2018/01/13/12-jaehriger-afghane-mit-bart-drei-weitere-asylbewerber-attackieren-13-jaehriges-maedchen-sexuell/
# 2021-12-07 08:26:12,523 - root - INFO - Article title downloaded from https://www.journalistenwatch.com/2018/02/05/junge-lehrerin-im-namen-gottes-ist-unser-nationales-motto/
# 2021-12-07 08:26:13,453 - root - INFO - Article title downloaded from https://www.journalistenwatch.com/2018/02/13/abgelehnte-asylbewerber-sorgen-fuer-bahnhofssperrung/
# 2021-12-07 08:26:13,786 - root - INFO - Article title downloaded from http://zuerst.de/2017/11/03/integration-steht-dem-ziel-und-we%C2%ADsen-des-asyls-entgegen/
# 2021-12-07 08:26:13,832 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/arme-fluechtlinge-muessen-zur-tafel-weil-sie-im-jahr-milliarden-eurer-steuern-in-die-heimat-schicken/
# 2021-12-07 08:26:13,876 - root - INFO - Article title downloaded from http://smopo.ch/deutschland-verbrechen-mit-messern-um-1200-prozent-angestiegen/
# 2021-12-07 08:26:13,886 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/massiver-islamistenangriff-am-24-12-2017-auf-polizei-in-reutlingen/
# 2021-12-07 08:26:14,444 - root - INFO - Article title downloaded from http://www.guidograndt.de/2018/02/19/weisse-sklavinnen-sollen-in-fluechtlingslagern-zur-unterhaltung-dienen-so-uebel-wird-gegen-europaeische-deutsche-frauen-gehetzt-4/
# 2021-12-07 08:26:14,556 - root - INFO - Article title downloaded from http://smopo.ch/schweden-werden-auf-eigenenvoelkermord-vorbereitet/
# 2021-12-07 08:26:14,954 - root - INFO - Article title downloaded from http://www.freiewelt.net/nachricht/auswertung-ergibt-parteien-auf-zerstoerungskurs-der-familie-10072048/
# 2021-12-07 08:26:15,040 - root - INFO - Article title downloaded from http://smopo.ch/merkel-schliesst-bundeswehreinsatz-nordkorea-nicht-aus/
# 2021-12-07 08:26:15,829 - root - INFO - Article title downloaded from http://info-direkt.eu/2018/02/23/nazikeule-wirkt-nicht-mehr-patriotischer-kongress-erneut-ausverkauft/
# 2021-12-07 08:26:15,877 - root - INFO - Article title downloaded from https://schluesselkindblog.com/2017/12/10/wie-der-links-staat-seine-gewalt-und-versaeumnisse-rechten-in-die-schuhe-schiebt/
# 2021-12-07 08:26:16,740 - root - INFO - Article title downloaded from http://www.truth24.net/mutmassliche-muslimgang-sticht-koelner-karnevalist-auf-heimweg-brutal-nieder/
# 2021-12-07 08:26:17,365 - root - INFO - Article title downloaded from http://www.guidograndt.de/2018/01/16/von-wegen-obergrenze-so-werden-sie-in-der-fluechtlingsfrage-von-deutschen-politikern-fuer-dumm-verkauft/
# 2021-12-07 08:26:18,284 - root - INFO - Article title downloaded from https://perspektive-online.net/2018/01/koeln-gewalt-an-frauen-ist-ein-verbrechen-keine-frage-der-herkunft/
# 2021-12-07 08:26:19,343 - root - INFO - Article title downloaded from http://www.truth24.net/asylant-aus-schwarzafrika-vergewaltigt-frankenthalerin-27-am-neujahrsmorgen/
# 2021-12-07 08:26:19,441 - root - INFO - Article title downloaded from http://smopo.ch/israel-atomare-vernichtung-deutschlands-gefordert/
# 2021-12-07 08:26:19,448 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/seit-oeffnung-der-bundeswehr-fuer-islamisten-vergewaltigungen-sprunghaft-gestiegen/
# 2021-12-07 08:26:20,624 - root - INFO - Article title downloaded from http://noch.info/2015/12/deutschland-schickt-taeglich-zig-busse-nach-griechenland-und-bringt-fluechtlinge-auf-einer-wenig-befahrenen-route-reisebuero-merkel-faymann/
# 2021-12-07 08:26:22,498 - root - INFO - Article title downloaded from http://www.epochtimes.de/gesundheit/bevoelkerungswachstum-kontrollieren-kenianische-aerzte-entdecken-sterilisationsmittel-in-impfstoffen-a1337657.html
# 2021-12-07 08:26:22,542 - root - INFO - Article title downloaded from https://schluesselkindblog.com/2018/02/19/bundeswehr-probleme-lassen-mehr-sabotage-als-pannen-vermuten/
# 2021-12-07 08:26:23,405 - root - INFO - Article title downloaded from http://www.truth24.net/doch-keine-nazis-armutsfluechtling-steckte-ehemaliges-asylhotel-selbst-an/
# 2021-12-07 08:26:24,006 - root - INFO - Article title downloaded from http://www.guidograndt.de/2017/12/15/blamage-fuer-refugee-politik-98-prozent-fluechtlinge-eines-berufs-integrations-projekts-nicht-vermittelbar/
# 2021-12-07 08:26:24,184 - root - INFO - Article title downloaded from https://de.sott.net/article/32048-Halbe-Wahrheit-Atomtests-in-USA-haben-fast-700000-Menschen-getotet-Was-wird-verschwiegen
# 2021-12-07 08:26:24,837 - root - INFO - Article title downloaded from http://news-for-friends.de/merkel-eheman-sauer-wird-vorstand-in-der-springer-stiftung/
# 2021-12-07 08:26:25,788 - root - INFO - Article title downloaded from http://smopo.ch/berlin-merkel-laesst-dissidenten-verhaften/
# 2021-12-07 08:26:26,688 - root - INFO - Article title downloaded from http://www.truth24.net/migrant-versucht-frau-in-wolfenbuettel-zu-vergewaltigen/
# 2021-12-07 08:26:26,899 - root - INFO - Article title downloaded from https://de.sott.net/article/31968-So-schaut-Propaganda-aus-Hungernder-Eisbar-in-der-Arktis-gefilmt-Und-der-Mensch-tragt-keine-Schuld
# 2021-12-07 08:26:26,992 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/zu-heiligabend-islamist-zuendet-hund-bei-lebendigem-leibe-an/
# 2021-12-07 08:26:27,936 - root - INFO - Article title downloaded from http://www.anonymousnews.ru/2017/10/20/staatsterrorismus-landeskriminalamt-stiftete-amri-zu-anschlag-auf-berliner-weihnachtmarkt-an/
# 2021-12-07 08:26:29,400 - root - INFO - Article title downloaded from https://www.compact-online.de/forscher-rechnen-volksaustausch-vor-75-millionen-muslime-in-eu-bis-2050-grenzschliessung-zwecklos/
# 2021-12-07 08:26:29,649 - root - INFO - Article title downloaded from https://philosophia-perennis.com/2017/10/24/deutschland-zensur/
# 2021-12-07 08:26:29,786 - root - INFO - Article title downloaded from http://smopo.ch/juncker-plant-ehrung-fuer-hitler/
# 2021-12-07 08:26:31,014 - root - INFO - Article title downloaded from http://www.journalistenwatch.com/2017/12/13/abgeschobener-afghane-landet-am-donnerstag-wieder-in-deutschland/
# 2021-12-07 08:26:31,890 - root - INFO - Article title downloaded from http://www.truth24.net/migrantenhorde-lockt-maedchen-mit-drogen-und-versucht-es-zu-vergewaltigen/
# 2021-12-07 08:26:32,928 - root - INFO - Article title downloaded from http://www.rapefugees.net/wirtschaftsfluechtling-vergewaltigt-frau-wirft-sie-aus-fenster-und-vergeht-sich-an-kind-bensheim-hessen/
# 2021-12-07 08:26:33,244 - root - INFO - Article title downloaded from http://www.epochtimes.de/politik/deutschland/ueberwaeltigende-resonanz-hessische-mohren-apotheke-wappnet-sich-gegen-namensaenderung-a2340330.html
# 2021-12-07 08:26:33,339 - root - INFO - Article title downloaded from http://smopo.ch/sohn-von-boris-becker-ein-uebler-rassist/
# 2021-12-07 08:26:34,427 - root - INFO - Article title downloaded from http://www.journalistenwatch.com/2018/01/08/orban-der-rigorose-grenzwaechter/
# 2021-12-07 08:26:35,400 - root - INFO - Article title downloaded from http://www.journalistenwatch.com/2017/10/25/24-stunden-in-hamburg-mord-vergewaltigung-und-schuesse/
# 2021-12-07 08:26:35,419 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/koeln-polizei-hat-ebertplatz-aufgegeben-und-den-migranten-ueberlassen/
# 2021-12-07 08:26:36,446 - root - INFO - Article title downloaded from http://www.journalistenwatch.com/2018/01/09/von-wegen-verhandlungen-familiennachzug-wird-schon-vorbereitet/
# 2021-12-07 08:26:36,464 - root - INFO - Article title downloaded from http://www.allesroger.at/artikel/beuten-aeltere-frauen-fluechtlinge-sexuell-aus
# 2021-12-07 08:26:36,761 - root - INFO - Article title downloaded from http://zuerst.de/2017/08/10/gutmenschen-und-zeitgeist-in-koeln-entsteht-eine-islamgerechte-hock-toilette-nach-mekka-kacken-geht-gar-nicht/
# 2021-12-07 08:26:36,789 - root - INFO - Article title downloaded from http://www.allesroger.at/artikel/der-weihnachtliche-kniefall-vor-dem-islam
# 2021-12-07 08:26:36,791 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/linkssiff-polizeichef-merbitz-kollaboriert-offen-mit-linksterroristen/
# 2021-12-07 08:26:36,795 - root - INFO - Article title downloaded from https://schluesselkindblog.com/2018/02/26/3-jaehrigen-ins-krankenhaus-getreten-wieder-merkel-fachkraft/
# 2021-12-07 08:26:37,093 - root - INFO - Article title downloaded from http://www.epochtimes.de/politik/europa/die-freuden-des-muslimischen-lebens-oesterreichs-kleine-sozialhilfe-harems-a1303734.html
# 2021-12-07 08:26:38,017 - root - INFO - Article title downloaded from http://noch.info/2016/03/totale-ueberwachung-alle-deutsche-internet-nutzer-werden-durch-eine-neue-software-namens-bundestrojaner-ausspioniert/
# 2021-12-07 08:26:40,319 - root - INFO - Article title downloaded from http://www.rapefugees.net/regierung-berlin-vertuscht-bub-12-mit-pistole-am-kopf-103-mal-durch-muslimischen-araber-44-vergewaltigt/
# 2021-12-07 08:26:41,336 - root - INFO - Article title downloaded from http://www.rapefugees.net/gruppenvergewaltigung-mutter-vor-kind-brutal-durch-islamisten-in-kurpark-geschaendet-lueneburg/
# 2021-12-07 08:26:43,242 - root - INFO - Article title downloaded from http://www.truth24.net/afrikaner-reibt-geschlechtsteil-an-studentin-in-strassenbahn-augsburg/
# 2021-12-07 08:26:44,342 - root - INFO - Article title downloaded from http://www.journalistenwatch.com/2017/10/25/schwerer-anschlag-auf-einprozent-haus-in-halle/
# 2021-12-07 08:26:44,592 - root - INFO - Article title downloaded from https://philosophia-perennis.com/2017/12/15/antisemitismus-schule/
# 2021-12-07 08:26:44,666 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/fluechtlinge-oder-nazis-klauten-oezdemirs-e-bike-fahrrad/
# 2021-12-07 08:26:44,668 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/mitten-in-deutschland-islamist-schaechtet-seine-eigene-tochter-2/
# 2021-12-07 08:26:45,760 - root - INFO - Article title downloaded from https://dieunbestechlichen.com/2017/12/auschwitz-geschichtswissen-oder-instrument-politischer-erziehung/
# 2021-12-07 08:26:45,857 - root - INFO - Article title downloaded from http://www.allesroger.at/artikel/islamisierung-in-zahlen
# 2021-12-07 08:26:45,860 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/neue-spielplatzverordnung-ab-20-muslime-nur-noch-spielplaetze-in-islamoptik/
# 2021-12-07 08:26:46,832 - root - INFO - Article title downloaded from http://www.mmnews.de/wirtschaft/36386-siemens-proteste-merkels-arbeitslose
# 2021-12-07 08:26:48,349 - root - INFO - Article title downloaded from https://www.compact-online.de/verdaechtiges-paket-am-potsdamer-weihnachtsmarkt-evakuierung/
# 2021-12-07 08:26:49,386 - root - INFO - Article title downloaded from https://dieunbestechlichen.com/2017/12/maulkorb-eu-projekt-erklaert-journalisten-wie-sie-ueber-die-massenmigration-zu-berichten-haben/
# 2021-12-07 08:26:49,723 - root - INFO - Article title downloaded from http://www.epochtimes.de/politik/deutschland/mobbing-in-der-schule-voranschreitende-radikalisierung-des-islam-ist-ein-problem-a2362262.html?meistgelesen=1
# 2021-12-07 08:26:50,290 - root - INFO - Article title downloaded from http://blauerbote.com/2017/09/21/spd-politiker-bringt-blogger-in-den-knast/
# 2021-12-07 08:26:51,444 - root - INFO - Article title downloaded from http://noch.info/2016/05/der-cia-agent-bin-laden-ist-lebendig-und-laesst-es-sich-auf-den-bahamas-gut-gehen-edward-snowden/
# 2021-12-07 08:26:53,200 - root - INFO - Article title downloaded from http://www.epochtimes.de/politik/deutschland/migranten-als-bevoelkerungsersatz-fuer-europaeer-bereits-seit-2000-offiziell-in-planung-a2276366.html
# 2021-12-07 08:26:54,230 - root - INFO - Article title downloaded from http://www.truth24.net/silvesterattacke-armutsfluechtling-versucht-frau-zu-vergewaltigen-schwabach/
# 2021-12-07 08:26:54,274 - root - INFO - Article title downloaded from http://www.noislam.de/deutschland-untergang-oder-daemmerung/
# 2021-12-07 08:26:55,179 - root - INFO - Article title downloaded from https://www.journalistenwatch.com/2018/02/02/familiennachzug-warum-1000-angehoerige-pro-monat-eine-falle-sind/
# 2021-12-07 08:26:58,279 - root - INFO - Article title downloaded from http://bereicherungswahrheit.com/asylbewerber-bekommen-den-fuehrerschein-zum-nulltarif/
# 2021-12-07 08:26:58,289 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/kriegswinter-2017-rentner-in-luebeck-durch-fluechtling-erschlagen/
# 2021-12-07 08:26:58,291 - root - INFO - Article title downloaded from http://www.noislam.de/beleidigt-geschlagen-und-angespuckt-polizisten-werden-immer-oefter-von-migranten-angegriffen/
# 2021-12-07 08:26:58,562 - root - INFO - Article title downloaded from https://philosophia-perennis.com/2018/02/05/normale-woche/
# 2021-12-07 08:26:59,657 - root - INFO - Article title downloaded from http://www.truth24.net/afrikanischer-mob-belaestigt-frau-bespuckt-und-schlaegt-den-mutigen-helfer/
# 2021-12-07 08:26:59,741 - root - INFO - Article title downloaded from http://smopo.ch/frankreich-ein-herz-fuer-paedophile/
# 2021-12-07 08:27:00,720 - root - INFO - Article title downloaded from https://www.journalistenwatch.com/2018/01/29/kandel-wir-sind-gekommen-um-zu-bleiben-oder-die-antifa-pfeift-auf-dem-letzten-loch/
# 2021-12-07 08:27:01,618 - root - INFO - Article title downloaded from https://dieunbestechlichen.com/2017/12/wir-moslems-koennen-nicht-gleichzeitig-mit-euch-existieren/
# 2021-12-07 08:27:01,857 - root - INFO - Article title downloaded from http://www.gegenfrage.com/reichsten-0001-636/
# 2021-12-07 08:27:01,866 - root - INFO - Article title downloaded from https://schluesselkindblog.com/2018/02/16/causa-yuecel-und-das-wort-eines-spd-politikers/
# 2021-12-07 08:27:01,868 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/genozid-wieder-obdachloser-durch-fluechtlinge-gesteinigt-und-lebendig-begraben/
# 2021-12-07 08:27:01,923 - root - INFO - Article title downloaded from http://smopo.ch/mossul-fuer-frauen-sicherer-als-stockholm/
# 2021-12-07 08:27:01,928 - root - INFO - Article title downloaded from http://www.noislam.de/sex-dschihad-in-schweden-frauen-werden-beim-joggen-von-bewaffneten-polizisten-eskortiert/
# 2021-12-07 08:27:02,918 - root - INFO - Article title downloaded from https://dieunbestechlichen.com/2018/02/spd-bundestagsabgeordnete-und-schmarotzer-freund-karl-lauterbach-verhoehnt-deutsche-arbeiter/
# 2021-12-07 08:27:04,688 - root - INFO - Article title downloaded from https://www.compact-online.de/wann-kommt-die-asyl-welle-aus-dem-jemen-amis-und-saudis-haben-das-land-verwuestet-und-weitere-topmeldungen-vom-15-august/
# 2021-12-07 08:27:04,690 - root - INFO - Article title downloaded from https://schluesselkindblog.com/2018/02/22/keine-migranten-mehr-essener-tafel-zieht-notbremse/
# 2021-12-07 08:27:05,695 - root - INFO - Article title downloaded from https://dieunbestechlichen.com/2017/12/fluechtlings-aktion-der-bahn-junge-weisse-wehrlose-maedchen-als-lockvogel/
# 2021-12-07 08:27:06,722 - root - INFO - Article title downloaded from http://www.anonymousnews.ru/2017/10/13/verwaltungsgerichtshof-legalisiert-polygamie-syrer-wird-erster-deutscher-mit-zwei-ehefrauen/
# 2021-12-07 08:27:06,777 - root - INFO - Article title downloaded from http://www.noislam.de/afrikanischer-islamist-zuendet-an-heilig-abend-hund-an-und-verbrennt-ihn-zu-tode/
# 2021-12-07 08:27:10,107 - root - INFO - Article title downloaded from http://www.pi-news.net/2018/01/ingolstadt-mordangriff-auf-pizzaboten-mit-kettensaege-und-beil/
# 2021-12-07 08:27:10,340 - root - INFO - Article title downloaded from http://www.noislam.de/wegen-abfuhr-wuetender-schwarzafrikaner-sticht-frau-21-in-den-hals-todeskampf-in-celle/
# 2021-12-07 08:27:11,017 - root - INFO - Article title downloaded from http://www.guidograndt.de/2018/02/20/videodanke-mama-merkel-syrer-mit-2-frauen-6-kindern-bedankt-sich-fuer-sozialleistungen-und-5-zimmer-haus-mit-2-baedern/
# 2021-12-07 08:27:11,115 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/altpartei-politmaden-fordern-muslimische-lieder-zu-weihnachten-in-kirchen/
# 2021-12-07 08:27:11,162 - root - INFO - Article title downloaded from http://smopo.ch/hamburg-7-jaehrige-opfer-von-massenvergewaltigung/
# 2021-12-07 08:27:11,570 - root - INFO - Article title downloaded from https://alpenschau.com/2017/10/12/bundesregierung-fliegt-fluechtlinge-mit-charterflugzeugen-aus-griechenland-ein/
# 2021-12-07 08:27:11,584 - root - INFO - Article title downloaded from https://schluesselkindblog.com/2018/02/21/die-antifa-ein-buettel-der-politischen-elite/
# 2021-12-07 08:27:12,514 - root - INFO - Article title downloaded from http://www.anonymousnews.ru/2017/10/14/urteil-erklaert-bundestagswahl-2017-fuer-ungueltig-verfassungsgericht-schreibt-neuwahlen-vor/
# 2021-12-07 08:27:12,573 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/fluechtlinge-hacken-rostocker-die-hand-ab-rest-musste-amputiert-werden/
# 2021-12-07 08:27:13,053 - root - INFO - Article title downloaded from https://opposition24.com/koeln-mann-nordafrikanern-strasse/384560
# 2021-12-07 08:27:14,040 - root - INFO - Article title downloaded from https://dieunbestechlichen.com/2017/12/das-ende-der-nannymedien-historischer-verkaufseinbruch-bei-bild-spiegel-stern-focus/
# 2021-12-07 08:27:15,182 - root - INFO - Article title downloaded from http://www.journalistenwatch.com/2017/11/29/jean-claude-juncker-ohne-masseneinwanderung-ist-europa-verloren/
# 2021-12-07 08:27:15,217 - root - INFO - Article title downloaded from http://smopo.ch/deutschland-moslem-kinder-sind-lebende-zeitbomben/
# 2021-12-07 08:27:16,127 - root - INFO - Article title downloaded from http://info-direkt.eu/2017/12/20/achtung-lebensgefahr-in-den-alpen-entstehen-neue-migrationsrouten/
# 2021-12-07 08:27:19,776 - root - INFO - Article title downloaded from http://zuerst.de/2017/11/03/asyl-kosten-explodieren-auf-10-milliarden-euro-anstieg-um-73-prozent/
# 2021-12-07 08:27:20,369 - root - INFO - Article title downloaded from http://www.guidograndt.de/2018/02/05/tabuthema-muslimisierung-sogar-spd-politiker-kritisiert-migrantenmilieus/
# 2021-12-07 08:27:20,432 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/hannover-75-christliche-graeber-dem-heiligen-krieg-fuer-allah-zum-opfer-gefallen/
# 2021-12-07 08:27:20,486 - root - INFO - Article title downloaded from http://smopo.ch/soros-unterstuetzt-einfuehrung-der-scharia-deutschland/
# 2021-12-07 08:27:21,321 - root - INFO - Article title downloaded from http://www.truth24.net/wieder-eine-grossmutter-durch-muslim-sexuell-attackiert-stuttgart/
# 2021-12-07 08:27:21,616 - root - INFO - Article title downloaded from https://philosophia-perennis.com/2018/02/06/medien-unterstuetzen-asylbetrueger-reicht-es-ihnen-immer-noch-nicht/
# 2021-12-07 08:27:28,691 - root - INFO - Article title downloaded from http://new.euro-med.dk/20160809-tief-in-der-nacht-landen-im-geheimen-minute-fur-minute-flugzeuge-mit-migranten-aus-der-turkei-in-deutschen-flughafen-sorosschocktherapie-fur-deutschland.php
# 2021-12-07 08:27:29,120 - root - INFO - Article title downloaded from https://www.unzensuriert.at/content/0025573-Marokkaner-verwuesten-Bruesseler-Innenstadt-belgischer-Innenminister-kann-es-gar
# 2021-12-07 08:27:29,439 - root - INFO - Article title downloaded from http://www.epochtimes.de/politik/deutschland/entdeckt-allahu-akbar-mit-tiptoi-fuer-kinder-ab-4-jahre-alice-weidel-warnt-vor-islam-im-kinderzimmer-a2352587.html
# 2021-12-07 08:27:29,484 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/polizei-keine-zeit-fuer-gruenen-nonsens-in-deutschland-wird-gemessert-und-vergewaltigt-durch-merkel-gaeste/
# 2021-12-07 08:27:29,714 - root - INFO - Article title downloaded from https://philosophia-perennis.com/2017/11/04/aegypten-nationale-pflicht-frauen-zu-vergewaltigen/
# 2021-12-07 08:27:30,695 - root - INFO - Article title downloaded from https://dieunbestechlichen.com/2017/12/gefaehrliche-fuehrerin-und-sogar-der-spiegel-will-nun-ein-ende-der-merkel-aera/
# 2021-12-07 08:27:31,530 - root - INFO - Article title downloaded from http://www.truth24.net/afrikanischer-islamist-zuendet-an-heilig-abend-hund-an-und-verbrennt-ihn-zu-tode/
# 2021-12-07 08:27:31,572 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/abgelehnter-fluechtling-schlitzt-waerter-im-knast-mit-cuttermesser-auf/
# 2021-12-07 08:27:31,575 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/zivilcourage-einbrecher-fluechtling-mit-baseballschlaeger-vermoebelt/
# 2021-12-07 08:27:31,799 - root - INFO - Article title downloaded from https://philosophia-perennis.com/2017/10/25/deutschland-hoelle/
# 2021-12-07 08:27:31,875 - root - INFO - Article title downloaded from https://schluesselkindblog.com/2018/01/01/duesseldorf-mit-auto-gezielt-in-personengruppe-gefahren/#comments
# 2021-12-07 08:27:32,581 - root - INFO - Article title downloaded from https://deutsch.rt.com/newsticker/65577-zu-viele-weisse-gluckliche-christen-ungarn-kulturhauptstadt/
# 2021-12-07 08:27:33,094 - root - INFO - Article title downloaded from https://opposition24.com/von-wegen-die-republik-rueckt-nach-rechts/356935
# 2021-12-07 08:27:33,276 - root - INFO - Article title downloaded from https://de.sott.net/article/32235-Vertuscht-von-ganz-oben-Tausende-Padophile-arbeiten-fur-die-UN
# 2021-12-07 08:27:33,361 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/der-weihnachtsmarkt-in-siegburg-heisst-jetzt-orientalischer-wintermarkt/
# 2021-12-07 08:27:34,302 - root - INFO - Article title downloaded from http://www.rapefugees.net/in-gruppenvergewaltigung-entjungfert-3-islamisten-schaenden-jungfrau-brutal-nuernberg/
# 2021-12-07 08:27:35,184 - root - INFO - Article title downloaded from http://www.rapefugees.net/maedchen-will-keinen-sex-araber-bespuckt-wuergt-tritt-auf-kopf-und-busen-alltag-bahn/
# 2021-12-07 08:27:36,079 - root - INFO - Article title downloaded from http://info-direkt.eu/2018/01/06/weiterhin-taeglich-aufgriffe-illegaler-migranten-am-brenner/
# 2021-12-07 08:27:36,975 - root - INFO - Article title downloaded from http://info-direkt.eu/2017/12/23/erstmals-migranten-aus-afrika-nach-italien-eingeflogen/
# 2021-12-07 08:27:37,948 - root - INFO - Article title downloaded from http://www.truth24.net/schwarzfahrender-armutsmigrant-in-bomberjacke-bedroht-polizistin-mit-kuechenmesser/
# 2021-12-07 08:27:38,429 - root - INFO - Article title downloaded from https://opposition24.com/heulsusen-alarm-wenn-staatsfunker/366551
# 2021-12-07 08:27:38,435 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/projekt-todesborn-fluechtlinge-sollen-mit-deutschen-schuelerinnen-verpaart-werden/
# 2021-12-07 08:27:38,725 - root - INFO - Article title downloaded from http://zuerst.de/2017/11/27/schwedische-protestanten-im-gender-rausch-heiliger-geist-wird-weiblich-und-gott-geschlechtsneutral/
# 2021-12-07 08:27:39,189 - root - INFO - Article title downloaded from https://opposition24.com/afd-politiker-berg-studie/393198
# 2021-12-07 08:27:42,056 - root - INFO - Article title downloaded from http://www.freisleben-news.at/eu-will-per-gesetz-eine-neue-fluechtlings-flut-erzwingen/
# 2021-12-07 08:27:43,411 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/steinzeitliche-fluechtlingsbestien-stechen-immer-haeufiger-auf-deutsche-ein/
# 2021-12-07 08:27:43,464 - root - INFO - Article title downloaded from http://smopo.ch/europas-regierungen-planen-vernichtung-der-einheimischen-bevoelkerungen/
# 2021-12-07 08:27:43,527 - root - INFO - Article title downloaded from http://smopo.ch/frankfurt-ist-jetzt-keine-deutsche-stadt-mehr/
# 2021-12-07 08:27:44,255 - root - INFO - Article title downloaded from http://noch.info/2017/11/die-ddr-taeter-gauck-de-maiziere-und-hitlers-tochter-merkel-alles-faschisten/
# 2021-12-07 08:27:45,759 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/muslime-lauern-frauen-nach-weihnachtsmarkt-im-stadtpark-von-halle-auf/
# 2021-12-07 08:27:46,693 - root - INFO - Article title downloaded from http://www.truth24.net/wie-deutsche-belogen-betrogen-und-medial-manipuliert-werden/
# 2021-12-07 08:27:47,278 - root - INFO - Article title downloaded from http://www.guidograndt.de/2018/02/13/gender-gutmenschen-wahn-jetzt-sollen-wir-die-bestien-die-unsere-kinder-missbrauchen-nicht-mehr-kinderschaender-nennen/
# 2021-12-07 08:27:48,201 - root - INFO - Article title downloaded from http://www.truth24.net/migrantengang-ueberfaellt-paerchen-schlaegt-frau-und-klaut-spielekonsole-frankfurt/
# 2021-12-07 08:27:48,554 - root - INFO - Article title downloaded from http://zuerst.de/2017/11/23/neuer-ueberwachungsangriff-bruessel-will-ab-2020-emissionsmelder-in-allen-pkw/
# 2021-12-07 08:27:49,566 - root - INFO - Article title downloaded from http://www.journalistenwatch.com/2017/12/20/bka-statistik-700-000-straftaten-durch-fluechtlinge/
# 2021-12-07 08:27:50,425 - root - INFO - Article title downloaded from http://www.truth24.net/armutsmigrant-attackiert-studentin-auf-universitaets-toilette-campus-freiburg/
# 2021-12-07 08:27:50,986 - root - INFO - Article title downloaded from http://blauerbote.com/2017/05/07/angela-merkel-setzt-bundeswehr-gegen-demonstranten-ein/
# 2021-12-07 08:27:51,534 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/luegenpresse-verharmlost-regelmaessig-brutale-vergewaltigungen-durch-fluechtlinge/
# 2021-12-07 08:27:51,534 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/wieder-joggerin-von-vergwaltiger-fluechtling-angefallen/
# 2021-12-07 08:27:51,547 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/achtung-fluechtlinge-lauern-friedhofsbesucher-auf-um-zu-vergewaltigen/
# 2021-12-07 08:27:51,587 - root - INFO - Article title downloaded from http://smopo.ch/deutschland-spd-aussenminister-gabriel-sorgt-fuer-verwirrung/
# 2021-12-07 08:27:51,807 - root - INFO - Article title downloaded from http://www.epochtimes.de/politik/deutschland/inhaftierter-welt-journalist-yuecel-freude-ueber-deutschensterben-und-sarrazin-naechsten-schlaganfall-gewuenscht-a2060022.html?meistgelesen=1
# 2021-12-07 08:27:51,858 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/linksterroristen-brechen-bei-fpoe-strache-ein-und-installieren-wanzen/
# 2021-12-07 08:27:52,753 - root - INFO - Article title downloaded from http://www.truth24.net/wegen-abfuhr-wuetender-schwarzafrikaner-sticht-frau-21-in-den-hals-todeskampf-in-celle/
# 2021-12-07 08:27:52,854 - root - INFO - Article title downloaded from http://smopo.ch/deutschland-merkels-gaeste-spielen-wilde-sau/
# 2021-12-07 08:27:53,817 - root - INFO - Article title downloaded from https://dieunbestechlichen.com/2017/12/kandel-organisierte-die-stadt-fluechtlings-parship-fuer-jugendliche-buergermeister-warnt-vor-fremdenfeindlichkeit/
# 2021-12-07 08:27:54,949 - root - INFO - Article title downloaded from http://www.journalistenwatch.com/2017/11/29/warum-uebersetzen-medien-und-amtstraeger-allahu-akbar-konstant-falsch/
# 2021-12-07 08:27:55,387 - root - INFO - Article title downloaded from https://www.unzensuriert.at/content/0025749-Weil-er-antinational-ist-Karlspreis-2018-geht-franzoesischen-Praesidenten-Emmanuel
# 2021-12-07 08:27:55,395 - root - INFO - Article title downloaded from https://blog.halle-leaks.de/fluechtling-tritt-3-jaehriges-kind-ins-krankenhaus-weil-es-ihm-keinen-platz-machte-schaedel-hirn-trauma/
# 2021-12-07 08:27:55,691 - root - INFO - Article title downloaded from http://zuerst.de/2017/11/02/asyl-ansturm-wie-der-staat-asylbewerber-zu-einwandern-macht/
# 2021-12-07 08:27:56,661 - root - INFO - Article title downloaded from http://www.truth24.net/armutsfluechtling-kastrati-weiterhin-wegen-mordattacke-von-polizei-gesucht/
# 2021-12-07 08:27:56,945 - root - INFO - Article title downloaded from http://www.epochtimes.de/politik/europa/40-jahre-multikulti-in-schweden-300-mehr-gewaltverbrechen-und-1472-mehr-vergewaltigungen-a2035485.html
# 2021-12-07 08:27:57,413 - root - INFO - Article title downloaded from https://opposition24.com/staatsfunk-fantasiert-ueber-rechte-trollfabriken/408637
# 2021-12-07 08:27:58,180 - root - INFO - Article title downloaded from https://www.unzensuriert.at/content/0025783-Neue-Regierung-auf-Leistungskurs-im-Bildungswesen
# 2021-12-07 08:27:59,941 - root - INFO - Article title downloaded from http://www.labournet.de/politik/wipo/privatisierung/privatbildung/volksinitiative-gegen-schulprivatisierung-berlin-gestartet-schulprivatisierung-droht-2018-ganz-deutschland/?cat=6757
# ...
# 2021-12-07 08:35:41,902 - root - INFO - Article text downloaded from http://www.epochtimes.de/politik/deutschland/lueneburg-gymnasium-verschiebt-weihnachtsfeier-muslimin-stoerten-die-lieder-a2299536.html
# 2021-12-07 08:35:42,000 - root - INFO - Article text downloaded from http://smopo.ch/deutschland-macht-wieder-kinder-zu-soldaten/
# 2021-12-07 08:35:42,063 - root - INFO - Article text downloaded from http://smopo.ch/gruene-neonazis-deutschland-waere-langweilig-ohne-islam/
# 2021-12-07 08:35:43,044 - root - INFO - Article text downloaded from https://dieunbestechlichen.com/2017/12/neue-studie-beweist-linke-und-gruene-sind-und-bleiben-kindskoepfe/
# 2021-12-07 08:35:43,967 - root - INFO - Article text downloaded from http://www.truth24.net/nigerianer-24-faellt-ueber-seniorin-her-und-vergewaltig-sie-muenchen/
# 2021-12-07 08:35:44,466 - root - INFO - Article text downloaded from https://opposition24.com/fuckten-zdf-faktencheck-medien/356955
# 2021-12-07 08:35:44,469 - root - INFO - Article text downloaded from http://www.noislam.de/aufgedeckt-tausende-schwerverbrecher-aus-maghreb-staaten-als-fluechtlinge-in-deutschland-entsorgt/
# 2021-12-07 08:35:44,925 - root - INFO - Article text downloaded from https://opposition24.com/russische-reichsbuerger-die-wiederauferstehung/379240
# 2021-12-07 08:35:45,476 - root - INFO - Article text downloaded from http://zuerst.de/2017/11/03/gewaltausbruch-in-essen-200-maenner-mit-migrationshintergrund-in-kleingruppen-attackieren-halloween-feier/
# 2021-12-07 08:35:52,506 - root - INFO - Article text downloaded from http://new.euro-med.dk/20171204-der-humanitarismus-der-deutschen-piloten-wollen-abzuschiebende-nicht-nach-afghanistan-fliegen-afghanen-schalen-wegen-sex-mit-muslimin-danischem-mann-haut-von-penis-ab-schwedischer-ex-ministerpras.php
# 2021-12-07 08:35:52,552 - root - INFO - Article text downloaded from http://smopo.ch/mit-droge-zur-fluechtlingsakzeptanz/
# 2021-12-07 08:35:53,405 - root - INFO - Article text downloaded from http://www.rapefugees.net/der-uni-frankfurt-egal-muslime-vergewaltigen-deutsche-studentinnen-auf-uni-campus/
# 2021-12-07 08:35:53,732 - root - INFO - Article text downloaded from http://www.epochtimes.de/politik/deutschland/amurat-spielt-prinzessin-und-sophie-heisst-jetzt-ben-berliner-senat-will-sexuelle-vielfalt-im-kleinkindalterberliner-senat-will-sexuelle-vielfalt-im-kleinkindalter-eltern-sind-dagegen-und-lan-a2348651.html
# 2021-12-07 08:35:53,787 - root - INFO - Article text downloaded from http://www.noislam.de/der-totale-ueberwachungsstaat-de-maiziere-voellig-gaga-staatlicher-zugriff-auf-alle-digitalen-geraete/
# 2021-12-07 08:35:54,725 - root - INFO - Article text downloaded from https://dieunbestechlichen.com/2018/02/die-antifa-ist-ein-buettel-der-herrschenden/
# 2021-12-07 08:35:54,807 - root - INFO - Article text downloaded from https://schluesselkindblog.com/2017/12/29/beihilfe-und-luegenmedien-warum-tv-macher-auch-noch-mit-ueber-90-in-den-knast-wandern-koennten/
# 2021-12-07 08:35:54,857 - root - INFO - Article text downloaded from http://smopo.ch/deutschlands-sozialdemokraten-peilen-5-prozent-huerde/
# 2021-12-07 08:35:54,859 - root - INFO - Article text downloaded from http://www.noislam.de/kandel-buergermeister-volker-poss-mach-sich-mehr-sorgen-um-fremdenfeindlichkeit-und-pauschalisierung-als-um-das-opfer-sorgte/
# 2021-12-07 08:35:54,963 - root - INFO - Article text downloaded from http://blaue-flora.de/polizei-fuehrt-in-mehreren-bundeslaendern-elektroschocker-ein/
# 2021-12-07 08:35:55,789 - root - INFO - Article text downloaded from http://www.rapefugees.net/gruppenvergewaltigung-armutsfluechtlinge-vergewaltigen-bettlaegerige-oma-im-schlaf-krankenhausreif/
# 2021-12-07 08:35:55,972 - root - INFO - Article text downloaded from https://de.sott.net/article/31425-Schnoggersburg-Ubungsstadt-fur-psychopathische-Kriegsspiele-und-Gewalt-gegen-eigenes-Volk-fast-betriebsbereit
# 2021-12-07 08:35:57,021 - root - INFO - Article text downloaded from http://www.journalistenwatch.com/2017/11/21/gewaltwelle-durch-arabische-fluechtlinge/
# 2021-12-07 08:35:57,031 - root - INFO - Article text downloaded from https://blog.halle-leaks.de/fluechtling-durch-rottweiler-biss-an-vergewaltigung-einer-oma-65-gehindert/
# 2021-12-07 08:35:58,060 - root - INFO - Article text downloaded from http://noch.info/2016/03/merkel-hat-ein-selfie-mit-einem-der-bruessel-terroristen-gemacht/
# 2021-12-07 08:36:00,535 - root - INFO - Article text downloaded from https://www.journalistenwatch.com/2017/09/21/wen-wuerde-allah-waehlen/
# 2021-12-07 08:36:00,582 - root - INFO - Article text downloaded from http://smopo.ch/zehntausende-terroristen-wollen-nach-europa/
# 2021-12-07 08:36:01,566 - root - INFO - Article text downloaded from https://www.journalistenwatch.com/2018/02/18/berliner-polizei-und-antifa-gemeinsam-gegen-frauenrechte/
# 2021-12-07 08:36:01,579 - root - INFO - Article text downloaded from https://blog.halle-leaks.de/merkels-terror-fluechtlinge-busfahrer-brutal-zusammengeschlagen-auf-einem-auge-nun-blind-arbeitslos/
# 2021-12-07 08:36:01,965 - root - INFO - Article text downloaded from https://www.zeitenschrift.com/artikel/masseneinwanderung-und-die-luegenpresse
# 2021-12-07 08:36:02,154 - root - INFO - Article text downloaded from https://blog.halle-leaks.de/putsch-islamistische-polizisten-darsteller-wollen-berliner-polizei-uebernehmen-massenschlaegerei/
# 2021-12-07 08:36:02,662 - root - INFO - Article text downloaded from http://blauerbote.com/2017/12/09/landgericht-hamburg-wer-fake-news-aufdeckt-macht-sich-strafbar/
# 2021-12-07 08:36:03,030 - root - INFO - Article text downloaded from http://www.allesroger.at/artikel/der-alternative-jahresrueckblick-von-alles-roger
# 2021-12-07 08:36:03,183 - root - INFO - Article text downloaded from https://perspektive-online.net/2018/02/donauwoerth-abgeschobene-fluechtlinge-wollen-nach-italien-ausreisen-polizei-hindert-sie/
# 2021-12-07 08:36:03,890 - root - INFO - Article text downloaded from http://www.guidograndt.de/2017/11/22/horror-innere-sicherheit-ferngesteuerte-fahrzeuge-mit-sprengstoff-neue-attentatsplaene-von-is-terroristen-in-deutschland/
# 2021-12-07 08:36:03,976 - root - INFO - Article text downloaded from https://blog.halle-leaks.de/rotrotgruenes-schmarotzer-berlin-baut-24-neue-siedlungen-fuer-50-000-goldstuecke/
# 2021-12-07 08:36:03,983 - root - INFO - Article text downloaded from https://blog.halle-leaks.de/fluechtlingsbestie-will-8-jaehrige-auf-spielplatz-in-muenchen-vergewaltigen/
# 2021-12-07 08:36:04,541 - root - INFO - Article text downloaded from http://www.guidograndt.de/2018/02/17/sexueller-dschihad-mit-euren-toechtern-so-uebel-wird-gegen-europaeische-deutsche-frauen-gehetzt-3/
# 2021-12-07 08:36:05,222 - root - INFO - Article text downloaded from http://www.guidograndt.de/2018/01/15/unfassbar-richter-nimmt-waehrend-verhandlung-gegen-radikalen-muslim-kreuz-von-der-wand-wegen-unzumutbarer-innerer-belastung/
# 2021-12-07 08:36:06,198 - root - INFO - Article text downloaded from http://www.truth24.net/ueberlingen-dunkelhaeutiger-exhibitionist-zeigt-maedchen-penis-auf-nachhauseweg/
# 2021-12-07 08:36:06,891 - root - INFO - Article text downloaded from http://www.guidograndt.de/2018/02/06/einheimischen-rassismus-in-leipzig-rentner-muss-mit-monatlich-257-e-leben-behoerden-lehnen-sozialhilfe-ab-fluechtlingsvater-kassiert-7-300-e/
# 2021-12-07 08:36:07,046 - root - INFO - Article text downloaded from https://blog.halle-leaks.de/streichelzoo-neukoeln-traechtiges-schaf-in-berlin-gestohlen-geschaendet-geschaechtet-und-gefressen/
# 2021-12-07 08:36:07,380 - root - INFO - Article text downloaded from https://philosophia-perennis.com/2017/10/25/linksextremer-terror-in-halle/
# 2021-12-07 08:36:08,542 - root - INFO - Article text downloaded from http://www.journalistenwatch.com/2018/01/08/kika-der-kinderschaender-kanal/
# 2021-12-07 08:36:08,613 - root - INFO - Article text downloaded from http://smopo.ch/deutschland-streicht-die-rede-und-meinungsfreiheit-aus-dem-grundgesetz/
# 2021-12-07 08:36:09,654 - root - INFO - Article text downloaded from https://dieunbestechlichen.com/2017/12/ohne-auffanglager-in-afrika-wird-europa-bald-kollabieren/
# 2021-12-07 08:36:09,743 - root - INFO - Article text downloaded from https://blog.halle-leaks.de/wegen-dumm-und-faulheit-fluechtlingsversagen-auf-arbeitsmarkt/
# 2021-12-07 08:36:09,749 - root - INFO - Article text downloaded from https://blog.halle-leaks.de/araber-reisst-18jaehrige-in-hamburg-am-montag-demonstriert-die-antifa-fuer-mehr-vergewaltigungen/
# 2021-12-07 08:36:10,889 - root - INFO - Article text downloaded from http://www.journalistenwatch.com/2017/10/25/grossrazzia-in-islamistenszene-in-berlin/
# 2021-12-07 08:36:11,462 - root - INFO - Article text downloaded from http://www.guidograndt.de/2018/02/20/unangreifbar-leben-news-n0-1108-dieses-debakel-verspricht-ihnen-die-groko/
# 2021-12-07 08:36:12,042 - root - INFO - Article text downloaded from https://www.unzensuriert.at/content/0025547-Time-Magazin-ehrt-moslemische-Schuelerin-aus-Wien-als-Kopftuch-Emoji-Erfinderin
# 2021-12-07 08:36:12,051 - root - INFO - Article text downloaded from https://blog.halle-leaks.de/pervers-staatlich-organisierte-verpaarung-von-fluechtlingen-und-einheimischen/
# 2021-12-07 08:36:12,953 - root - INFO - Article text downloaded from http://www.truth24.net/achtung-polizei-bad-homburg-fahndet-nach-brutalem-moerder-mudasar-ali-rana/
# 2021-12-07 08:36:13,242 - root - INFO - Article text downloaded from http://www.epochtimes.de/politik/deutschland/duisburg-26-schulen-haben-ueber-70-prozent-kinder-mit-migrationshintergrund-a2350647.html
# 2021-12-07 08:36:13,794 - root - INFO - Article text downloaded from https://www.unzensuriert.at/content/0025772-Frauenbadetag-Picknick-am-Beckenrand-Urin-im-Mistkuebel-Babywindeln-im-Planschbecken
# 2021-12-07 08:36:13,796 - root - INFO - Article text downloaded from https://blog.halle-leaks.de/video-koelner-linksmaden-irrsinn-armbaender-sollen-vor-vergewaltigungen-schuetzen/
# 2021-12-07 08:36:14,338 - root - INFO - Article text downloaded from http://news-for-friends.de/islamischer-killerfluechtling-will-neuen-prozess-aber-vor-scharia-gericht/
# 2021-12-07 08:36:15,610 - root - INFO - Article text downloaded from http://www.allesroger.at/artikel/linker-meinungsterror-statt-freiheit
# 2021-12-07 08:36:16,490 - root - INFO - Article text downloaded from http://www.truth24.net/afrikanischer-islamist-zieht-frau-ins-gebuesch-und-versucht-sie-brutal-zu-vergewaltigen/
# 2021-12-07 08:36:16,710 - root - INFO - Article text downloaded from https://de.sott.net/article/32058-Die-Welt-brennt-nicht-nur-symbolisch-Die-Massen-schreien-Auslander
# 2021-12-07 08:36:17,735 - root - INFO - Article text downloaded from http://www.truth24.net/mehrere-sexattacken-armutsasylanten-ueberfallen-frauen-in-krefeld-um-sie-zu-vergewaltigen/
# 2021-12-07 08:36:17,764 - root - INFO - Article text downloaded from https://blog.halle-leaks.de/11jaehrige-gerade-so-einer-vergewaltigung-durch-5-fluechtlinge-entkommen/
# 2021-12-07 08:36:18,343 - root - INFO - Article text downloaded from http://www.guidograndt.de/2018/01/10/sie-kommen-egal-was-man-ihnen-erzaehlt-deutsche-regierung-bereitet-umstrittenen-fluechtlings-familiennachzug-vor/
# 2021-12-07 08:36:19,115 - root - INFO - Article text downloaded from http://www.guidograndt.de/2018/01/17/amtlich-die-meisten-terroristen-kommen-aus-afghanistan-somalia-syrien/
# 2021-12-07 08:36:20,183 - root - INFO - Article text downloaded from http://www.anonymousnews.ru/2017/11/01/sex-dschihad-in-essen-200-fluechtlinge-stuermen-halloween-party-medien-schweigen/
# 2021-12-07 08:36:20,232 - root - INFO - Article text downloaded from https://blog.halle-leaks.de/messer-jihad-in-koeln-moslem-sticht-behinderten-mit-taschenmesser-nieder/
# 2021-12-07 08:36:20,246 - root - INFO - Article text downloaded from https://blog.halle-leaks.de/erzieherin-will-von-uma-nicht-geschaechtet-werden-nimmt-freitod-in-kauf/
# 2021-12-07 08:36:21,698 - root - INFO - Article text downloaded from https://www.compact-online.de/armer-martin-schulz-nur-wenige-wollen-seine-vereinigten-staaten-von-europa/
# 2021-12-07 08:36:21,880 - root - INFO - Article text downloaded from https://de.sott.net/article/32263-Kindesmissbrauch-in-108-Fallen-Padophiler-Priester-wird-nicht-ins-Gefangnis-gesteckt
# 2021-12-07 08:36:21,961 - root - INFO - Head of dataframe after parsing:
#         Date                                                URL  \
# 0 2017-08-30  https://schluesselkindblog.com/2017/08/30/proz...
# 1 2017-12-18  http://blauerbote.com/2017/12/18/bild-journali...
# 2 2017-06-02  http://blauerbote.com/2017/06/02/angela-merkel...
# 3 2017-09-25  http://smopo.ch/deutschlands-neonazis-waehlen-...
# 4 2018-02-17  http://www.truth24.net/gruppenvergewaltigung-s...
#
#   False_Statement_1_Location False_Statement_1_Index  \
# 0                       Text                 213-237
# 1                       Text                   13-36
# 2                      Title                     1-7
# 3                      Title                     1-5
# 4                      Title                     1-1
#
#   False_Statement_2_Location False_Statement_2_Index  \
# 0
# 1                       Text                   52-81
# 2                       Text                   70-94
# 3                       Text                   28-53
# 4                      Title                     3-4
#
#   False_Statement_3_Location False_Statement_3_Index  \
# 0
# 1
# 2                       Text                 121-153
# 3                       Text                 127-141
# 4                      Title                     6-7
#
#    Ratio_of_Fake_Statements  Overall_Rating  \
# 0                         1             0.7
# 1                         3             0.8
# 2                         3             0.7
# 3                         3             0.8
# 4                         1             0.4
#
#                                                titel  \
# 0                                           No title
# 1  BILD-Journalist Julian Röpcke und seine Nazifr...
# 2  Angela Merkel läßt Rock am Ring abbrechen – Bl...
# 3                                           No title
# 4  Gruppenvergewaltigung: Sex Jihadisten vergewal...
#
#                                                 text
# 0                                            No text
# 1  Es ist schon ein (Haken-) Kreuz mit der Bildze...
# 2  Auch heute noch für Aufsehen sorgte der Widers...
# 3                                            No text
# 4  Bad Soden / Hofheim. Beim Herumvagabundieren ü...
# 2021-12-07 08:36:21,961 - root - INFO - Shape of final dataframe: (232, 12)
# 2021-12-07 08:36:21,961 - root - INFO - dtypes:
# Date                          datetime64[ns]
# URL                                   object
# False_Statement_1_Location            object
# False_Statement_1_Index               object
# False_Statement_2_Location            object
# False_Statement_2_Index               object
# False_Statement_3_Location            object
# False_Statement_3_Index               object
# Ratio_of_Fake_Statements               int64
# Overall_Rating                       float64
# titel                                 object
# text                                  object
# dtype: object
# 2021-12-07 08:36:21,974 - root - INFO - Rows with null values:
# Date                          17
# URL                            0
# False_Statement_1_Location     0
# False_Statement_1_Index        0
# False_Statement_2_Location     0
# False_Statement_2_Index        0
# False_Statement_3_Location     0
# False_Statement_3_Index        0
# Ratio_of_Fake_Statements       0
# Overall_Rating                 0
# titel                          0
# text                           0
# dtype: int64
# 2021-12-07 08:36:21,985 - root - INFO - CSV was saved to disk

# %% [markdown]
# #### Prepare the news.csv for individual (not merged with GermanFakeNC) use
# This merely drops columns Kategorie, Quelle and Art and removes duplicates from the news.csv

# %%
def prepare_news_csv(filepath):
    """ 
    1.) Drop columns -> Kategorie, Quelle, Art
    2.) Check on duplicate Titel and Body and drop the first entry of duplicates
    3.) Rename Columns in order to match it with the other dataset (GermanFakeNC)
    4.) Add column source_name with news_csv to identifiy the source of a row after merging
    """

    # Read news.csv from disk
    _df = pd.read_csv(filepath)
    logger.debug(_df.info())
    # Drop cols
    logger.info('Null values in news.csv: \n%s' % _df.isnull().sum())
    cols_to_drop = ['Kategorie', 'Quelle', 'Art']
    cols_to_drop = ['Art']
    _df.drop(cols_to_drop, axis=1, inplace=True)
    logger.info('Cols %s dropped' % cols_to_drop)


    # Drop duplicates
    logger.info('Percent duplicated Titel and Body: \n%s' % str(
        _df.duplicated(subset=['Titel', 'Body']).value_counts(normalize=True)))
    _df.drop_duplicates(subset=['Titel', 'Body'], inplace=True)
    logger.info('Duplicates in Titel and Body dropped')

    return _df

#     logger.info('Shape: %s\n Columns: %s' % (df_1.shape, df_1.columns))
#     logger.info('Shape: %s\n Columns: %s' % (df_2.shape, df_2.columns))
#     # Check col names
#     sym_diff = set(df_1).symmetric_difference(set(df_2))
#     assert len(sym_diff) == 0 , 'Differences in colnames of the two datasets'
#     return pd.concat([df_1, df_2], axis=0, ignore_index=True)



log_fmt = '%(asctime)s - %(name)s - %(levelname)s : %(message)s'
logging.basicConfig(level=logging.INFO, format=log_fmt)
logger = logging.getLogger()

# find .env automagically by walking up directories until it's found, then
# load up the .env entries as environment variables
load_dotenv(find_dotenv())

NEWS_CSV = os.path.join('news.csv')
OUTPUT = os.path.join('news_cleaned.csv')

df_news = prepare_news_csv(NEWS_CSV)

try:
    df_news.to_csv(OUTPUT, sep=';', index=False)
    logger.info('Final dataset prepared and saved to %s' % OUTPUT)
except Exception:
    logger.exception('File could not be daved to disk\n', exc_info=True )
# Out:
# 2021-12-07 07:58:31,336 - root - INFO - Null values in news.csv:
# id               0
# url              0
# Titel            0
# Body             0
# Kategorie     1322
# Datum            0
# Quelle           0
# Fake             0
# Art          40972
# dtype: int64
# 2021-12-07 07:58:31,343 - root - INFO - Cols ['Kategorie', 'Quelle', 'Art'] dropped
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63868 entries, 0 to 63867
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         63868 non-null  int64
#  1   url        63868 non-null  object
#  2   Titel      63868 non-null  object
#  3   Body       63868 non-null  object
#  4   Kategorie  62546 non-null  object
#  5   Datum      63868 non-null  object
#  6   Quelle     63868 non-null  object
#  7   Fake       63868 non-null  int64
#  8   Art        22896 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 4.4+ MB
# 2021-12-07 07:58:31,783 - root - INFO - Percent duplicated Titel and Body:
# False    0.980444
# True     0.019556
# dtype: float64
# 2021-12-07 07:58:32,076 - root - INFO - Duplicates in Titel and Body dropped
# 2021-12-07 07:58:34,189 - root - INFO - Final dataset prepared and saved to news_cleaned.csv

# %% [markdown]
# #### Combine GermanFakeNC_interim.csv with news.csv
# This unifies both datasets and merges them.
# All samples from the GermanFakeNC are treated at "fake", despite some of them having low "over all rating" in regards to fakeness

# %%
# Functions


def prepare_news_csv(filepath):
    """ 
    1.) Drop columns -> Kategorie, Quelle, Art
    2.) Check on duplicate Titel and Body and drop the first entry of duplicates
    3.) Rename Columns in order to match it with the other dataset (GermanFakeNC)
    4.) Add column source_name with news_csv to identifiy the source of a row after merging
    """

    # Read news.csv from disk
    _df = pd.read_csv(filepath)
    logger.debug(_df.info())
    # Drop cols
    logger.info('Null values in news.csv: \n%s' % _df.isnull().sum())
    cols_to_drop = ['Kategorie', 'Quelle', 'Art']
    _df.drop(cols_to_drop, axis=1, inplace=True)
    logger.info('Cols %s dropped' % cols_to_drop)


    # Drop duplicates
    logger.info('Percent duplicated Titel and Body: \n%s' % str(
        _df.duplicated(subset=['Titel', 'Body']).value_counts(normalize=True)))
    _df.drop_duplicates(subset=['Titel', 'Body'], inplace=True)
    logger.info('Duplicates in Titel and Body dropped')

    # Rename Cols
    new_cols = {'id': 'src_id',
                'Titel': 'title',
                'Body': 'text',
                'Datum': 'date',
                'Fake': 'fake'}
    _df.rename(columns=new_cols, inplace=True)
    logger.info('Cols renamed')

    # Add col source_name
    _df['src_name'] = 'news_csv'

    return _df


def prepare_germanfake(filepath):
    """ 
    1.) Drop columns -> [False_Statement_1_Location,
                         False_Statement_1_Index,
                         False_Statement_2_Location,
                         False_Statement_2_Index,
                         False_Statement_3_Location,
                         False_Statement_3_Index,
                         Ratio_of_Fake_Statements,
                         Overall_Rating]
        We treat all entries as fakenews, eventhough there are some instances
        that have a very low fake overall ratings!!
    2.) Make index source_id
    3.) Check on duplicate titel and text and drop the first entry of duplicates
    4.) Drop rows where titel or text is null 
    5.) Fill Dates for missing values -> From the URL we can see that the Date could
        be 2017/12 
    6.) Rename Columns in order to match it with the other dataset (news.csv)
    7.) Add label col 'fake' = 1 -> all 1; col 'src_name' = 'GermanFakeNC'
    """

    # Read news.csv from disk
    _df = pd.read_csv(filepath)
    logger.debug(_df.info())
    # Drop cols
    logger.info('Null values in GermanFakeNC_interim.csv: \n%s' % _df.isnull().sum())
    cols_to_drop = ['False_Statement_1_Location',
                    'False_Statement_1_Index',
                    'False_Statement_2_Location',
                    'False_Statement_2_Index',
                    'False_Statement_3_Location',
                    'False_Statement_3_Index',
                    'Ratio_of_Fake_Statements',
                    'Overall_Rating']
    _df.drop(cols_to_drop, axis=1, inplace=True)
    logger.info('Cols %s dropped' % cols_to_drop)

    # Set source_id
    _df.reset_index(inplace=True)
    logger.info('Index reset')
    
    # Drop duplicates
    logger.info('Percent duplicated titel and text: \n%s' % str(
        _df.duplicated(subset=['titel', 'text']).value_counts(normalize=True)))
    _df.drop_duplicates(subset=['titel', 'text'], inplace=True)
    logger.info('Duplicates in titel and text dropped')

    # Drop rows where titel or text is null
    _df.dropna(subset=['titel', 'text'], inplace=True)
    logger.info('Null rows for titel and text dropped')

    # Fill the missing dates
    _df['Date'].fillna(pd.to_datetime('01/12/2017'), inplace=True)

    # Rename Cols
    new_cols = {'index': 'src_id',
                'titel': 'title',
                'Date': 'date',
                'URL': 'url'}
    _df.rename(columns=new_cols, inplace=True)
    logger.info('Cols renamed')

    # Add col source_name
    _df['fake'] = 1
    _df['src_name'] = 'GermanFakeNC'

    return _df


def merge_datasets(df_1, df_2):
    logger.info('Shape: %s\n Columns: %s' % (df_1.shape, df_1.columns))
    logger.info('Shape: %s\n Columns: %s' % (df_2.shape, df_2.columns))
    # Check col names
    sym_diff = set(df_1).symmetric_difference(set(df_2))
    assert len(sym_diff) == 0 , 'Differences in colnames of the two datasets'
    return pd.concat([df_1, df_2], axis=0, ignore_index=True)



log_fmt = '%(asctime)s - %(name)s - %(levelname)s : %(message)s'
logging.basicConfig(level=logging.INFO, format=log_fmt)
logger = logging.getLogger()

# find .env automagically by walking up directories until it's found, then
# load up the .env entries as environment variables
load_dotenv(find_dotenv())

NEWS_CSV = os.path.join('news.csv')
GERMAN_FAKE_NC = os.path.join('GermanFakeNC_interim.csv')
OUTPUT = os.path.join('datasets_merged.csv')

df_news = prepare_news_csv(NEWS_CSV)
df_gfn = prepare_germanfake(GERMAN_FAKE_NC)
df_merged = merge_datasets(df_news, df_gfn)

try:
    df_merged.to_csv(OUTPUT, sep=';', index=False)
    logger.info('Final dataset prepared and saved to %s' % OUTPUT)
except Exception:
    logger.exception('File could not be daved to disk\n', exc_info=True )
# Out:
# 2021-12-07 07:46:55,076 - root - INFO - Null values in news.csv:
# id               0
# url              0
# Titel            0
# Body             0
# Kategorie     1322
# Datum            0
# Quelle           0
# Fake             0
# Art          40972
# dtype: int64
# 2021-12-07 07:46:55,076 - root - INFO - Cols ['Kategorie', 'Quelle', 'Art'] dropped
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63868 entries, 0 to 63867
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         63868 non-null  int64
#  1   url        63868 non-null  object
#  2   Titel      63868 non-null  object
#  3   Body       63868 non-null  object
#  4   Kategorie  62546 non-null  object
#  5   Datum      63868 non-null  object
#  6   Quelle     63868 non-null  object
#  7   Fake       63868 non-null  int64
#  8   Art        22896 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 4.4+ MB
# 2021-12-07 07:46:55,527 - root - INFO - Percent duplicated Titel and Body:
# False    0.980444
# True     0.019556
# dtype: float64
# 2021-12-07 07:46:55,834 - root - INFO - Duplicates in Titel and Body dropped
# 2021-12-07 07:46:55,835 - root - INFO - Cols renamed
# 2021-12-07 07:46:55,855 - root - INFO - Null values in GermanFakeNC_interim.csv:
# Date                           17
# URL                             0
# False_Statement_1_Location      0
# False_Statement_1_Index        14
# False_Statement_2_Location     79
# False_Statement_2_Index        83
# False_Statement_3_Location    146
# False_Statement_3_Index       148
# Ratio_of_Fake_Statements        0
# Overall_Rating                  0
# titel                           0
# text                            3
# dtype: int64
# 2021-12-07 07:46:55,856 - root - INFO - Cols ['False_Statement_1_Location', 'False_Statement_1_Index', 'False_Statement_2_Location', 'False_Statement_2_Index', 'False_Statement_3_Location', 'False_Statement_3_Index', 'Ratio_of_Fake_Statements', 'Overall_Rating'] dropped
# 2021-12-07 07:46:55,857 - root - INFO - Index reset
# 2021-12-07 07:46:55,859 - root - INFO - Percent duplicated titel and text:
# False    0.943966
# True     0.056034
# dtype: float64
# 2021-12-07 07:46:55,861 - root - INFO - Duplicates in titel and text dropped
# 2021-12-07 07:46:55,862 - root - INFO - Null rows for titel and text dropped
# 2021-12-07 07:46:55,863 - root - INFO - Cols renamed
# 2021-12-07 07:46:55,864 - root - INFO - Shape: (62619, 7)
#  Columns: Index(['src_id', 'url', 'title', 'text', 'date', 'fake', 'src_name'], dtype='object')
# 2021-12-07 07:46:55,865 - root - INFO - Shape: (217, 7)
#  Columns: Index(['src_id', 'date', 'url', 'title', 'text', 'fake', 'src_name'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232 entries, 0 to 231
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        215 non-null    object
#  1   URL                         232 non-null    object
#  2   False_Statement_1_Location  232 non-null    object
#  3   False_Statement_1_Index     218 non-null    object
#  4   False_Statement_2_Location  153 non-null    object
#  5   False_Statement_2_Index     149 non-null    object
#  6   False_Statement_3_Location  86 non-null     object
#  7   False_Statement_3_Index     84 non-null     object
#  8   Ratio_of_Fake_Statements    232 non-null    int64
#  9   Overall_Rating              232 non-null    float64
#  10  titel                       232 non-null    object
#  11  text                        229 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 21.9+ KB
# 2021-12-07 07:46:58,072 - root - INFO - Final dataset prepared and saved to datasets_merged.csv
