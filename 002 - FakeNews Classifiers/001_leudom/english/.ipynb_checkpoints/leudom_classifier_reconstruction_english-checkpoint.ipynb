# %% [markdown]
# ##### A stemmed CountVectorizer

# %%
import copy
from sklearn.feature_extraction.text import CountVectorizer

# Overide CountVectorizer to integrate stemming
class StemmedCountVectorizer(CountVectorizer):
    def __init__(self, stemmer, **kwargs):
        super(StemmedCountVectorizer, self).__init__(**kwargs)
        self.stemmer = stemmer

    def build_analyzer(self):
        analyzer = super(StemmedCountVectorizer, self).build_analyzer()
        return lambda doc: (self.stemmer.stem(w) for w in analyzer(doc))

    def get_params(self, deep=True):
        params = super().get_params(deep=deep)
        cp = copy.copy(self)
        cp.__class__ = CountVectorizer
        params.update(CountVectorizer.get_params(cp, deep))
        return params

# %%
# -*- coding: utf-8 -*-

"""FakeNewsClassifier Trainer

This script conduct the following steps (overview):

1. Load the processes dataset from {PROJECT_DIR}/data/processed as dataframe
2. Concatenate title and text in one column
3. Split the dataset into train and test

4. Set up a sklearn pipeline with preprocessor and classifier for the combined column (title+text)
   and perform hyperparam search 
5. Extract best score and best_params for and log it
6. Predict on testset and log the score

7. Pickle best pipe to disk (final model)

"""
# %%
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()

import os
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import VotingClassifier
from catboost import CatBoostClassifier, Pool
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, f1_score, recall_score, precision_score
from dotenv import find_dotenv, load_dotenv
import nltk
from nltk.stem.snowball import GermanStemmer
from sklearn.feature_extraction.text import CountVectorizer
import dagshub
from joblib import dump


load_dotenv(find_dotenv())
#%% Load and split dataset
# INPUTFILE = os.path.join(os.getenv('PROJECT_DIR'), 'data', 'processed', 'fake_news_processed.csv')
INPUTFILE = os.path.join('data', 'BuzzFeed-Webis.csv')
df = pd.read_csv(INPUTFILE, sep=',', keep_default_na=False)
logger.info('Distribution of fake news in entire dataset: \n%s' % df.veracity.value_counts(normalize=True))


# # Convert NaN titles to an empty string for concatination of title and text
# df[['title']] = df[['title']].fillna('')

print(df['title'].isnull().values.any())
print(df['mainText'].isnull().values.any())
print(df['veracity'].isnull().values.any())

X = df['title']+' '+df['mainText']
y = df['veracity']



X_train, X_test, y_train, y_test = train_test_split(X, y,
                    test_size=0.2,
                    stratify=y,
                    random_state=42)

# Download and init stopwordlist
nltk.download('stopwords')
STOPWORD_LIST = nltk.corpus.stopwords.words('english')

#print(X_train[100])

# %% Test with CountVectorizer
"""
count_vec = StemmedCountVectorizer(token_pattern=r'\b[a-zA-Z]{2,}\b',
                                max_features=100,
                                stop_words=STOPWORD_LIST,
                                lowercase=True,
                                stemmer=GermanStemmer(ignore_stopwords=True),
                                ngram_range=(2,2)
                        )

word_counts = count_vec.fit_transform(X_train).todense()

df_body = pd.DataFrame(word_counts, columns=count_vec.get_feature_names())
df_body_trans = pd.DataFrame(df_body.T.sum(axis=1), columns=['count'])
df_body_trans.sort_values(by='count', ascending=False).head(20)

"""

#%% Define param grid for tuning
param_grid = {'vectorizer__max_features':[500],
        'clf__n_estimators': [400],
        'clf__learning_rate': [0.9],
        'clf__max_depth': [5]}

# Constants for training
# MODEL_PATH = os.getenv('MODEL_PATH')
MODEL_PATH = 'model.pkl'
CV_SCORING = 'f1'
CV_FOLDS = 3

# %%
with dagshub.dagshub_logger() as dagslog:
        # Pipeline
        pipe = Pipeline(steps=[
        ('vectorizer', StemmedCountVectorizer(stop_words=STOPWORD_LIST,
                                   token_pattern=r'\b[a-zA-Z]{2,}\b',
                                   stemmer=GermanStemmer(ignore_stopwords=True),
                                   lowercase=True)),
        ('clf', CatBoostClassifier(allow_writing_files=False))
        ])
        
        # pipe_title_tune.get_params().keys()
        logger.info('Start training estimator pipeline')
        cv_grid = GridSearchCV(pipe, param_grid, scoring=CV_SCORING, cv=CV_FOLDS, n_jobs=2)
        cv_grid.fit(X_train, y_train)
        #cv_grid.best_estimator_.named_steps['clf'].get_all_params()

        # Log and assign best score and params to var
        logger.info('Best params from GridSearchCV: %s' % str(cv_grid.best_params_))
        dagslog.log_hyperparams({'model_path': MODEL_PATH})
        dagslog.log_hyperparams({'cv_score': CV_SCORING})
        dagslog.log_hyperparams({'best_cv_params': cv_grid.best_params_})

        logger.info('Best %s from GridSearchCV: %s' % (CV_SCORING, str(cv_grid.best_score_)))
        dagslog.log_metrics({'best_cv_score': cv_grid.best_score_})
        
        # Predict on testdata
        y_pred = cv_grid.best_estimator_.predict(X_test)
        logger.info('f1_score for testdata: %s' % str(f1_score(y_test, y_pred)))
        dagslog.log_metrics({'f1_score_on_testdata': f1_score(y_test, y_pred)})
        logger.info('precision_score for testdata: %s' % str(precision_score(y_test, y_pred)))
        dagslog.log_metrics({'precision_score_on_testdata': precision_score(y_test, y_pred)})
        logger.info('recall_score for testdata: %s' % str(recall_score(y_test, y_pred)))
        dagslog.log_metrics({'recall_score_on_testdata': recall_score(y_test, y_pred)})
        logger.info('Classification report for testdata: \n%s' % classification_report(y_test, y_pred))
        logger.info('Confusion matrix for testdata: \n%s' % confusion_matrix(y_test, y_pred))

        # Dump model to disk
        dump(cv_grid.best_estimator_, MODEL_PATH)
# Out:
# INFO:root:Distribution of fake news in entire dataset:
# 0    0.812296
# 1    0.187704
# Name: veracity, dtype: float64
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\fjun\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# INFO:root:Start training estimator pipeline
# False
# False
# False
# 0:	learn: 0.4838447	total: 23.4ms	remaining: 9.34s
# 1:	learn: 0.3818877	total: 26.3ms	remaining: 5.24s
# 2:	learn: 0.3493742	total: 29.1ms	remaining: 3.84s
# 3:	learn: 0.3313220	total: 31.8ms	remaining: 3.15s
# 4:	learn: 0.3141586	total: 34.3ms	remaining: 2.71s
# 5:	learn: 0.3086892	total: 36.8ms	remaining: 2.42s
# 6:	learn: 0.3049385	total: 39.4ms	remaining: 2.21s
# 7:	learn: 0.3011920	total: 41.9ms	remaining: 2.05s
# 8:	learn: 0.2847506	total: 44.7ms	remaining: 1.94s
# 9:	learn: 0.2582713	total: 47.2ms	remaining: 1.84s
# 10:	learn: 0.2368846	total: 49.9ms	remaining: 1.76s
# 11:	learn: 0.2315861	total: 52.5ms	remaining: 1.7s
# 12:	learn: 0.2292199	total: 55.2ms	remaining: 1.64s
# 13:	learn: 0.2121081	total: 57.8ms	remaining: 1.59s
# 14:	learn: 0.1889032	total: 60.4ms	remaining: 1.55s
# 15:	learn: 0.1785348	total: 63ms	remaining: 1.51s
# 16:	learn: 0.1759440	total: 65.7ms	remaining: 1.48s
# 17:	learn: 0.1661175	total: 68.3ms	remaining: 1.45s
# 18:	learn: 0.1620314	total: 71ms	remaining: 1.42s
# 19:	learn: 0.1585606	total: 73.6ms	remaining: 1.4s
# 20:	learn: 0.1560630	total: 76.3ms	remaining: 1.38s
# 21:	learn: 0.1507083	total: 78.8ms	remaining: 1.35s
# 22:	learn: 0.1349876	total: 81.3ms	remaining: 1.33s
# 23:	learn: 0.1251101	total: 83.8ms	remaining: 1.31s
# 24:	learn: 0.1147788	total: 86.4ms	remaining: 1.29s
# 25:	learn: 0.1094969	total: 88.9ms	remaining: 1.28s
# 26:	learn: 0.1081930	total: 91.5ms	remaining: 1.26s
# 27:	learn: 0.1067569	total: 94.2ms	remaining: 1.25s
# 28:	learn: 0.1047908	total: 96.8ms	remaining: 1.24s
# 29:	learn: 0.0992092	total: 99.3ms	remaining: 1.22s
# 30:	learn: 0.0962987	total: 102ms	remaining: 1.21s
# 31:	learn: 0.0948500	total: 104ms	remaining: 1.2s
# 32:	learn: 0.0941321	total: 107ms	remaining: 1.19s
# 33:	learn: 0.0919991	total: 109ms	remaining: 1.17s
# 34:	learn: 0.0857232	total: 112ms	remaining: 1.16s
# 35:	learn: 0.0828369	total: 114ms	remaining: 1.15s
# 36:	learn: 0.0820737	total: 117ms	remaining: 1.14s
# 37:	learn: 0.0761010	total: 119ms	remaining: 1.13s
# 38:	learn: 0.0741190	total: 121ms	remaining: 1.12s
# 39:	learn: 0.0699994	total: 124ms	remaining: 1.12s
# 40:	learn: 0.0689066	total: 127ms	remaining: 1.11s
# 41:	learn: 0.0683568	total: 129ms	remaining: 1.1s
# 42:	learn: 0.0679775	total: 132ms	remaining: 1.09s
# 43:	learn: 0.0661422	total: 134ms	remaining: 1.09s
# 44:	learn: 0.0639861	total: 137ms	remaining: 1.08s
# 45:	learn: 0.0611119	total: 140ms	remaining: 1.07s
# 46:	learn: 0.0604080	total: 142ms	remaining: 1.07s
# 47:	learn: 0.0596938	total: 145ms	remaining: 1.06s
# 48:	learn: 0.0546326	total: 147ms	remaining: 1.05s
# 49:	learn: 0.0517723	total: 150ms	remaining: 1.05s
# 50:	learn: 0.0494060	total: 161ms	remaining: 1.1s
# 51:	learn: 0.0490070	total: 164ms	remaining: 1.09s
# 52:	learn: 0.0487067	total: 166ms	remaining: 1.09s
# 53:	learn: 0.0475401	total: 177ms	remaining: 1.13s
# 54:	learn: 0.0464526	total: 179ms	remaining: 1.12s
# 55:	learn: 0.0449024	total: 182ms	remaining: 1.11s
# 56:	learn: 0.0427220	total: 184ms	remaining: 1.11s
# 57:	learn: 0.0412806	total: 187ms	remaining: 1.1s
# 58:	learn: 0.0386189	total: 189ms	remaining: 1.09s
# 59:	learn: 0.0365456	total: 192ms	remaining: 1.09s
# 60:	learn: 0.0363039	total: 194ms	remaining: 1.08s
# 61:	learn: 0.0359569	total: 197ms	remaining: 1.07s
# 62:	learn: 0.0345683	total: 200ms	remaining: 1.07s
# 63:	learn: 0.0335445	total: 202ms	remaining: 1.06s
# 64:	learn: 0.0314290	total: 205ms	remaining: 1.05s
# 65:	learn: 0.0300205	total: 208ms	remaining: 1.05s
# 66:	learn: 0.0290333	total: 210ms	remaining: 1.04s
# 67:	learn: 0.0284606	total: 213ms	remaining: 1.04s
# 68:	learn: 0.0280795	total: 215ms	remaining: 1.03s
# 69:	learn: 0.0279681	total: 218ms	remaining: 1.03s
# 70:	learn: 0.0278162	total: 220ms	remaining: 1.02s
# 71:	learn: 0.0276953	total: 223ms	remaining: 1.01s
# 72:	learn: 0.0275907	total: 226ms	remaining: 1.01s
# 73:	learn: 0.0274994	total: 228ms	remaining: 1s
# 74:	learn: 0.0272883	total: 231ms	remaining: 1000ms
# 75:	learn: 0.0271789	total: 233ms	remaining: 995ms
# 76:	learn: 0.0260413	total: 236ms	remaining: 989ms
# 77:	learn: 0.0247945	total: 238ms	remaining: 984ms
# 78:	learn: 0.0232001	total: 241ms	remaining: 979ms
# 79:	learn: 0.0224654	total: 244ms	remaining: 974ms
# 80:	learn: 0.0219721	total: 246ms	remaining: 969ms
# 81:	learn: 0.0206952	total: 249ms	remaining: 964ms
# 82:	learn: 0.0203595	total: 251ms	remaining: 959ms
# 83:	learn: 0.0202812	total: 254ms	remaining: 954ms
# 84:	learn: 0.0202209	total: 257ms	remaining: 951ms
# 85:	learn: 0.0201620	total: 259ms	remaining: 946ms
# 86:	learn: 0.0195013	total: 262ms	remaining: 942ms
# 87:	learn: 0.0188890	total: 264ms	remaining: 937ms
# 88:	learn: 0.0188163	total: 267ms	remaining: 932ms
# 89:	learn: 0.0187452	total: 269ms	remaining: 927ms
# 90:	learn: 0.0179221	total: 272ms	remaining: 923ms
# 91:	learn: 0.0170915	total: 275ms	remaining: 919ms
# 92:	learn: 0.0170135	total: 277ms	remaining: 915ms
# 93:	learn: 0.0169666	total: 280ms	remaining: 911ms
# 94:	learn: 0.0165847	total: 283ms	remaining: 907ms
# 95:	learn: 0.0160989	total: 285ms	remaining: 903ms
# 96:	learn: 0.0160515	total: 288ms	remaining: 899ms
# 97:	learn: 0.0157697	total: 291ms	remaining: 895ms
# 98:	learn: 0.0157170	total: 293ms	remaining: 891ms
# 99:	learn: 0.0156846	total: 295ms	remaining: 886ms
# 100:	learn: 0.0156488	total: 298ms	remaining: 882ms
# 101:	learn: 0.0155722	total: 301ms	remaining: 878ms
# 102:	learn: 0.0152542	total: 303ms	remaining: 874ms
# 103:	learn: 0.0145757	total: 306ms	remaining: 870ms
# 104:	learn: 0.0145340	total: 308ms	remaining: 866ms
# 105:	learn: 0.0144914	total: 311ms	remaining: 862ms
# 106:	learn: 0.0144623	total: 313ms	remaining: 858ms
# 107:	learn: 0.0144110	total: 316ms	remaining: 854ms
# 108:	learn: 0.0143844	total: 318ms	remaining: 850ms
# 109:	learn: 0.0143456	total: 321ms	remaining: 846ms
# 110:	learn: 0.0141586	total: 323ms	remaining: 842ms
# 111:	learn: 0.0141088	total: 326ms	remaining: 838ms
# 112:	learn: 0.0135892	total: 328ms	remaining: 834ms
# 113:	learn: 0.0133089	total: 331ms	remaining: 831ms
# 114:	learn: 0.0132738	total: 334ms	remaining: 827ms
# 115:	learn: 0.0132133	total: 336ms	remaining: 823ms
# 116:	learn: 0.0127352	total: 346ms	remaining: 837ms
# 117:	learn: 0.0125053	total: 348ms	remaining: 833ms
# 118:	learn: 0.0118652	total: 351ms	remaining: 829ms
# 119:	learn: 0.0117864	total: 353ms	remaining: 825ms
# 120:	learn: 0.0117509	total: 362ms	remaining: 834ms
# 121:	learn: 0.0117235	total: 364ms	remaining: 830ms
# 122:	learn: 0.0116752	total: 367ms	remaining: 825ms
# 123:	learn: 0.0112688	total: 369ms	remaining: 822ms
# 124:	learn: 0.0112544	total: 372ms	remaining: 818ms
# 125:	learn: 0.0112241	total: 374ms	remaining: 814ms
# 126:	learn: 0.0110662	total: 377ms	remaining: 810ms
# 127:	learn: 0.0106125	total: 379ms	remaining: 806ms
# 128:	learn: 0.0103686	total: 382ms	remaining: 802ms
# 129:	learn: 0.0101945	total: 384ms	remaining: 798ms
# 130:	learn: 0.0101602	total: 387ms	remaining: 795ms
# 131:	learn: 0.0101324	total: 390ms	remaining: 791ms
# 132:	learn: 0.0101174	total: 392ms	remaining: 788ms
# 133:	learn: 0.0098752	total: 395ms	remaining: 784ms
# 134:	learn: 0.0095043	total: 397ms	remaining: 780ms
# 135:	learn: 0.0094763	total: 400ms	remaining: 776ms
# 136:	learn: 0.0094535	total: 403ms	remaining: 773ms
# 137:	learn: 0.0094365	total: 405ms	remaining: 769ms
# 138:	learn: 0.0093820	total: 408ms	remaining: 766ms
# 139:	learn: 0.0091825	total: 411ms	remaining: 763ms
# 140:	learn: 0.0087732	total: 414ms	remaining: 760ms
# 141:	learn: 0.0087620	total: 416ms	remaining: 756ms
# 142:	learn: 0.0087503	total: 419ms	remaining: 752ms
# 143:	learn: 0.0087201	total: 421ms	remaining: 749ms
# 144:	learn: 0.0087047	total: 424ms	remaining: 745ms
# 145:	learn: 0.0086193	total: 426ms	remaining: 742ms
# 146:	learn: 0.0084355	total: 429ms	remaining: 738ms
# 147:	learn: 0.0082129	total: 431ms	remaining: 734ms
# 148:	learn: 0.0082000	total: 434ms	remaining: 731ms
# 149:	learn: 0.0081766	total: 436ms	remaining: 727ms
# 150:	learn: 0.0081615	total: 439ms	remaining: 724ms
# 151:	learn: 0.0080977	total: 441ms	remaining: 720ms
# 152:	learn: 0.0078487	total: 444ms	remaining: 717ms
# 153:	learn: 0.0078157	total: 446ms	remaining: 713ms
# 154:	learn: 0.0077673	total: 449ms	remaining: 710ms
# 155:	learn: 0.0077306	total: 451ms	remaining: 706ms
# 156:	learn: 0.0076831	total: 454ms	remaining: 703ms
# 157:	learn: 0.0075812	total: 456ms	remaining: 699ms
# 158:	learn: 0.0075659	total: 459ms	remaining: 696ms
# 159:	learn: 0.0075531	total: 462ms	remaining: 693ms
# 160:	learn: 0.0075340	total: 464ms	remaining: 689ms
# 161:	learn: 0.0074755	total: 467ms	remaining: 686ms
# 162:	learn: 0.0072275	total: 469ms	remaining: 682ms
# 163:	learn: 0.0071848	total: 472ms	remaining: 679ms
# 164:	learn: 0.0071845	total: 475ms	remaining: 676ms
# 165:	learn: 0.0071700	total: 477ms	remaining: 673ms
# 166:	learn: 0.0069649	total: 480ms	remaining: 669ms
# 167:	learn: 0.0067719	total: 482ms	remaining: 666ms
# 168:	learn: 0.0067060	total: 485ms	remaining: 663ms
# 169:	learn: 0.0067060	total: 487ms	remaining: 659ms
# 170:	learn: 0.0067058	total: 489ms	remaining: 655ms
# 171:	learn: 0.0066931	total: 498ms	remaining: 660ms
# 172:	learn: 0.0066930	total: 500ms	remaining: 657ms
# 173:	learn: 0.0066929	total: 503ms	remaining: 653ms
# 174:	learn: 0.0066857	total: 505ms	remaining: 650ms
# 175:	learn: 0.0065582	total: 508ms	remaining: 646ms
# 176:	learn: 0.0065509	total: 510ms	remaining: 643ms
# 177:	learn: 0.0065458	total: 513ms	remaining: 639ms
# 178:	learn: 0.0065084	total: 515ms	remaining: 636ms
# 179:	learn: 0.0065017	total: 518ms	remaining: 633ms
# 180:	learn: 0.0064929	total: 527ms	remaining: 637ms
# 181:	learn: 0.0064658	total: 529ms	remaining: 634ms
# 182:	learn: 0.0062999	total: 532ms	remaining: 631ms
# 183:	learn: 0.0060733	total: 534ms	remaining: 627ms
# 184:	learn: 0.0059894	total: 537ms	remaining: 624ms
# 185:	learn: 0.0059290	total: 539ms	remaining: 620ms
# 186:	learn: 0.0059248	total: 542ms	remaining: 617ms
# 187:	learn: 0.0059245	total: 544ms	remaining: 613ms
# 188:	learn: 0.0059159	total: 547ms	remaining: 610ms
# 189:	learn: 0.0059100	total: 549ms	remaining: 607ms
# 190:	learn: 0.0059030	total: 552ms	remaining: 604ms
# 191:	learn: 0.0059029	total: 554ms	remaining: 601ms
# 192:	learn: 0.0059028	total: 557ms	remaining: 597ms
# 193:	learn: 0.0058813	total: 559ms	remaining: 594ms
# 194:	learn: 0.0058775	total: 562ms	remaining: 591ms
# 195:	learn: 0.0058555	total: 564ms	remaining: 587ms
# 196:	learn: 0.0058530	total: 567ms	remaining: 584ms
# 197:	learn: 0.0058141	total: 569ms	remaining: 581ms
# 198:	learn: 0.0057422	total: 572ms	remaining: 578ms
# 199:	learn: 0.0056579	total: 574ms	remaining: 574ms
# 200:	learn: 0.0056444	total: 577ms	remaining: 571ms
# 201:	learn: 0.0056370	total: 579ms	remaining: 568ms
# 202:	learn: 0.0056306	total: 582ms	remaining: 565ms
# 203:	learn: 0.0055331	total: 584ms	remaining: 562ms
# 204:	learn: 0.0055330	total: 587ms	remaining: 558ms
# 205:	learn: 0.0055329	total: 589ms	remaining: 555ms
# 206:	learn: 0.0055329	total: 592ms	remaining: 552ms
# 207:	learn: 0.0055325	total: 594ms	remaining: 548ms
# 208:	learn: 0.0054482	total: 597ms	remaining: 545ms
# 209:	learn: 0.0053653	total: 599ms	remaining: 542ms
# 210:	learn: 0.0052259	total: 602ms	remaining: 539ms
# 211:	learn: 0.0052194	total: 605ms	remaining: 536ms
# 212:	learn: 0.0052013	total: 607ms	remaining: 533ms
# 213:	learn: 0.0051994	total: 610ms	remaining: 530ms
# 214:	learn: 0.0051993	total: 612ms	remaining: 527ms
# 215:	learn: 0.0051993	total: 615ms	remaining: 524ms
# 216:	learn: 0.0051981	total: 618ms	remaining: 521ms
# 217:	learn: 0.0051492	total: 620ms	remaining: 518ms
# 218:	learn: 0.0049739	total: 623ms	remaining: 515ms
# 219:	learn: 0.0048800	total: 625ms	remaining: 512ms
# 220:	learn: 0.0048798	total: 628ms	remaining: 508ms
# 221:	learn: 0.0048744	total: 630ms	remaining: 505ms
# 222:	learn: 0.0048744	total: 633ms	remaining: 502ms
# 223:	learn: 0.0048729	total: 635ms	remaining: 499ms
# 224:	learn: 0.0048683	total: 638ms	remaining: 496ms
# 225:	learn: 0.0048683	total: 640ms	remaining: 493ms
# 226:	learn: 0.0048679	total: 643ms	remaining: 490ms
# 227:	learn: 0.0048661	total: 645ms	remaining: 487ms
# 228:	learn: 0.0048658	total: 662ms	remaining: 495ms
# 229:	learn: 0.0048658	total: 665ms	remaining: 491ms
# 230:	learn: 0.0048634	total: 667ms	remaining: 488ms
# 231:	learn: 0.0048380	total: 670ms	remaining: 485ms
# 232:	learn: 0.0048379	total: 672ms	remaining: 482ms
# 233:	learn: 0.0047308	total: 675ms	remaining: 479ms
# 234:	learn: 0.0047305	total: 677ms	remaining: 476ms
# 235:	learn: 0.0046987	total: 680ms	remaining: 473ms
# 236:	learn: 0.0046987	total: 683ms	remaining: 469ms
# 237:	learn: 0.0046280	total: 685ms	remaining: 466ms
# 238:	learn: 0.0046279	total: 687ms	remaining: 463ms
# 239:	learn: 0.0046127	total: 690ms	remaining: 460ms
# 240:	learn: 0.0046126	total: 692ms	remaining: 457ms
# 241:	learn: 0.0046063	total: 695ms	remaining: 454ms
# 242:	learn: 0.0046063	total: 697ms	remaining: 450ms
# 243:	learn: 0.0046062	total: 700ms	remaining: 447ms
# 244:	learn: 0.0046060	total: 702ms	remaining: 444ms
# 245:	learn: 0.0046006	total: 705ms	remaining: 441ms
# 246:	learn: 0.0045995	total: 707ms	remaining: 438ms
# 247:	learn: 0.0045973	total: 710ms	remaining: 435ms
# 248:	learn: 0.0045656	total: 712ms	remaining: 432ms
# 249:	learn: 0.0044865	total: 715ms	remaining: 429ms
# 250:	learn: 0.0044864	total: 717ms	remaining: 426ms
# 251:	learn: 0.0044864	total: 721ms	remaining: 424ms
# 252:	learn: 0.0044619	total: 724ms	remaining: 421ms
# 253:	learn: 0.0044595	total: 726ms	remaining: 418ms
# 254:	learn: 0.0044574	total: 729ms	remaining: 414ms
# 255:	learn: 0.0044574	total: 731ms	remaining: 411ms
# 256:	learn: 0.0044545	total: 734ms	remaining: 408ms
# 257:	learn: 0.0044539	total: 736ms	remaining: 405ms
# 258:	learn: 0.0044537	total: 739ms	remaining: 402ms
# 259:	learn: 0.0044532	total: 741ms	remaining: 399ms
# 260:	learn: 0.0044532	total: 744ms	remaining: 396ms
# 261:	learn: 0.0044532	total: 752ms	remaining: 396ms
# 262:	learn: 0.0044483	total: 754ms	remaining: 393ms
# 263:	learn: 0.0044483	total: 757ms	remaining: 390ms
# 264:	learn: 0.0044483	total: 759ms	remaining: 387ms
# 265:	learn: 0.0044482	total: 761ms	remaining: 384ms
# 266:	learn: 0.0043008	total: 764ms	remaining: 380ms
# 267:	learn: 0.0043009	total: 766ms	remaining: 377ms
# 268:	learn: 0.0042640	total: 783ms	remaining: 382ms
# 269:	learn: 0.0042073	total: 786ms	remaining: 378ms
# 270:	learn: 0.0042046	total: 789ms	remaining: 375ms
# 271:	learn: 0.0042012	total: 791ms	remaining: 372ms
# 272:	learn: 0.0042011	total: 793ms	remaining: 369ms
# 273:	learn: 0.0041994	total: 796ms	remaining: 366ms
# 274:	learn: 0.0041994	total: 798ms	remaining: 363ms
# 275:	learn: 0.0041993	total: 801ms	remaining: 360ms
# 276:	learn: 0.0041993	total: 804ms	remaining: 357ms
# 277:	learn: 0.0041981	total: 806ms	remaining: 354ms
# 278:	learn: 0.0041980	total: 808ms	remaining: 351ms
# 279:	learn: 0.0041949	total: 811ms	remaining: 347ms
# 280:	learn: 0.0041246	total: 830ms	remaining: 352ms
# 281:	learn: 0.0040240	total: 833ms	remaining: 348ms
# 282:	learn: 0.0039798	total: 835ms	remaining: 345ms
# 283:	learn: 0.0038954	total: 838ms	remaining: 342ms
# 284:	learn: 0.0038306	total: 840ms	remaining: 339ms
# 285:	learn: 0.0037582	total: 843ms	remaining: 336ms
# 286:	learn: 0.0037582	total: 845ms	remaining: 333ms
# 287:	learn: 0.0037582	total: 847ms	remaining: 330ms
# 288:	learn: 0.0037535	total: 850ms	remaining: 327ms
# 289:	learn: 0.0037534	total: 853ms	remaining: 323ms
# 290:	learn: 0.0037533	total: 855ms	remaining: 320ms
# 291:	learn: 0.0037533	total: 858ms	remaining: 317ms
# 292:	learn: 0.0037532	total: 860ms	remaining: 314ms
# 293:	learn: 0.0037526	total: 862ms	remaining: 311ms
# 294:	learn: 0.0037444	total: 865ms	remaining: 308ms
# 295:	learn: 0.0037408	total: 867ms	remaining: 305ms
# 296:	learn: 0.0037142	total: 870ms	remaining: 302ms
# 297:	learn: 0.0037141	total: 872ms	remaining: 299ms
# 298:	learn: 0.0037140	total: 875ms	remaining: 295ms
# 299:	learn: 0.0036904	total: 877ms	remaining: 292ms
# 300:	learn: 0.0036903	total: 880ms	remaining: 289ms
# 301:	learn: 0.0036902	total: 882ms	remaining: 286ms
# 302:	learn: 0.0036873	total: 885ms	remaining: 283ms
# 303:	learn: 0.0036872	total: 887ms	remaining: 280ms
# 304:	learn: 0.0036873	total: 890ms	remaining: 277ms
# 305:	learn: 0.0036873	total: 892ms	remaining: 274ms
# 306:	learn: 0.0036869	total: 894ms	remaining: 271ms
# 307:	learn: 0.0036870	total: 897ms	remaining: 268ms
# 308:	learn: 0.0036869	total: 899ms	remaining: 265ms
# 309:	learn: 0.0036868	total: 902ms	remaining: 262ms
# 310:	learn: 0.0036867	total: 904ms	remaining: 259ms
# 311:	learn: 0.0036866	total: 907ms	remaining: 256ms
# 312:	learn: 0.0036864	total: 909ms	remaining: 253ms
# 313:	learn: 0.0036838	total: 911ms	remaining: 250ms
# 314:	learn: 0.0035897	total: 914ms	remaining: 247ms
# 315:	learn: 0.0035797	total: 916ms	remaining: 244ms
# 316:	learn: 0.0035797	total: 919ms	remaining: 241ms
# 317:	learn: 0.0035797	total: 921ms	remaining: 238ms
# 318:	learn: 0.0035797	total: 924ms	remaining: 235ms
# 319:	learn: 0.0035037	total: 926ms	remaining: 232ms
# 320:	learn: 0.0034900	total: 929ms	remaining: 229ms
# 321:	learn: 0.0034900	total: 931ms	remaining: 226ms
# 322:	learn: 0.0034897	total: 934ms	remaining: 223ms
# 323:	learn: 0.0034897	total: 936ms	remaining: 220ms
# 324:	learn: 0.0034897	total: 938ms	remaining: 217ms
# 325:	learn: 0.0034896	total: 941ms	remaining: 214ms
# 326:	learn: 0.0034896	total: 943ms	remaining: 211ms
# 327:	learn: 0.0034896	total: 945ms	remaining: 208ms
# 328:	learn: 0.0034895	total: 948ms	remaining: 205ms
# 329:	learn: 0.0034896	total: 950ms	remaining: 202ms
# 330:	learn: 0.0034896	total: 953ms	remaining: 199ms
# 331:	learn: 0.0034815	total: 955ms	remaining: 196ms
# 332:	learn: 0.0034814	total: 957ms	remaining: 193ms
# 333:	learn: 0.0034801	total: 960ms	remaining: 190ms
# 334:	learn: 0.0034801	total: 962ms	remaining: 187ms
# 335:	learn: 0.0034788	total: 965ms	remaining: 184ms
# 336:	learn: 0.0034776	total: 967ms	remaining: 181ms
# 337:	learn: 0.0034775	total: 969ms	remaining: 178ms
# 338:	learn: 0.0034774	total: 972ms	remaining: 175ms
# 339:	learn: 0.0034771	total: 974ms	remaining: 172ms
# 340:	learn: 0.0034771	total: 977ms	remaining: 169ms
# 341:	learn: 0.0034385	total: 979ms	remaining: 166ms
# 342:	learn: 0.0034383	total: 982ms	remaining: 163ms
# 343:	learn: 0.0034384	total: 984ms	remaining: 160ms
# 344:	learn: 0.0034383	total: 986ms	remaining: 157ms
# 345:	learn: 0.0034383	total: 989ms	remaining: 154ms
# 346:	learn: 0.0034370	total: 991ms	remaining: 151ms
# 347:	learn: 0.0034368	total: 994ms	remaining: 148ms
# 348:	learn: 0.0034367	total: 996ms	remaining: 146ms
# 349:	learn: 0.0034367	total: 998ms	remaining: 143ms
# 350:	learn: 0.0034367	total: 1s	remaining: 140ms
# 351:	learn: 0.0034366	total: 1s	remaining: 137ms
# 352:	learn: 0.0034366	total: 1s	remaining: 134ms
# 353:	learn: 0.0034367	total: 1.01s	remaining: 131ms
# 354:	learn: 0.0034366	total: 1.03s	remaining: 130ms
# 355:	learn: 0.0034366	total: 1.03s	remaining: 127ms
# 356:	learn: 0.0034365	total: 1.03s	remaining: 124ms
# 357:	learn: 0.0034363	total: 1.03s	remaining: 121ms
# 358:	learn: 0.0034358	total: 1.04s	remaining: 118ms
# 359:	learn: 0.0034358	total: 1.04s	remaining: 115ms
# 360:	learn: 0.0034358	total: 1.04s	remaining: 113ms
# 361:	learn: 0.0034358	total: 1.04s	remaining: 110ms
# 362:	learn: 0.0034357	total: 1.05s	remaining: 107ms
# 363:	learn: 0.0034357	total: 1.05s	remaining: 104ms
# 364:	learn: 0.0034351	total: 1.05s	remaining: 101ms
# 365:	learn: 0.0034350	total: 1.05s	remaining: 97.9ms
# 366:	learn: 0.0034349	total: 1.05s	remaining: 94.9ms
# 367:	learn: 0.0034349	total: 1.06s	remaining: 92ms
# 368:	learn: 0.0034349	total: 1.06s	remaining: 89.1ms
# 369:	learn: 0.0034349	total: 1.06s	remaining: 86.2ms
# 370:	learn: 0.0034310	total: 1.06s	remaining: 83.3ms
# 371:	learn: 0.0034310	total: 1.07s	remaining: 80.4ms
# 372:	learn: 0.0034309	total: 1.07s	remaining: 77.5ms
# 373:	learn: 0.0034308	total: 1.07s	remaining: 74.6ms
# 374:	learn: 0.0034306	total: 1.07s	remaining: 71.7ms
# 375:	learn: 0.0034305	total: 1.08s	remaining: 68.8ms
# 376:	learn: 0.0034304	total: 1.08s	remaining: 65.9ms
# 377:	learn: 0.0034296	total: 1.08s	remaining: 63ms
# 378:	learn: 0.0034295	total: 1.08s	remaining: 60.1ms
# 379:	learn: 0.0034284	total: 1.09s	remaining: 57.2ms
# 380:	learn: 0.0034277	total: 1.09s	remaining: 54.3ms
# 381:	learn: 0.0034277	total: 1.09s	remaining: 51.5ms
# 382:	learn: 0.0034277	total: 1.09s	remaining: 48.6ms
# 383:	learn: 0.0034275	total: 1.1s	remaining: 45.7ms
# INFO:root:Best params from GridSearchCV: {'clf__learning_rate': 0.9, 'clf__max_depth': 5, 'clf__n_estimators': 400, 'vectorizer__max_features': 500}
# INFO:root:Best f1 from GridSearchCV: 0.4234074868221209
# 384:	learn: 0.0034275	total: 1.1s	remaining: 42.8ms
# 385:	learn: 0.0034275	total: 1.1s	remaining: 40ms
# 386:	learn: 0.0034274	total: 1.1s	remaining: 37.1ms
# 387:	learn: 0.0034274	total: 1.11s	remaining: 34.2ms
# 388:	learn: 0.0034270	total: 1.11s	remaining: 31.4ms
# 389:	learn: 0.0034260	total: 1.11s	remaining: 28.5ms
# 390:	learn: 0.0034260	total: 1.11s	remaining: 25.6ms
# 391:	learn: 0.0034248	total: 1.12s	remaining: 22.8ms
# 392:	learn: 0.0034247	total: 1.12s	remaining: 19.9ms
# 393:	learn: 0.0034246	total: 1.12s	remaining: 17.1ms
# 394:	learn: 0.0034246	total: 1.12s	remaining: 14.2ms
# 395:	learn: 0.0034245	total: 1.13s	remaining: 11.4ms
# 396:	learn: 0.0034244	total: 1.13s	remaining: 8.53ms
# 397:	learn: 0.0034245	total: 1.13s	remaining: 5.68ms
# 398:	learn: 0.0034244	total: 1.15s	remaining: 2.88ms
# 399:	learn: 0.0034244	total: 1.15s	remaining: 0us
# INFO:root:f1_score for testdata: 0.3736263736263736
# INFO:root:precision_score for testdata: 0.5
# INFO:root:recall_score for testdata: 0.2982456140350877
# INFO:root:Classification report for testdata:
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89       249
#            1       0.50      0.30      0.37        57
#
#     accuracy                           0.81       306
#    macro avg       0.68      0.61      0.63       306
# weighted avg       0.79      0.81      0.79       306
#
# INFO:root:Confusion matrix for testdata:
# [[232  17]
#  [ 40  17]]

# %%
key = 'HOME'
value = os.getenv(key)
  
# Print the value of 'HOME'
# environment variable
print("Value of 'HOME' environment variable :", value) 
  
# Get the value of 'JAVA_HOME'
# environment variable
key = 'MODEL_PATH'
value = os.getenv(key)
  
# Print the value of 'JAVA_HOME'
# environment variable
print("Value of 'JAVA_HOME' environment variable :", value)
# Out:
# Value of 'HOME' environment variable : None
# Value of 'JAVA_HOME' environment variable : None
