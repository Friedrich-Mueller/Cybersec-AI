# %% [markdown]
# ##### A stemmed CountVectorizer

# %%
import copy
from sklearn.feature_extraction.text import CountVectorizer

# Overide CountVectorizer to integrate stemming
class StemmedCountVectorizer(CountVectorizer):
    def __init__(self, stemmer, **kwargs):
        super(StemmedCountVectorizer, self).__init__(**kwargs)
        self.stemmer = stemmer

    def build_analyzer(self):
        analyzer = super(StemmedCountVectorizer, self).build_analyzer()
        return lambda doc: (self.stemmer.stem(w) for w in analyzer(doc))

    def get_params(self, deep=True):
        params = super().get_params(deep=deep)
        cp = copy.copy(self)
        cp.__class__ = CountVectorizer
        params.update(CountVectorizer.get_params(cp, deep))
        return params

# %%
# -*- coding: utf-8 -*-

"""FakeNewsClassifier Trainer

This script conduct the following steps (overview):

1. Load the processes dataset from {PROJECT_DIR}/data/processed as dataframe
2. Concatenate title and text in one column
3. Split the dataset into train and test

4. Set up a sklearn pipeline with preprocessor and classifier for the combined column (title+text)
   and perform hyperparam search 
5. Extract best score and best_params for and log it
6. Predict on testset and log the score

7. Pickle best pipe to disk (final model)

"""
# %%
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()

import os
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import VotingClassifier
from catboost import CatBoostClassifier, Pool
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, f1_score, recall_score, precision_score
from dotenv import find_dotenv, load_dotenv
import nltk
from nltk.stem.snowball import GermanStemmer
from sklearn.feature_extraction.text import CountVectorizer
import dagshub
from joblib import dump


load_dotenv(find_dotenv())
#%% Load and split dataset
# INPUTFILE = os.path.join(os.getenv('PROJECT_DIR'), 'data', 'processed', 'fake_news_processed.csv')
INPUTFILE = os.path.join('data', 'datasets_merged.csv')
df = pd.read_csv(INPUTFILE, sep=';')
logger.info('Distribution of fake news in entire dataset: \n%s' % df.fake.value_counts(normalize=True))

X = df['title']+' '+df['text']
y = df['fake']

X_train, X_test, y_train, y_test = train_test_split(X, y,
                    test_size=0.2,
                    stratify=y,
                    random_state=42)

# Download and init stopwordlist
nltk.download('stopwords')
STOPWORD_LIST = nltk.corpus.stopwords.words('german')

#print(X_train[100])

# %% Test with CountVectorizer
"""
count_vec = StemmedCountVectorizer(token_pattern=r'\b[a-zA-Z]{2,}\b',
                                max_features=100,
                                stop_words=STOPWORD_LIST,
                                lowercase=True,
                                stemmer=GermanStemmer(ignore_stopwords=True),
                                ngram_range=(2,2)
                        )

word_counts = count_vec.fit_transform(X_train).todense()

df_body = pd.DataFrame(word_counts, columns=count_vec.get_feature_names())
df_body_trans = pd.DataFrame(df_body.T.sum(axis=1), columns=['count'])
df_body_trans.sort_values(by='count', ascending=False).head(20)

"""

#%% Define param grid for tuning
param_grid = {'vectorizer__max_features':[500],
        'clf__n_estimators': [400],
        'clf__learning_rate': [0.9],
        'clf__max_depth': [5]}

# Constants for training
MODEL_PATH = os.getenv('MODEL_PATH')
CV_SCORING = 'f1'
CV_FOLDS = 3

# %%
with dagshub.dagshub_logger() as dagslog:
        # Pipeline
        pipe = Pipeline(steps=[
        ('vectorizer', StemmedCountVectorizer(stop_words=STOPWORD_LIST,
                                   token_pattern=r'\b[a-zA-Z]{2,}\b',
                                   stemmer=GermanStemmer(ignore_stopwords=True),
                                   lowercase=True)),
        ('clf', CatBoostClassifier(allow_writing_files=False))
        ])
        
        # pipe_title_tune.get_params().keys()
        logger.info('Start training estimator pipeline')
        cv_grid = GridSearchCV(pipe, param_grid, scoring=CV_SCORING, cv=CV_FOLDS, n_jobs=2)
        cv_grid.fit(X_train, y_train)
        #cv_grid.best_estimator_.named_steps['clf'].get_all_params()

        # Log and assign best score and params to var
        logger.info('Best params from GridSearchCV: %s' % str(cv_grid.best_params_))
        dagslog.log_hyperparams({'model_path': MODEL_PATH})
        dagslog.log_hyperparams({'cv_score': CV_SCORING})
        dagslog.log_hyperparams({'best_cv_params': cv_grid.best_params_})

        logger.info('Best %s from GridSearchCV: %s' % (CV_SCORING, str(cv_grid.best_score_)))
        dagslog.log_metrics({'best_cv_score': cv_grid.best_score_})
        
        # Predict on testdata
        y_pred = cv_grid.best_estimator_.predict(X_test)
        logger.info('f1_score for testdata: %s' % str(f1_score(y_test, y_pred)))
        dagslog.log_metrics({'f1_score_on_testdata': f1_score(y_test, y_pred)})
        logger.info('precision_score for testdata: %s' % str(precision_score(y_test, y_pred)))
        dagslog.log_metrics({'precision_score_on_testdata': precision_score(y_test, y_pred)})
        logger.info('recall_score for testdata: %s' % str(recall_score(y_test, y_pred)))
        dagslog.log_metrics({'recall_score_on_testdata': recall_score(y_test, y_pred)})
        logger.info('Classification report for testdata: \n%s' % classification_report(y_test, y_pred))
        logger.info('Confusion matrix for testdata: \n%s' % confusion_matrix(y_test, y_pred))

        # Dump model to disk
        dump(cv_grid.best_estimator_, MODEL_PATH)
# Out:
# INFO:root:Distribution of fake news in entire dataset:
# 0    0.922928
# 1    0.077072
# Name: fake, dtype: float64
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\fjun\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# INFO:root:Start training estimator pipeline
# 0:	learn: 0.1790363	total: 157ms	remaining: 1m 2s
# 1:	learn: 0.1292465	total: 171ms	remaining: 33.9s
# 2:	learn: 0.1143598	total: 184ms	remaining: 24.3s
# 3:	learn: 0.1028559	total: 196ms	remaining: 19.4s
# 4:	learn: 0.0949349	total: 209ms	remaining: 16.5s
# 5:	learn: 0.0891569	total: 221ms	remaining: 14.5s
# 6:	learn: 0.0860463	total: 233ms	remaining: 13.1s
# 7:	learn: 0.0828056	total: 245ms	remaining: 12s
# 8:	learn: 0.0804890	total: 258ms	remaining: 11.2s
# 9:	learn: 0.0802443	total: 268ms	remaining: 10.5s
# 10:	learn: 0.0773814	total: 281ms	remaining: 9.92s
# 11:	learn: 0.0743589	total: 294ms	remaining: 9.49s
# 12:	learn: 0.0742056	total: 304ms	remaining: 9.04s
# 13:	learn: 0.0712867	total: 317ms	remaining: 8.73s
# 14:	learn: 0.0710549	total: 327ms	remaining: 8.4s
# 15:	learn: 0.0693764	total: 339ms	remaining: 8.14s
# 16:	learn: 0.0692207	total: 350ms	remaining: 7.88s
# 17:	learn: 0.0672085	total: 362ms	remaining: 7.69s
# 18:	learn: 0.0662156	total: 374ms	remaining: 7.5s
# 19:	learn: 0.0660709	total: 385ms	remaining: 7.32s
# 20:	learn: 0.0659696	total: 395ms	remaining: 7.13s
# 21:	learn: 0.0639224	total: 409ms	remaining: 7.03s
# 22:	learn: 0.0638430	total: 420ms	remaining: 6.88s
# 23:	learn: 0.0637816	total: 431ms	remaining: 6.75s
# 24:	learn: 0.0626393	total: 443ms	remaining: 6.64s
# 25:	learn: 0.0625686	total: 453ms	remaining: 6.52s
# 26:	learn: 0.0614781	total: 465ms	remaining: 6.42s
# 27:	learn: 0.0600299	total: 477ms	remaining: 6.33s
# 28:	learn: 0.0590320	total: 488ms	remaining: 6.24s
# 29:	learn: 0.0589758	total: 498ms	remaining: 6.15s
# 30:	learn: 0.0583752	total: 509ms	remaining: 6.06s
# 31:	learn: 0.0571620	total: 523ms	remaining: 6.01s
# 32:	learn: 0.0560785	total: 535ms	remaining: 5.95s
# 33:	learn: 0.0559112	total: 546ms	remaining: 5.88s
# 34:	learn: 0.0551193	total: 559ms	remaining: 5.83s
# 35:	learn: 0.0546761	total: 570ms	remaining: 5.76s
# 36:	learn: 0.0545377	total: 581ms	remaining: 5.7s
# 37:	learn: 0.0544909	total: 591ms	remaining: 5.63s
# 38:	learn: 0.0544598	total: 602ms	remaining: 5.57s
# 39:	learn: 0.0535422	total: 613ms	remaining: 5.52s
# 40:	learn: 0.0527834	total: 625ms	remaining: 5.47s
# 41:	learn: 0.0515576	total: 636ms	remaining: 5.42s
# 42:	learn: 0.0515061	total: 647ms	remaining: 5.37s
# 43:	learn: 0.0508738	total: 660ms	remaining: 5.34s
# 44:	learn: 0.0503188	total: 671ms	remaining: 5.29s
# 45:	learn: 0.0494934	total: 683ms	remaining: 5.25s
# 46:	learn: 0.0489615	total: 695ms	remaining: 5.22s
# 47:	learn: 0.0488993	total: 705ms	remaining: 5.17s
# 48:	learn: 0.0485972	total: 716ms	remaining: 5.13s
# 49:	learn: 0.0485521	total: 727ms	remaining: 5.09s
# 50:	learn: 0.0483383	total: 738ms	remaining: 5.05s
# 51:	learn: 0.0479784	total: 751ms	remaining: 5.02s
# 52:	learn: 0.0477081	total: 761ms	remaining: 4.98s
# 53:	learn: 0.0475242	total: 772ms	remaining: 4.95s
# 54:	learn: 0.0470952	total: 783ms	remaining: 4.91s
# 55:	learn: 0.0470181	total: 794ms	remaining: 4.88s
# 56:	learn: 0.0467146	total: 806ms	remaining: 4.85s
# 57:	learn: 0.0461463	total: 818ms	remaining: 4.82s
# 58:	learn: 0.0461281	total: 829ms	remaining: 4.79s
# 59:	learn: 0.0452694	total: 841ms	remaining: 4.77s
# 60:	learn: 0.0452446	total: 851ms	remaining: 4.73s
# 61:	learn: 0.0450904	total: 862ms	remaining: 4.7s
# 62:	learn: 0.0446594	total: 875ms	remaining: 4.68s
# 63:	learn: 0.0439970	total: 888ms	remaining: 4.66s
# 64:	learn: 0.0436914	total: 900ms	remaining: 4.64s
# 65:	learn: 0.0434403	total: 911ms	remaining: 4.61s
# 66:	learn: 0.0431911	total: 922ms	remaining: 4.58s
# 67:	learn: 0.0430428	total: 933ms	remaining: 4.56s
# 68:	learn: 0.0430199	total: 944ms	remaining: 4.53s
# 69:	learn: 0.0429768	total: 955ms	remaining: 4.5s
# 70:	learn: 0.0426576	total: 966ms	remaining: 4.48s
# 71:	learn: 0.0425996	total: 978ms	remaining: 4.45s
# 72:	learn: 0.0423110	total: 990ms	remaining: 4.43s
# 73:	learn: 0.0422356	total: 1s	remaining: 4.41s
# 74:	learn: 0.0419686	total: 1.01s	remaining: 4.39s
# 75:	learn: 0.0419356	total: 1.02s	remaining: 4.37s
# 76:	learn: 0.0414523	total: 1.04s	remaining: 4.35s
# 77:	learn: 0.0412135	total: 1.05s	remaining: 4.33s
# 78:	learn: 0.0407750	total: 1.06s	remaining: 4.31s
# 79:	learn: 0.0401620	total: 1.07s	remaining: 4.29s
# 80:	learn: 0.0401438	total: 1.08s	remaining: 4.26s
# 81:	learn: 0.0399702	total: 1.09s	remaining: 4.24s
# 82:	learn: 0.0398341	total: 1.1s	remaining: 4.21s
# 83:	learn: 0.0394456	total: 1.11s	remaining: 4.19s
# 84:	learn: 0.0390360	total: 1.13s	remaining: 4.17s
# 85:	learn: 0.0389966	total: 1.14s	remaining: 4.15s
# 86:	learn: 0.0386428	total: 1.15s	remaining: 4.13s
# 87:	learn: 0.0381633	total: 1.16s	remaining: 4.11s
# 88:	learn: 0.0379802	total: 1.17s	remaining: 4.09s
# 89:	learn: 0.0376136	total: 1.18s	remaining: 4.08s
# 90:	learn: 0.0376011	total: 1.19s	remaining: 4.05s
# 91:	learn: 0.0375778	total: 1.2s	remaining: 4.03s
# 92:	learn: 0.0373976	total: 1.22s	remaining: 4.01s
# 93:	learn: 0.0371224	total: 1.23s	remaining: 4s
# 94:	learn: 0.0367741	total: 1.24s	remaining: 3.98s
# 95:	learn: 0.0366308	total: 1.25s	remaining: 3.96s
# 96:	learn: 0.0365786	total: 1.26s	remaining: 3.94s
# 97:	learn: 0.0364324	total: 1.27s	remaining: 3.92s
# 98:	learn: 0.0364209	total: 1.28s	remaining: 3.9s
# 99:	learn: 0.0362854	total: 1.29s	remaining: 3.88s
# 100:	learn: 0.0362708	total: 1.31s	remaining: 3.87s
# 101:	learn: 0.0361725	total: 1.32s	remaining: 3.85s
# 102:	learn: 0.0361308	total: 1.33s	remaining: 3.84s
# 103:	learn: 0.0359149	total: 1.34s	remaining: 3.82s
# 104:	learn: 0.0359012	total: 1.35s	remaining: 3.8s
# 105:	learn: 0.0357370	total: 1.36s	remaining: 3.78s
# 106:	learn: 0.0357317	total: 1.37s	remaining: 3.76s
# 107:	learn: 0.0355321	total: 1.39s	remaining: 3.74s
# 108:	learn: 0.0352850	total: 1.4s	remaining: 3.73s
# 109:	learn: 0.0352782	total: 1.41s	remaining: 3.71s
# 110:	learn: 0.0350878	total: 1.42s	remaining: 3.69s
# 111:	learn: 0.0347886	total: 1.43s	remaining: 3.68s
# 112:	learn: 0.0347542	total: 1.44s	remaining: 3.67s
# 113:	learn: 0.0345032	total: 1.46s	remaining: 3.66s
# 114:	learn: 0.0340421	total: 1.48s	remaining: 3.66s
# 115:	learn: 0.0338691	total: 1.49s	remaining: 3.65s
# 116:	learn: 0.0338317	total: 1.5s	remaining: 3.63s
# 117:	learn: 0.0336950	total: 1.51s	remaining: 3.61s
# 118:	learn: 0.0333984	total: 1.53s	remaining: 3.6s
# 119:	learn: 0.0331927	total: 1.54s	remaining: 3.59s
# 120:	learn: 0.0329086	total: 1.55s	remaining: 3.57s
# 121:	learn: 0.0328242	total: 1.56s	remaining: 3.56s
# 122:	learn: 0.0328164	total: 1.57s	remaining: 3.54s
# 123:	learn: 0.0327335	total: 1.58s	remaining: 3.52s
# 124:	learn: 0.0323071	total: 1.59s	remaining: 3.51s
# 125:	learn: 0.0322973	total: 1.6s	remaining: 3.49s
# 126:	learn: 0.0322735	total: 1.62s	remaining: 3.47s
# 127:	learn: 0.0321300	total: 1.63s	remaining: 3.46s
# 128:	learn: 0.0319521	total: 1.64s	remaining: 3.44s
# 129:	learn: 0.0317704	total: 1.65s	remaining: 3.43s
# 130:	learn: 0.0317097	total: 1.66s	remaining: 3.41s
# 131:	learn: 0.0315856	total: 1.67s	remaining: 3.39s
# 132:	learn: 0.0315038	total: 1.68s	remaining: 3.38s
# 133:	learn: 0.0314959	total: 1.69s	remaining: 3.36s
# 134:	learn: 0.0313369	total: 1.7s	remaining: 3.34s
# 135:	learn: 0.0312697	total: 1.71s	remaining: 3.33s
# 136:	learn: 0.0310000	total: 1.73s	remaining: 3.31s
# 137:	learn: 0.0307441	total: 1.74s	remaining: 3.31s
# 138:	learn: 0.0306392	total: 1.77s	remaining: 3.32s
# 139:	learn: 0.0306236	total: 1.78s	remaining: 3.31s
# 140:	learn: 0.0306061	total: 1.79s	remaining: 3.29s
# 141:	learn: 0.0304465	total: 1.8s	remaining: 3.28s
# 142:	learn: 0.0304237	total: 1.82s	remaining: 3.27s
# 143:	learn: 0.0302563	total: 1.83s	remaining: 3.25s
# 144:	learn: 0.0301629	total: 1.84s	remaining: 3.24s
# 145:	learn: 0.0300521	total: 1.85s	remaining: 3.22s
# 146:	learn: 0.0298627	total: 1.86s	remaining: 3.21s
# 147:	learn: 0.0298578	total: 1.87s	remaining: 3.19s
# 148:	learn: 0.0296698	total: 1.89s	remaining: 3.18s
# 149:	learn: 0.0295836	total: 1.9s	remaining: 3.16s
# 150:	learn: 0.0295785	total: 1.91s	remaining: 3.15s
# 151:	learn: 0.0294876	total: 1.92s	remaining: 3.13s
# 152:	learn: 0.0293046	total: 1.93s	remaining: 3.12s
# 153:	learn: 0.0291511	total: 1.94s	remaining: 3.1s
# 154:	learn: 0.0290020	total: 1.95s	remaining: 3.08s
# 155:	learn: 0.0288868	total: 1.96s	remaining: 3.07s
# 156:	learn: 0.0287830	total: 1.97s	remaining: 3.06s
# 157:	learn: 0.0287229	total: 1.99s	remaining: 3.04s
# 158:	learn: 0.0285333	total: 2s	remaining: 3.03s
# 159:	learn: 0.0284297	total: 2.01s	remaining: 3.01s
# 160:	learn: 0.0284247	total: 2.02s	remaining: 3s
# 161:	learn: 0.0282872	total: 2.03s	remaining: 2.99s
# 162:	learn: 0.0282479	total: 2.04s	remaining: 2.97s
# 163:	learn: 0.0281838	total: 2.06s	remaining: 2.96s
# 164:	learn: 0.0280910	total: 2.07s	remaining: 2.94s
# 165:	learn: 0.0280334	total: 2.08s	remaining: 2.93s
# 166:	learn: 0.0279550	total: 2.09s	remaining: 2.91s
# 167:	learn: 0.0278372	total: 2.1s	remaining: 2.9s
# 168:	learn: 0.0278300	total: 2.11s	remaining: 2.88s
# 169:	learn: 0.0278139	total: 2.12s	remaining: 2.87s
# 170:	learn: 0.0277460	total: 2.13s	remaining: 2.86s
# 171:	learn: 0.0277406	total: 2.14s	remaining: 2.84s
# 172:	learn: 0.0276533	total: 2.15s	remaining: 2.83s
# 173:	learn: 0.0276435	total: 2.17s	remaining: 2.81s
# 174:	learn: 0.0272859	total: 2.18s	remaining: 2.8s
# 175:	learn: 0.0272140	total: 2.19s	remaining: 2.79s
# 176:	learn: 0.0272094	total: 2.2s	remaining: 2.77s
# 177:	learn: 0.0270789	total: 2.21s	remaining: 2.76s
# 178:	learn: 0.0270125	total: 2.22s	remaining: 2.75s
# 179:	learn: 0.0269998	total: 2.23s	remaining: 2.73s
# 180:	learn: 0.0269821	total: 2.25s	remaining: 2.72s
# 181:	learn: 0.0269769	total: 2.25s	remaining: 2.7s
# 182:	learn: 0.0268652	total: 2.27s	remaining: 2.69s
# 183:	learn: 0.0266784	total: 2.28s	remaining: 2.67s
# 184:	learn: 0.0266743	total: 2.29s	remaining: 2.66s
# 185:	learn: 0.0265352	total: 2.3s	remaining: 2.65s
# 186:	learn: 0.0265061	total: 2.31s	remaining: 2.63s
# 187:	learn: 0.0265027	total: 2.32s	remaining: 2.62s
# 188:	learn: 0.0264620	total: 2.33s	remaining: 2.6s
# 189:	learn: 0.0263202	total: 2.34s	remaining: 2.59s
# 190:	learn: 0.0263165	total: 2.35s	remaining: 2.58s
# 191:	learn: 0.0261984	total: 2.37s	remaining: 2.56s
# 192:	learn: 0.0260912	total: 2.38s	remaining: 2.55s
# 193:	learn: 0.0259652	total: 2.39s	remaining: 2.54s
# 194:	learn: 0.0259588	total: 2.4s	remaining: 2.52s
# 195:	learn: 0.0258649	total: 2.41s	remaining: 2.51s
# 196:	learn: 0.0258277	total: 2.42s	remaining: 2.49s
# 197:	learn: 0.0255776	total: 2.43s	remaining: 2.48s
# 198:	learn: 0.0254724	total: 2.44s	remaining: 2.47s
# 199:	learn: 0.0253514	total: 2.46s	remaining: 2.46s
# 200:	learn: 0.0253496	total: 2.46s	remaining: 2.44s
# 201:	learn: 0.0251825	total: 2.48s	remaining: 2.43s
# 202:	learn: 0.0250838	total: 2.49s	remaining: 2.41s
# 203:	learn: 0.0249957	total: 2.5s	remaining: 2.4s
# 204:	learn: 0.0249905	total: 2.51s	remaining: 2.39s
# 205:	learn: 0.0247907	total: 2.52s	remaining: 2.38s
# 206:	learn: 0.0247114	total: 2.53s	remaining: 2.36s
# 207:	learn: 0.0247080	total: 2.54s	remaining: 2.35s
# 208:	learn: 0.0246234	total: 2.56s	remaining: 2.33s
# 209:	learn: 0.0246094	total: 2.56s	remaining: 2.32s
# 210:	learn: 0.0245636	total: 2.58s	remaining: 2.31s
# 211:	learn: 0.0245193	total: 2.59s	remaining: 2.29s
# 212:	learn: 0.0244606	total: 2.6s	remaining: 2.28s
# 213:	learn: 0.0243412	total: 2.61s	remaining: 2.27s
# 214:	learn: 0.0243359	total: 2.62s	remaining: 2.25s
# 215:	learn: 0.0242748	total: 2.63s	remaining: 2.24s
# 216:	learn: 0.0242180	total: 2.64s	remaining: 2.23s
# 217:	learn: 0.0240814	total: 2.65s	remaining: 2.21s
# 218:	learn: 0.0240778	total: 2.66s	remaining: 2.2s
# 219:	learn: 0.0240418	total: 2.67s	remaining: 2.19s
# 220:	learn: 0.0240385	total: 2.69s	remaining: 2.17s
# 221:	learn: 0.0236645	total: 2.7s	remaining: 2.17s
# 222:	learn: 0.0236594	total: 2.71s	remaining: 2.15s
# 223:	learn: 0.0235336	total: 2.72s	remaining: 2.14s
# 224:	learn: 0.0233504	total: 2.73s	remaining: 2.13s
# 225:	learn: 0.0231058	total: 2.75s	remaining: 2.11s
# 226:	learn: 0.0231017	total: 2.76s	remaining: 2.1s
# 227:	learn: 0.0230382	total: 2.77s	remaining: 2.09s
# 228:	learn: 0.0229515	total: 2.78s	remaining: 2.08s
# 229:	learn: 0.0227845	total: 2.79s	remaining: 2.06s
# 230:	learn: 0.0227036	total: 2.8s	remaining: 2.05s
# 231:	learn: 0.0226260	total: 2.81s	remaining: 2.04s
# 232:	learn: 0.0226083	total: 2.83s	remaining: 2.02s
# 233:	learn: 0.0225868	total: 2.84s	remaining: 2.01s
# 234:	learn: 0.0224700	total: 2.85s	remaining: 2s
# 235:	learn: 0.0223838	total: 2.86s	remaining: 1.99s
# 236:	learn: 0.0223814	total: 2.87s	remaining: 1.97s
# 237:	learn: 0.0222736	total: 2.88s	remaining: 1.96s
# 238:	learn: 0.0221894	total: 2.9s	remaining: 1.96s
# 239:	learn: 0.0221591	total: 2.91s	remaining: 1.94s
# 240:	learn: 0.0221564	total: 2.92s	remaining: 1.93s
# 241:	learn: 0.0221530	total: 2.93s	remaining: 1.92s
# 242:	learn: 0.0221141	total: 2.94s	remaining: 1.9s
# 243:	learn: 0.0220461	total: 2.96s	remaining: 1.89s
# 244:	learn: 0.0219749	total: 2.97s	remaining: 1.88s
# 245:	learn: 0.0217764	total: 2.98s	remaining: 1.86s
# 246:	learn: 0.0216763	total: 2.99s	remaining: 1.85s
# 247:	learn: 0.0216527	total: 3s	remaining: 1.84s
# 248:	learn: 0.0215549	total: 3.02s	remaining: 1.83s
# 249:	learn: 0.0215487	total: 3.03s	remaining: 1.82s
# 250:	learn: 0.0214684	total: 3.04s	remaining: 1.8s
# 251:	learn: 0.0213457	total: 3.05s	remaining: 1.79s
# 252:	learn: 0.0213015	total: 3.06s	remaining: 1.78s
# 253:	learn: 0.0212230	total: 3.08s	remaining: 1.77s
# 254:	learn: 0.0211827	total: 3.09s	remaining: 1.75s
# 255:	learn: 0.0211585	total: 3.1s	remaining: 1.74s
# 256:	learn: 0.0211037	total: 3.11s	remaining: 1.73s
# 257:	learn: 0.0210673	total: 3.12s	remaining: 1.72s
# 258:	learn: 0.0210505	total: 3.13s	remaining: 1.7s
# 259:	learn: 0.0209191	total: 3.15s	remaining: 1.7s
# 260:	learn: 0.0209165	total: 3.16s	remaining: 1.69s
# 261:	learn: 0.0207594	total: 3.17s	remaining: 1.67s
# 262:	learn: 0.0206873	total: 3.19s	remaining: 1.66s
# 263:	learn: 0.0206849	total: 3.2s	remaining: 1.65s
# 264:	learn: 0.0206014	total: 3.21s	remaining: 1.63s
# 265:	learn: 0.0205674	total: 3.22s	remaining: 1.62s
# 266:	learn: 0.0205567	total: 3.23s	remaining: 1.61s
# 267:	learn: 0.0205497	total: 3.24s	remaining: 1.59s
# 268:	learn: 0.0204676	total: 3.25s	remaining: 1.58s
# 269:	learn: 0.0204657	total: 3.26s	remaining: 1.57s
# 270:	learn: 0.0204123	total: 3.27s	remaining: 1.56s
# 271:	learn: 0.0203813	total: 3.28s	remaining: 1.54s
# 272:	learn: 0.0203104	total: 3.3s	remaining: 1.53s
# 273:	learn: 0.0202405	total: 3.31s	remaining: 1.52s
# 274:	learn: 0.0201986	total: 3.32s	remaining: 1.51s
# 275:	learn: 0.0201219	total: 3.33s	remaining: 1.5s
# 276:	learn: 0.0200827	total: 3.35s	remaining: 1.49s
# 277:	learn: 0.0200342	total: 3.36s	remaining: 1.47s
# 278:	learn: 0.0200291	total: 3.37s	remaining: 1.46s
# 279:	learn: 0.0199091	total: 3.38s	remaining: 1.45s
# 280:	learn: 0.0198488	total: 3.39s	remaining: 1.44s
# 281:	learn: 0.0198454	total: 3.4s	remaining: 1.42s
# 282:	learn: 0.0198129	total: 3.41s	remaining: 1.41s
# 283:	learn: 0.0198128	total: 3.42s	remaining: 1.4s
# 284:	learn: 0.0198052	total: 3.43s	remaining: 1.39s
# 285:	learn: 0.0196774	total: 3.45s	remaining: 1.37s
# 286:	learn: 0.0196684	total: 3.46s	remaining: 1.36s
# 287:	learn: 0.0196269	total: 3.47s	remaining: 1.35s
# 288:	learn: 0.0196254	total: 3.48s	remaining: 1.34s
# 289:	learn: 0.0196233	total: 3.49s	remaining: 1.32s
# 290:	learn: 0.0194552	total: 3.5s	remaining: 1.31s
# 291:	learn: 0.0194528	total: 3.52s	remaining: 1.3s
# 292:	learn: 0.0194508	total: 3.52s	remaining: 1.29s
# 293:	learn: 0.0193883	total: 3.54s	remaining: 1.27s
# 294:	learn: 0.0193322	total: 3.55s	remaining: 1.26s
# 295:	learn: 0.0192898	total: 3.56s	remaining: 1.25s
# 296:	learn: 0.0192561	total: 3.57s	remaining: 1.24s
# 297:	learn: 0.0191487	total: 3.58s	remaining: 1.23s
# 298:	learn: 0.0190800	total: 3.59s	remaining: 1.21s
# 299:	learn: 0.0190789	total: 3.6s	remaining: 1.2s
# 300:	learn: 0.0189560	total: 3.62s	remaining: 1.19s
# 301:	learn: 0.0189154	total: 3.63s	remaining: 1.18s
# 302:	learn: 0.0189146	total: 3.64s	remaining: 1.16s
# 303:	learn: 0.0188668	total: 3.65s	remaining: 1.15s
# 304:	learn: 0.0188282	total: 3.66s	remaining: 1.14s
# 305:	learn: 0.0187670	total: 3.67s	remaining: 1.13s
# 306:	learn: 0.0187162	total: 3.68s	remaining: 1.11s
# 307:	learn: 0.0187092	total: 3.69s	remaining: 1.1s
# 308:	learn: 0.0186296	total: 3.7s	remaining: 1.09s
# 309:	learn: 0.0185706	total: 3.72s	remaining: 1.08s
# 310:	learn: 0.0185266	total: 3.73s	remaining: 1.07s
# 311:	learn: 0.0184726	total: 3.74s	remaining: 1.05s
# 312:	learn: 0.0183397	total: 3.75s	remaining: 1.04s
# 313:	learn: 0.0183155	total: 3.76s	remaining: 1.03s
# 314:	learn: 0.0183142	total: 3.77s	remaining: 1.02s
# 315:	learn: 0.0182848	total: 3.78s	remaining: 1s
# 316:	learn: 0.0182010	total: 3.79s	remaining: 994ms
# 317:	learn: 0.0180231	total: 3.81s	remaining: 982ms
# 318:	learn: 0.0179835	total: 3.82s	remaining: 970ms
# 319:	learn: 0.0179120	total: 3.83s	remaining: 958ms
# 320:	learn: 0.0178287	total: 3.84s	remaining: 946ms
# 321:	learn: 0.0178105	total: 3.85s	remaining: 933ms
# 322:	learn: 0.0177301	total: 3.87s	remaining: 921ms
# 323:	learn: 0.0176130	total: 3.88s	remaining: 909ms
# 324:	learn: 0.0175563	total: 3.89s	remaining: 897ms
# 325:	learn: 0.0175426	total: 3.9s	remaining: 885ms
# 326:	learn: 0.0174894	total: 3.91s	remaining: 873ms
# 327:	learn: 0.0174890	total: 3.92s	remaining: 860ms
# 328:	learn: 0.0174872	total: 3.93s	remaining: 848ms
# 329:	learn: 0.0174650	total: 3.94s	remaining: 836ms
# 330:	learn: 0.0174229	total: 3.95s	remaining: 824ms
# 331:	learn: 0.0173992	total: 3.96s	remaining: 812ms
# 332:	learn: 0.0173744	total: 3.97s	remaining: 800ms
# 333:	learn: 0.0173729	total: 3.98s	remaining: 788ms
# 334:	learn: 0.0172831	total: 4s	remaining: 776ms
# 335:	learn: 0.0172528	total: 4.01s	remaining: 764ms
# 336:	learn: 0.0170778	total: 4.02s	remaining: 752ms
# 337:	learn: 0.0170558	total: 4.03s	remaining: 740ms
# 338:	learn: 0.0169999	total: 4.04s	remaining: 728ms
# 339:	learn: 0.0169425	total: 4.05s	remaining: 716ms
# 340:	learn: 0.0168844	total: 4.07s	remaining: 704ms
# 341:	learn: 0.0168831	total: 4.08s	remaining: 691ms
# 342:	learn: 0.0168805	total: 4.09s	remaining: 679ms
# 343:	learn: 0.0168684	total: 4.1s	remaining: 667ms
# 344:	learn: 0.0168546	total: 4.11s	remaining: 655ms
# 345:	learn: 0.0167984	total: 4.12s	remaining: 643ms
# 346:	learn: 0.0167353	total: 4.13s	remaining: 631ms
# 347:	learn: 0.0167231	total: 4.14s	remaining: 619ms
# 348:	learn: 0.0166949	total: 4.15s	remaining: 607ms
# 349:	learn: 0.0166856	total: 4.16s	remaining: 595ms
# 350:	learn: 0.0166549	total: 4.17s	remaining: 583ms
# 351:	learn: 0.0166390	total: 4.19s	remaining: 571ms
# 352:	learn: 0.0165855	total: 4.2s	remaining: 559ms
# 353:	learn: 0.0165495	total: 4.21s	remaining: 547ms
# 354:	learn: 0.0165172	total: 4.22s	remaining: 535ms
# 355:	learn: 0.0164860	total: 4.23s	remaining: 523ms
# 356:	learn: 0.0164603	total: 4.24s	remaining: 511ms
# 357:	learn: 0.0164589	total: 4.25s	remaining: 499ms
# 358:	learn: 0.0163962	total: 4.26s	remaining: 487ms
# 359:	learn: 0.0163571	total: 4.28s	remaining: 475ms
# 360:	learn: 0.0163562	total: 4.29s	remaining: 463ms
# 361:	learn: 0.0162444	total: 4.31s	remaining: 452ms
# 362:	learn: 0.0162183	total: 4.32s	remaining: 440ms
# 363:	learn: 0.0161398	total: 4.33s	remaining: 428ms
# 364:	learn: 0.0161084	total: 4.34s	remaining: 416ms
# 365:	learn: 0.0160845	total: 4.35s	remaining: 404ms
# 366:	learn: 0.0160827	total: 4.37s	remaining: 392ms
# 367:	learn: 0.0160531	total: 4.38s	remaining: 381ms
# 368:	learn: 0.0159746	total: 4.39s	remaining: 369ms
# 369:	learn: 0.0158918	total: 4.4s	remaining: 357ms
# 370:	learn: 0.0158818	total: 4.41s	remaining: 345ms
# 371:	learn: 0.0158106	total: 4.42s	remaining: 333ms
# 372:	learn: 0.0157620	total: 4.44s	remaining: 322ms
# 373:	learn: 0.0157331	total: 4.46s	remaining: 310ms
# 374:	learn: 0.0157123	total: 4.47s	remaining: 298ms
# 375:	learn: 0.0156919	total: 4.48s	remaining: 286ms
# 376:	learn: 0.0156468	total: 4.49s	remaining: 274ms
# 377:	learn: 0.0155686	total: 4.5s	remaining: 262ms
# 378:	learn: 0.0155674	total: 4.51s	remaining: 250ms
# 379:	learn: 0.0155363	total: 4.53s	remaining: 238ms
# 380:	learn: 0.0155207	total: 4.54s	remaining: 226ms
# 381:	learn: 0.0155042	total: 4.55s	remaining: 214ms
# 382:	learn: 0.0153785	total: 4.56s	remaining: 203ms
# 383:	learn: 0.0152993	total: 4.58s	remaining: 191ms
# 384:	learn: 0.0152982	total: 4.59s	remaining: 179ms
# 385:	learn: 0.0152515	total: 4.6s	remaining: 167ms
# 386:	learn: 0.0152504	total: 4.61s	remaining: 155ms
# 387:	learn: 0.0151855	total: 4.62s	remaining: 143ms
# 388:	learn: 0.0151545	total: 4.63s	remaining: 131ms
# INFO:root:Best params from GridSearchCV: {'clf__learning_rate': 0.9, 'clf__max_depth': 5, 'clf__n_estimators': 400, 'vectorizer__max_features': 500}
# INFO:root:Best f1 from GridSearchCV: 0.8555504998353983
# 389:	learn: 0.0151265	total: 4.65s	remaining: 119ms
# 390:	learn: 0.0150010	total: 4.66s	remaining: 107ms
# 391:	learn: 0.0149992	total: 4.67s	remaining: 95.3ms
# 392:	learn: 0.0149916	total: 4.68s	remaining: 83.4ms
# 393:	learn: 0.0149502	total: 4.7s	remaining: 71.5ms
# 394:	learn: 0.0149196	total: 4.71s	remaining: 59.6ms
# 395:	learn: 0.0148455	total: 4.72s	remaining: 47.7ms
# 396:	learn: 0.0148343	total: 4.73s	remaining: 35.8ms
# 397:	learn: 0.0147797	total: 4.75s	remaining: 23.8ms
# 398:	learn: 0.0147034	total: 4.76s	remaining: 11.9ms
# 399:	learn: 0.0146892	total: 4.77s	remaining: 0us
# INFO:root:f1_score for testdata: 0.8681434599156118
# INFO:root:precision_score for testdata: 0.8878101402373247
# INFO:root:recall_score for testdata: 0.849329205366357
# INFO:root:Classification report for testdata:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     11599
#            1       0.89      0.85      0.87       969
#
#     accuracy                           0.98     12568
#    macro avg       0.94      0.92      0.93     12568
# weighted avg       0.98      0.98      0.98     12568
#
# INFO:root:Confusion matrix for testdata:
# [[11495   104]
#  [  146   823]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-cfa31ecffa93> in <module>
#     126
#     127         # Dump model to disk
# --> 128         dump(cv_grid.best_estimator_, MODEL_PATH)
#
# ~\anaconda3\envs\cv\lib\site-packages\joblib\numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     443         # People keep inverting arguments, and the resulting error is
#     444         # incomprehensible
# --> 445         raise ValueError(
#     446             'Second argument should be a filename or a file-like object, '
#     447             '%s (type %s) was given.'
#
# ValueError: Second argument should be a filename or a file-like object, None (type <class 'NoneType'>) was given.

# %%
key = 'HOME'
value = os.getenv(key)
  
# Print the value of 'HOME'
# environment variable
print("Value of 'HOME' environment variable :", value) 
  
# Get the value of 'JAVA_HOME'
# environment variable
key = 'MODEL_PATH'
value = os.getenv(key)
  
# Print the value of 'JAVA_HOME'
# environment variable
print("Value of 'JAVA_HOME' environment variable :", value)
# Out:
# Value of 'HOME' environment variable : None
# Value of 'JAVA_HOME' environment variable : None
