# %% [markdown]
# ##### A stemmed CountVectorizer

# %%
import copy
from sklearn.feature_extraction.text import CountVectorizer

# Overide CountVectorizer to integrate stemming
class StemmedCountVectorizer(CountVectorizer):
    def __init__(self, stemmer, **kwargs):
        super(StemmedCountVectorizer, self).__init__(**kwargs)
        self.stemmer = stemmer

    def build_analyzer(self):
        analyzer = super(StemmedCountVectorizer, self).build_analyzer()
        return lambda doc: (self.stemmer.stem(w) for w in analyzer(doc))

    def get_params(self, deep=True):
        params = super().get_params(deep=deep)
        cp = copy.copy(self)
        cp.__class__ = CountVectorizer
        params.update(CountVectorizer.get_params(cp, deep))
        return params

# %%
# -*- coding: utf-8 -*-

"""FakeNewsClassifier Trainer

This script conduct the following steps (overview):

1. Load the processes dataset from {PROJECT_DIR}/data/processed as dataframe
2. Concatenate title and text in one column
3. Split the dataset into train and test

4. Set up a sklearn pipeline with preprocessor and classifier for the combined column (title+text)
   and perform hyperparam search 
5. Extract best score and best_params for and log it
6. Predict on testset and log the score

7. Pickle best pipe to disk (final model)

"""
# %%
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()

import os
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import VotingClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, f1_score, recall_score, precision_score
from dotenv import find_dotenv, load_dotenv
import nltk
from nltk.stem.snowball import GermanStemmer
from sklearn.feature_extraction.text import CountVectorizer
import dagshub
from joblib import dump


load_dotenv(find_dotenv())
#%% Load and split dataset
# INPUTFILE = os.path.join(os.getenv('PROJECT_DIR'), 'data', 'processed', 'fake_news_processed.csv')
INPUTFILE = os.path.join('data', 'datasets_merged.csv')
df = pd.read_csv(INPUTFILE, sep=';')
logger.info('Distribution of fake news in entire dataset: \n%s' % df.fake.value_counts(normalize=True))

X = df['title']+' '+df['text']
y = df['fake']

X_train, X_test, y_train, y_test = train_test_split(X, y,
                    test_size=0.2,
                    stratify=y,
                    random_state=42)

# Download and init stopwordlist
nltk.download('stopwords')
STOPWORD_LIST = nltk.corpus.stopwords.words('german')

#print(X_train[100])

# %% Test with CountVectorizer
"""
count_vec = StemmedCountVectorizer(token_pattern=r'\b[a-zA-Z]{2,}\b',
                                max_features=100,
                                stop_words=STOPWORD_LIST,
                                lowercase=True,
                                stemmer=GermanStemmer(ignore_stopwords=True),
                                ngram_range=(2,2)
                        )

word_counts = count_vec.fit_transform(X_train).todense()

df_body = pd.DataFrame(word_counts, columns=count_vec.get_feature_names())
df_body_trans = pd.DataFrame(df_body.T.sum(axis=1), columns=['count'])
df_body_trans.sort_values(by='count', ascending=False).head(20)

"""

#%% Define param grid for tuning
param_grid = {'vectorizer__max_features':[500],
        'clf__n_estimators': [400],
        'clf__learning_rate': [0.9],
        'clf__max_depth': [5]}

# Constants for training
# MODEL_PATH = os.getenv('MODEL_PATH')
MODEL_PATH = 'model.pkl'
CV_SCORING = 'f1'
CV_FOLDS = 3

# %%
with dagshub.dagshub_logger() as dagslog:
        # Pipeline
        pipe = Pipeline(steps=[
        ('vectorizer', StemmedCountVectorizer(stop_words=STOPWORD_LIST,
                                   token_pattern=r'\b[a-zA-Z]{2,}\b',
                                   stemmer=GermanStemmer(ignore_stopwords=True),
                                   lowercase=True)),
        ('clf', CatBoostClassifier(allow_writing_files=False))
        ])
        
        # pipe_title_tune.get_params().keys()
        logger.info('Start training estimator pipeline')
        cv_grid = GridSearchCV(pipe, param_grid, scoring=CV_SCORING, cv=CV_FOLDS, n_jobs=2)
        cv_grid.fit(X_train, y_train)
        #cv_grid.best_estimator_.named_steps['clf'].get_all_params()

        # Log and assign best score and params to var
        logger.info('Best params from GridSearchCV: %s' % str(cv_grid.best_params_))
        dagslog.log_hyperparams({'model_path': MODEL_PATH})
        dagslog.log_hyperparams({'cv_score': CV_SCORING})
        dagslog.log_hyperparams({'best_cv_params': cv_grid.best_params_})

        logger.info('Best %s from GridSearchCV: %s' % (CV_SCORING, str(cv_grid.best_score_)))
        dagslog.log_metrics({'best_cv_score': cv_grid.best_score_})
        
        # Predict on testdata
        y_pred = cv_grid.best_estimator_.predict(X_test)
        logger.info('f1_score for testdata: %s' % str(f1_score(y_test, y_pred)))
        dagslog.log_metrics({'f1_score_on_testdata': f1_score(y_test, y_pred)})
        logger.info('precision_score for testdata: %s' % str(precision_score(y_test, y_pred)))
        dagslog.log_metrics({'precision_score_on_testdata': precision_score(y_test, y_pred)})
        logger.info('recall_score for testdata: %s' % str(recall_score(y_test, y_pred)))
        dagslog.log_metrics({'recall_score_on_testdata': recall_score(y_test, y_pred)})
        logger.info('Classification report for testdata: \n%s' % classification_report(y_test, y_pred))
        logger.info('Confusion matrix for testdata: \n%s' % confusion_matrix(y_test, y_pred))

        # Dump model to disk
        dump(cv_grid.best_estimator_, MODEL_PATH)
# Out:
# INFO:root:Distribution of fake news in entire dataset:
# 0    0.922928
# 1    0.077072
# Name: fake, dtype: float64
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\fjun\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# INFO:root:Start training estimator pipeline
# 0:	learn: 0.1790348	total: 185ms	remaining: 1m 13s
# 1:	learn: 0.1292450	total: 250ms	remaining: 49.7s
# 2:	learn: 0.1143598	total: 308ms	remaining: 40.8s
# 3:	learn: 0.1028553	total: 359ms	remaining: 35.5s
# 4:	learn: 0.0949345	total: 412ms	remaining: 32.5s
# 5:	learn: 0.0891566	total: 481ms	remaining: 31.6s
# 6:	learn: 0.0860460	total: 547ms	remaining: 30.7s
# 7:	learn: 0.0828053	total: 599ms	remaining: 29.3s
# 8:	learn: 0.0804890	total: 669ms	remaining: 29.1s
# 9:	learn: 0.0802442	total: 719ms	remaining: 28s
# 10:	learn: 0.0773813	total: 776ms	remaining: 27.4s
# 11:	learn: 0.0743588	total: 847ms	remaining: 27.4s
# 12:	learn: 0.0742056	total: 885ms	remaining: 26.3s
# 13:	learn: 0.0712867	total: 952ms	remaining: 26.2s
# 14:	learn: 0.0710548	total: 988ms	remaining: 25.4s
# 15:	learn: 0.0693764	total: 1.04s	remaining: 24.9s
# 16:	learn: 0.0692207	total: 1.08s	remaining: 24.3s
# 17:	learn: 0.0672085	total: 1.13s	remaining: 24.1s
# 18:	learn: 0.0662156	total: 1.18s	remaining: 23.7s
# 19:	learn: 0.0660709	total: 1.22s	remaining: 23.2s
# 20:	learn: 0.0659696	total: 1.26s	remaining: 22.7s
# 21:	learn: 0.0639225	total: 1.36s	remaining: 23.4s
# 22:	learn: 0.0638431	total: 1.4s	remaining: 23s
# 23:	learn: 0.0637817	total: 1.44s	remaining: 22.6s
# 24:	learn: 0.0626394	total: 1.5s	remaining: 22.4s
# 25:	learn: 0.0625686	total: 1.53s	remaining: 22.1s
# 26:	learn: 0.0614782	total: 1.58s	remaining: 21.8s
# 27:	learn: 0.0600301	total: 1.65s	remaining: 21.9s
# 28:	learn: 0.0590322	total: 1.71s	remaining: 21.9s
# 29:	learn: 0.0589760	total: 1.75s	remaining: 21.7s
# 30:	learn: 0.0583753	total: 1.8s	remaining: 21.4s
# 31:	learn: 0.0571622	total: 1.87s	remaining: 21.5s
# 32:	learn: 0.0560787	total: 1.91s	remaining: 21.3s
# 33:	learn: 0.0559114	total: 1.96s	remaining: 21s
# 34:	learn: 0.0551196	total: 2.01s	remaining: 20.9s
# 35:	learn: 0.0546763	total: 2.06s	remaining: 20.8s
# 36:	learn: 0.0545379	total: 2.1s	remaining: 20.6s
# 37:	learn: 0.0544912	total: 2.14s	remaining: 20.4s
# 38:	learn: 0.0544601	total: 2.18s	remaining: 20.2s
# 39:	learn: 0.0535425	total: 2.23s	remaining: 20.1s
# 40:	learn: 0.0527836	total: 2.33s	remaining: 20.4s
# 41:	learn: 0.0515579	total: 2.43s	remaining: 20.7s
# 42:	learn: 0.0515064	total: 2.49s	remaining: 20.7s
# 43:	learn: 0.0508741	total: 2.57s	remaining: 20.8s
# 44:	learn: 0.0503191	total: 2.67s	remaining: 21.1s
# 45:	learn: 0.0494938	total: 2.8s	remaining: 21.5s
# 46:	learn: 0.0489619	total: 2.9s	remaining: 21.8s
# 47:	learn: 0.0488996	total: 2.95s	remaining: 21.6s
# 48:	learn: 0.0485976	total: 3.01s	remaining: 21.6s
# 49:	learn: 0.0485525	total: 3.07s	remaining: 21.5s
# 50:	learn: 0.0483387	total: 3.12s	remaining: 21.3s
# 51:	learn: 0.0479788	total: 3.18s	remaining: 21.3s
# 52:	learn: 0.0477086	total: 3.32s	remaining: 21.7s
# 53:	learn: 0.0475246	total: 3.44s	remaining: 22s
# 54:	learn: 0.0470956	total: 3.56s	remaining: 22.4s
# 55:	learn: 0.0470185	total: 3.7s	remaining: 22.7s
# 56:	learn: 0.0467150	total: 3.82s	remaining: 23s
# 57:	learn: 0.0461467	total: 3.95s	remaining: 23.3s
# 58:	learn: 0.0461285	total: 4.07s	remaining: 23.5s
# 59:	learn: 0.0452698	total: 4.22s	remaining: 23.9s
# 60:	learn: 0.0452451	total: 4.33s	remaining: 24s
# 61:	learn: 0.0450909	total: 4.51s	remaining: 24.6s
# 62:	learn: 0.0446598	total: 4.67s	remaining: 25s
# 63:	learn: 0.0439975	total: 4.92s	remaining: 25.8s
# 64:	learn: 0.0436919	total: 5.04s	remaining: 26s
# 65:	learn: 0.0434408	total: 5.2s	remaining: 26.3s
# 66:	learn: 0.0431916	total: 5.34s	remaining: 26.5s
# 67:	learn: 0.0430434	total: 5.47s	remaining: 26.7s
# 68:	learn: 0.0430204	total: 5.6s	remaining: 26.9s
# 69:	learn: 0.0429773	total: 5.73s	remaining: 27s
# 70:	learn: 0.0426582	total: 5.96s	remaining: 27.6s
# 71:	learn: 0.0426001	total: 6.15s	remaining: 28s
# 72:	learn: 0.0423115	total: 6.44s	remaining: 28.9s
# 73:	learn: 0.0422361	total: 6.58s	remaining: 29s
# 74:	learn: 0.0419691	total: 6.69s	remaining: 29s
# 75:	learn: 0.0419361	total: 6.75s	remaining: 28.8s
# 76:	learn: 0.0414529	total: 6.82s	remaining: 28.6s
# 77:	learn: 0.0412140	total: 6.9s	remaining: 28.5s
# 78:	learn: 0.0407755	total: 6.97s	remaining: 28.3s
# 79:	learn: 0.0401625	total: 7.04s	remaining: 28.2s
# 80:	learn: 0.0401444	total: 7.1s	remaining: 28s
# 81:	learn: 0.0399708	total: 7.19s	remaining: 27.9s
# 82:	learn: 0.0398347	total: 7.25s	remaining: 27.7s
# 83:	learn: 0.0394461	total: 7.31s	remaining: 27.5s
# 84:	learn: 0.0390366	total: 7.38s	remaining: 27.4s
# 85:	learn: 0.0389972	total: 7.44s	remaining: 27.2s
# 86:	learn: 0.0386433	total: 7.5s	remaining: 27s
# 87:	learn: 0.0381638	total: 7.56s	remaining: 26.8s
# 88:	learn: 0.0379808	total: 7.64s	remaining: 26.7s
# 89:	learn: 0.0376142	total: 7.73s	remaining: 26.6s
# 90:	learn: 0.0376017	total: 7.8s	remaining: 26.5s
# 91:	learn: 0.0375784	total: 7.85s	remaining: 26.3s
# 92:	learn: 0.0373982	total: 7.89s	remaining: 26.1s
# 93:	learn: 0.0371229	total: 7.95s	remaining: 25.9s
# 94:	learn: 0.0367747	total: 8.01s	remaining: 25.7s
# 95:	learn: 0.0366314	total: 8.06s	remaining: 25.5s
# 96:	learn: 0.0365792	total: 8.1s	remaining: 25.3s
# 97:	learn: 0.0364330	total: 8.14s	remaining: 25.1s
# 98:	learn: 0.0364214	total: 8.19s	remaining: 24.9s
# 99:	learn: 0.0362859	total: 8.24s	remaining: 24.7s
# 100:	learn: 0.0362713	total: 8.28s	remaining: 24.5s
# 101:	learn: 0.0361730	total: 8.32s	remaining: 24.3s
# 102:	learn: 0.0361313	total: 8.39s	remaining: 24.2s
# 103:	learn: 0.0359155	total: 8.46s	remaining: 24.1s
# 104:	learn: 0.0359017	total: 8.5s	remaining: 23.9s
# 105:	learn: 0.0357376	total: 8.55s	remaining: 23.7s
# 106:	learn: 0.0357323	total: 8.59s	remaining: 23.5s
# 107:	learn: 0.0355326	total: 8.66s	remaining: 23.4s
# 108:	learn: 0.0352856	total: 8.74s	remaining: 23.3s
# 109:	learn: 0.0352787	total: 8.82s	remaining: 23.3s
# 110:	learn: 0.0350883	total: 8.87s	remaining: 23.1s
# 111:	learn: 0.0347891	total: 8.92s	remaining: 22.9s
# 112:	learn: 0.0347548	total: 8.96s	remaining: 22.8s
# 113:	learn: 0.0345038	total: 9.01s	remaining: 22.6s
# 114:	learn: 0.0340427	total: 9.06s	remaining: 22.5s
# 115:	learn: 0.0338696	total: 9.11s	remaining: 22.3s
# 116:	learn: 0.0338322	total: 9.14s	remaining: 22.1s
# 117:	learn: 0.0336956	total: 9.19s	remaining: 22s
# 118:	learn: 0.0333989	total: 9.26s	remaining: 21.9s
# 119:	learn: 0.0331933	total: 9.31s	remaining: 21.7s
# 120:	learn: 0.0329092	total: 9.4s	remaining: 21.7s
# 121:	learn: 0.0328247	total: 9.46s	remaining: 21.6s
# 122:	learn: 0.0328169	total: 9.53s	remaining: 21.5s
# 123:	learn: 0.0327341	total: 9.59s	remaining: 21.4s
# 124:	learn: 0.0323077	total: 9.73s	remaining: 21.4s
# 125:	learn: 0.0322979	total: 9.89s	remaining: 21.5s
# 126:	learn: 0.0322741	total: 10.1s	remaining: 21.6s
# 127:	learn: 0.0321306	total: 10.3s	remaining: 21.9s
# 128:	learn: 0.0319526	total: 10.5s	remaining: 22s
# 129:	learn: 0.0317710	total: 10.8s	remaining: 22.5s
# 130:	learn: 0.0317102	total: 11s	remaining: 22.6s
# 131:	learn: 0.0315862	total: 11.2s	remaining: 22.7s
# 132:	learn: 0.0315043	total: 11.4s	remaining: 22.8s
# 133:	learn: 0.0314964	total: 11.5s	remaining: 22.9s
# 134:	learn: 0.0313375	total: 11.7s	remaining: 23s
# 135:	learn: 0.0312703	total: 11.9s	remaining: 23s
# 136:	learn: 0.0310005	total: 12.1s	remaining: 23.2s
# 137:	learn: 0.0307446	total: 12.3s	remaining: 23.4s
# 138:	learn: 0.0306397	total: 12.5s	remaining: 23.5s
# 139:	learn: 0.0306242	total: 12.7s	remaining: 23.5s
# 140:	learn: 0.0306066	total: 12.8s	remaining: 23.5s
# 141:	learn: 0.0304470	total: 13s	remaining: 23.6s
# 142:	learn: 0.0304242	total: 13.1s	remaining: 23.5s
# 143:	learn: 0.0302568	total: 13.2s	remaining: 23.4s
# 144:	learn: 0.0301634	total: 13.2s	remaining: 23.3s
# 145:	learn: 0.0300526	total: 13.3s	remaining: 23.2s
# 146:	learn: 0.0298632	total: 13.4s	remaining: 23s
# 147:	learn: 0.0298583	total: 13.4s	remaining: 22.9s
# 148:	learn: 0.0296703	total: 13.5s	remaining: 22.7s
# 149:	learn: 0.0295841	total: 13.5s	remaining: 22.6s
# 150:	learn: 0.0295790	total: 13.6s	remaining: 22.4s
# 151:	learn: 0.0294881	total: 13.6s	remaining: 22.2s
# 152:	learn: 0.0293051	total: 13.7s	remaining: 22.1s
# 153:	learn: 0.0291517	total: 13.7s	remaining: 21.9s
# 154:	learn: 0.0290025	total: 13.8s	remaining: 21.8s
# 155:	learn: 0.0288873	total: 13.9s	remaining: 21.7s
# 156:	learn: 0.0287835	total: 13.9s	remaining: 21.6s
# 157:	learn: 0.0287234	total: 14s	remaining: 21.4s
# 158:	learn: 0.0285338	total: 14.1s	remaining: 21.3s
# 159:	learn: 0.0284302	total: 14.2s	remaining: 21.2s
# 160:	learn: 0.0284252	total: 14.3s	remaining: 21.2s
# 161:	learn: 0.0282877	total: 14.3s	remaining: 21.1s
# 162:	learn: 0.0282484	total: 14.4s	remaining: 21s
# 163:	learn: 0.0281843	total: 14.5s	remaining: 20.9s
# 164:	learn: 0.0280915	total: 14.8s	remaining: 21.1s
# 165:	learn: 0.0280339	total: 15s	remaining: 21.1s
# 166:	learn: 0.0279555	total: 15.1s	remaining: 21.1s
# 167:	learn: 0.0278377	total: 15.2s	remaining: 21s
# 168:	learn: 0.0278304	total: 15.4s	remaining: 21.1s
# 169:	learn: 0.0278144	total: 15.5s	remaining: 21s
# 170:	learn: 0.0277465	total: 15.6s	remaining: 21s
# 171:	learn: 0.0277411	total: 15.7s	remaining: 20.9s
# 172:	learn: 0.0276537	total: 15.9s	remaining: 20.9s
# 173:	learn: 0.0276439	total: 16s	remaining: 20.8s
# 174:	learn: 0.0272863	total: 16.2s	remaining: 20.9s
# 175:	learn: 0.0272144	total: 16.5s	remaining: 20.9s
# 176:	learn: 0.0272099	total: 16.8s	remaining: 21.2s
# 177:	learn: 0.0270794	total: 17.3s	remaining: 21.5s
# 178:	learn: 0.0270130	total: 17.7s	remaining: 21.8s
# 179:	learn: 0.0270002	total: 18s	remaining: 21.9s
# 180:	learn: 0.0269826	total: 18.2s	remaining: 22s
# 181:	learn: 0.0269773	total: 18.3s	remaining: 21.9s
# 182:	learn: 0.0268656	total: 18.6s	remaining: 22s
# 183:	learn: 0.0266789	total: 18.8s	remaining: 22.1s
# 184:	learn: 0.0266748	total: 19.1s	remaining: 22.2s
# 185:	learn: 0.0265357	total: 19.3s	remaining: 22.2s
# 186:	learn: 0.0265066	total: 19.5s	remaining: 22.2s
# 187:	learn: 0.0265032	total: 19.6s	remaining: 22.1s
# 188:	learn: 0.0264625	total: 19.6s	remaining: 21.9s
# 189:	learn: 0.0263207	total: 19.7s	remaining: 21.7s
# 190:	learn: 0.0263169	total: 19.8s	remaining: 21.6s
# 191:	learn: 0.0261988	total: 19.9s	remaining: 21.5s
# 192:	learn: 0.0260916	total: 19.9s	remaining: 21.4s
# 193:	learn: 0.0259656	total: 20s	remaining: 21.3s
# 194:	learn: 0.0259592	total: 20.1s	remaining: 21.1s
# 195:	learn: 0.0258653	total: 20.1s	remaining: 20.9s
# 196:	learn: 0.0258282	total: 20.2s	remaining: 20.8s
# 197:	learn: 0.0255780	total: 20.2s	remaining: 20.6s
# 198:	learn: 0.0254728	total: 20.3s	remaining: 20.5s
# 199:	learn: 0.0253519	total: 20.4s	remaining: 20.4s
# 200:	learn: 0.0253500	total: 20.4s	remaining: 20.2s
# 201:	learn: 0.0251829	total: 20.5s	remaining: 20.1s
# 202:	learn: 0.0250842	total: 20.5s	remaining: 19.9s
# 203:	learn: 0.0249961	total: 20.6s	remaining: 19.8s
# 204:	learn: 0.0249910	total: 20.7s	remaining: 19.6s
# 205:	learn: 0.0247911	total: 20.7s	remaining: 19.5s
# 206:	learn: 0.0247119	total: 20.8s	remaining: 19.4s
# 207:	learn: 0.0247084	total: 20.8s	remaining: 19.2s
# 208:	learn: 0.0246238	total: 20.9s	remaining: 19.1s
# 209:	learn: 0.0246098	total: 21s	remaining: 19s
# 210:	learn: 0.0245640	total: 21s	remaining: 18.8s
# 211:	learn: 0.0245197	total: 21.1s	remaining: 18.7s
# 212:	learn: 0.0244610	total: 21.1s	remaining: 18.5s
# 213:	learn: 0.0243416	total: 21.2s	remaining: 18.4s
# 214:	learn: 0.0243363	total: 21.2s	remaining: 18.3s
# 215:	learn: 0.0242752	total: 21.3s	remaining: 18.1s
# 216:	learn: 0.0242184	total: 21.3s	remaining: 18s
# 217:	learn: 0.0240818	total: 21.4s	remaining: 17.8s
# 218:	learn: 0.0240782	total: 21.4s	remaining: 17.7s
# 219:	learn: 0.0240422	total: 21.5s	remaining: 17.6s
# 220:	learn: 0.0240389	total: 21.6s	remaining: 17.5s
# 221:	learn: 0.0236649	total: 21.7s	remaining: 17.4s
# 222:	learn: 0.0236598	total: 21.8s	remaining: 17.3s
# 223:	learn: 0.0235340	total: 21.9s	remaining: 17.2s
# 224:	learn: 0.0233508	total: 22s	remaining: 17.1s
# 225:	learn: 0.0231062	total: 22s	remaining: 16.9s
# 226:	learn: 0.0231020	total: 22.1s	remaining: 16.8s
# 227:	learn: 0.0230386	total: 22.1s	remaining: 16.7s
# 228:	learn: 0.0229518	total: 22.2s	remaining: 16.5s
# 229:	learn: 0.0227849	total: 22.2s	remaining: 16.4s
# 230:	learn: 0.0227040	total: 22.2s	remaining: 16.3s
# 231:	learn: 0.0226263	total: 22.3s	remaining: 16.1s
# 232:	learn: 0.0226087	total: 22.3s	remaining: 16s
# 233:	learn: 0.0225871	total: 22.4s	remaining: 15.9s
# 234:	learn: 0.0224703	total: 22.4s	remaining: 15.8s
# 235:	learn: 0.0223842	total: 22.5s	remaining: 15.6s
# 236:	learn: 0.0223818	total: 22.5s	remaining: 15.5s
# 237:	learn: 0.0222739	total: 22.6s	remaining: 15.4s
# 238:	learn: 0.0221897	total: 22.7s	remaining: 15.3s
# 239:	learn: 0.0221594	total: 22.7s	remaining: 15.2s
# 240:	learn: 0.0221568	total: 22.9s	remaining: 15.1s
# 241:	learn: 0.0221534	total: 23s	remaining: 15s
# 242:	learn: 0.0221145	total: 23.2s	remaining: 15s
# 243:	learn: 0.0220465	total: 23.3s	remaining: 14.9s
# 244:	learn: 0.0219752	total: 23.4s	remaining: 14.8s
# 245:	learn: 0.0217767	total: 23.6s	remaining: 14.8s
# 246:	learn: 0.0216767	total: 23.7s	remaining: 14.7s
# 247:	learn: 0.0216530	total: 23.9s	remaining: 14.7s
# 248:	learn: 0.0215552	total: 24.1s	remaining: 14.6s
# 249:	learn: 0.0215491	total: 24.2s	remaining: 14.5s
# 250:	learn: 0.0214687	total: 24.4s	remaining: 14.5s
# 251:	learn: 0.0213460	total: 24.5s	remaining: 14.4s
# 252:	learn: 0.0213019	total: 24.6s	remaining: 14.3s
# 253:	learn: 0.0212234	total: 24.7s	remaining: 14.2s
# 254:	learn: 0.0211830	total: 24.9s	remaining: 14.1s
# 255:	learn: 0.0211588	total: 25s	remaining: 14s
# 256:	learn: 0.0211040	total: 25.1s	remaining: 14s
# 257:	learn: 0.0210676	total: 25.2s	remaining: 13.9s
# 258:	learn: 0.0210508	total: 25.5s	remaining: 13.9s
# 259:	learn: 0.0209194	total: 25.7s	remaining: 13.8s
# 260:	learn: 0.0209168	total: 25.9s	remaining: 13.8s
# 261:	learn: 0.0207597	total: 26.1s	remaining: 13.7s
# 262:	learn: 0.0206876	total: 26.1s	remaining: 13.6s
# 263:	learn: 0.0206852	total: 26.1s	remaining: 13.5s
# 264:	learn: 0.0206017	total: 26.2s	remaining: 13.3s
# 265:	learn: 0.0205677	total: 26.2s	remaining: 13.2s
# 266:	learn: 0.0205570	total: 26.3s	remaining: 13.1s
# 267:	learn: 0.0205500	total: 26.3s	remaining: 13s
# 268:	learn: 0.0204679	total: 26.4s	remaining: 12.9s
# 269:	learn: 0.0204659	total: 26.5s	remaining: 12.7s
# 270:	learn: 0.0204125	total: 26.5s	remaining: 12.6s
# 271:	learn: 0.0203815	total: 26.6s	remaining: 12.5s
# 272:	learn: 0.0203107	total: 26.6s	remaining: 12.4s
# 273:	learn: 0.0202408	total: 26.7s	remaining: 12.3s
# 274:	learn: 0.0201989	total: 26.7s	remaining: 12.1s
# 275:	learn: 0.0201222	total: 26.8s	remaining: 12s
# 276:	learn: 0.0200830	total: 26.8s	remaining: 11.9s
# 277:	learn: 0.0200345	total: 26.9s	remaining: 11.8s
# 278:	learn: 0.0200294	total: 26.9s	remaining: 11.7s
# 279:	learn: 0.0199094	total: 26.9s	remaining: 11.5s
# 280:	learn: 0.0198491	total: 27s	remaining: 11.4s
# 281:	learn: 0.0198457	total: 27.1s	remaining: 11.3s
# 282:	learn: 0.0198131	total: 27.1s	remaining: 11.2s
# 283:	learn: 0.0198131	total: 27.2s	remaining: 11.1s
# 284:	learn: 0.0198055	total: 27.2s	remaining: 11s
# 285:	learn: 0.0196776	total: 27.2s	remaining: 10.9s
# 286:	learn: 0.0196687	total: 27.3s	remaining: 10.7s
# 287:	learn: 0.0196271	total: 27.3s	remaining: 10.6s
# 288:	learn: 0.0196257	total: 27.4s	remaining: 10.5s
# 289:	learn: 0.0196235	total: 27.4s	remaining: 10.4s
# 290:	learn: 0.0194555	total: 27.4s	remaining: 10.3s
# 291:	learn: 0.0194530	total: 27.5s	remaining: 10.2s
# 292:	learn: 0.0194510	total: 27.5s	remaining: 10s
# 293:	learn: 0.0193886	total: 27.6s	remaining: 9.93s
# 294:	learn: 0.0193324	total: 27.6s	remaining: 9.83s
# 295:	learn: 0.0192901	total: 27.7s	remaining: 9.72s
# 296:	learn: 0.0192564	total: 27.7s	remaining: 9.61s
# 297:	learn: 0.0191490	total: 27.8s	remaining: 9.5s
# 298:	learn: 0.0190802	total: 27.8s	remaining: 9.39s
# 299:	learn: 0.0190791	total: 27.8s	remaining: 9.28s
# 300:	learn: 0.0189562	total: 27.9s	remaining: 9.17s
# 301:	learn: 0.0189157	total: 27.9s	remaining: 9.06s
# 302:	learn: 0.0189148	total: 28s	remaining: 8.95s
# 303:	learn: 0.0188670	total: 28s	remaining: 8.84s
# 304:	learn: 0.0188285	total: 28s	remaining: 8.73s
# 305:	learn: 0.0187673	total: 28.1s	remaining: 8.63s
# 306:	learn: 0.0187164	total: 28.1s	remaining: 8.52s
# 307:	learn: 0.0187095	total: 28.2s	remaining: 8.41s
# 308:	learn: 0.0186298	total: 28.2s	remaining: 8.31s
# 309:	learn: 0.0185708	total: 28.2s	remaining: 8.2s
# 310:	learn: 0.0185268	total: 28.3s	remaining: 8.1s
# 311:	learn: 0.0184728	total: 28.3s	remaining: 7.99s
# 312:	learn: 0.0183399	total: 28.4s	remaining: 7.89s
# 313:	learn: 0.0183158	total: 28.4s	remaining: 7.78s
# 314:	learn: 0.0183144	total: 28.5s	remaining: 7.68s
# 315:	learn: 0.0182851	total: 28.5s	remaining: 7.58s
# 316:	learn: 0.0182012	total: 28.5s	remaining: 7.47s
# 317:	learn: 0.0180233	total: 28.6s	remaining: 7.38s
# 318:	learn: 0.0179838	total: 28.6s	remaining: 7.27s
# 319:	learn: 0.0179123	total: 28.7s	remaining: 7.17s
# 320:	learn: 0.0178290	total: 28.7s	remaining: 7.07s
# 321:	learn: 0.0178107	total: 28.8s	remaining: 6.97s
# 322:	learn: 0.0177303	total: 28.8s	remaining: 6.87s
# 323:	learn: 0.0176133	total: 28.9s	remaining: 6.77s
# 324:	learn: 0.0175565	total: 28.9s	remaining: 6.67s
# 325:	learn: 0.0175428	total: 28.9s	remaining: 6.57s
# 326:	learn: 0.0174896	total: 29s	remaining: 6.47s
# 327:	learn: 0.0174893	total: 29s	remaining: 6.37s
# 328:	learn: 0.0174874	total: 29s	remaining: 6.27s
# 329:	learn: 0.0174652	total: 29.1s	remaining: 6.17s
# 330:	learn: 0.0174231	total: 29.1s	remaining: 6.07s
# 331:	learn: 0.0173994	total: 29.2s	remaining: 5.97s
# 332:	learn: 0.0173747	total: 29.2s	remaining: 5.88s
# 333:	learn: 0.0173731	total: 29.2s	remaining: 5.78s
# 334:	learn: 0.0172833	total: 29.3s	remaining: 5.69s
# 335:	learn: 0.0172530	total: 29.5s	remaining: 5.61s
# 336:	learn: 0.0170780	total: 29.6s	remaining: 5.53s
# 337:	learn: 0.0170560	total: 29.7s	remaining: 5.45s
# 338:	learn: 0.0170001	total: 29.8s	remaining: 5.37s
# 339:	learn: 0.0169427	total: 30s	remaining: 5.29s
# 340:	learn: 0.0168846	total: 30.1s	remaining: 5.21s
# 341:	learn: 0.0168833	total: 30.2s	remaining: 5.12s
# 342:	learn: 0.0168808	total: 30.3s	remaining: 5.04s
# 343:	learn: 0.0168686	total: 30.4s	remaining: 4.95s
# 344:	learn: 0.0168548	total: 30.5s	remaining: 4.86s
# 345:	learn: 0.0167986	total: 30.6s	remaining: 4.78s
# 346:	learn: 0.0167355	total: 30.8s	remaining: 4.7s
# 347:	learn: 0.0167233	total: 30.9s	remaining: 4.62s
# 348:	learn: 0.0166951	total: 31s	remaining: 4.53s
# 349:	learn: 0.0166858	total: 31.1s	remaining: 4.45s
# 350:	learn: 0.0166551	total: 31.2s	remaining: 4.36s
# 351:	learn: 0.0166392	total: 31.3s	remaining: 4.27s
# 352:	learn: 0.0165857	total: 31.5s	remaining: 4.19s
# 353:	learn: 0.0165497	total: 31.6s	remaining: 4.11s
# 354:	learn: 0.0165174	total: 31.8s	remaining: 4.03s
# 355:	learn: 0.0164862	total: 31.9s	remaining: 3.94s
# 356:	learn: 0.0164605	total: 32s	remaining: 3.85s
# 357:	learn: 0.0164591	total: 32.2s	remaining: 3.77s
# 358:	learn: 0.0163964	total: 32.3s	remaining: 3.69s
# 359:	learn: 0.0163573	total: 32.5s	remaining: 3.61s
# 360:	learn: 0.0163564	total: 32.5s	remaining: 3.52s
# 361:	learn: 0.0162446	total: 32.6s	remaining: 3.42s
# 362:	learn: 0.0162185	total: 32.6s	remaining: 3.33s
# 363:	learn: 0.0161400	total: 32.7s	remaining: 3.23s
# 364:	learn: 0.0161086	total: 32.7s	remaining: 3.14s
# 365:	learn: 0.0160848	total: 32.8s	remaining: 3.04s
# 366:	learn: 0.0160829	total: 32.8s	remaining: 2.95s
# 367:	learn: 0.0160533	total: 32.8s	remaining: 2.85s
# 368:	learn: 0.0159748	total: 32.9s	remaining: 2.76s
# 369:	learn: 0.0158920	total: 32.9s	remaining: 2.67s
# 370:	learn: 0.0158820	total: 33s	remaining: 2.58s
# 371:	learn: 0.0158108	total: 33s	remaining: 2.48s
# 372:	learn: 0.0157622	total: 33.1s	remaining: 2.39s
# 373:	learn: 0.0157333	total: 33.1s	remaining: 2.3s
# 374:	learn: 0.0157125	total: 33.2s	remaining: 2.21s
# 375:	learn: 0.0156921	total: 33.3s	remaining: 2.13s
# 376:	learn: 0.0156470	total: 33.4s	remaining: 2.04s
# 377:	learn: 0.0155688	total: 33.4s	remaining: 1.95s
# 378:	learn: 0.0155676	total: 33.5s	remaining: 1.85s
# 379:	learn: 0.0155365	total: 33.5s	remaining: 1.76s
# 380:	learn: 0.0155209	total: 33.6s	remaining: 1.68s
# 381:	learn: 0.0155044	total: 33.6s	remaining: 1.58s
# 382:	learn: 0.0153787	total: 33.7s	remaining: 1.5s
# 383:	learn: 0.0152994	total: 33.8s	remaining: 1.41s
# 384:	learn: 0.0152983	total: 33.8s	remaining: 1.32s
# 385:	learn: 0.0152517	total: 33.9s	remaining: 1.23s
# 386:	learn: 0.0152506	total: 33.9s	remaining: 1.14s
# 387:	learn: 0.0151857	total: 34s	remaining: 1.05s
# 388:	learn: 0.0151547	total: 34s	remaining: 962ms
# 389:	learn: 0.0151267	total: 34.1s	remaining: 874ms
# 390:	learn: 0.0150011	total: 34.1s	remaining: 786ms
# 391:	learn: 0.0149994	total: 34.2s	remaining: 697ms
# 392:	learn: 0.0149918	total: 34.2s	remaining: 610ms
# 393:	learn: 0.0149504	total: 34.3s	remaining: 522ms
# 394:	learn: 0.0149198	total: 34.3s	remaining: 434ms
# 395:	learn: 0.0148457	total: 34.4s	remaining: 347ms
# 396:	learn: 0.0148345	total: 34.4s	remaining: 260ms
# 397:	learn: 0.0147799	total: 34.5s	remaining: 173ms
# INFO:root:Best params from GridSearchCV: {'clf__learning_rate': 0.9, 'clf__max_depth': 5, 'clf__n_estimators': 400, 'vectorizer__max_features': 500}
# INFO:root:Best f1 from GridSearchCV: 0.8555504998353983
# 398:	learn: 0.0147036	total: 34.5s	remaining: 86.5ms
# 399:	learn: 0.0146894	total: 34.6s	remaining: 0us
# INFO:root:f1_score for testdata: 0.8681434599156118
# INFO:root:precision_score for testdata: 0.8878101402373247
# INFO:root:recall_score for testdata: 0.849329205366357
# INFO:root:Classification report for testdata:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     11599
#            1       0.89      0.85      0.87       969
#
#     accuracy                           0.98     12568
#    macro avg       0.94      0.92      0.93     12568
# weighted avg       0.98      0.98      0.98     12568
#
# INFO:root:Confusion matrix for testdata:
# [[11495   104]
#  [  146   823]]

# %%
key = 'HOME'
value = os.getenv(key)
  
# Print the value of 'HOME'
# environment variable
print("Value of 'HOME' environment variable :", value) 
  
# Get the value of 'JAVA_HOME'
# environment variable
key = 'MODEL_PATH'
value = os.getenv(key)
  
# Print the value of 'JAVA_HOME'
# environment variable
print("Value of 'JAVA_HOME' environment variable :", value)
# Out:
# Value of 'HOME' environment variable : None
# Value of 'JAVA_HOME' environment variable : None
