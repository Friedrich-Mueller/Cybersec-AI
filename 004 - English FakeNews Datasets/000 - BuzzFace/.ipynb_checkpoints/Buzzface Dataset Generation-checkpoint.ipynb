# %% [markdown]
# ##### The Dataset is not just directly downloadable. A variety of scripts are provided to download and organize the dataset.
# here: https://github.com/gsantia/BuzzFace

# %% [markdown]
# Nessecary IDs:
#
#
# Facebook App-ID:
#
# 495004908666220
#
# Facebook App-Secret-ID:
#
# 72b126cb77822118f4fd073882c191ac
#
#
# Disqus App-ID:
#
# VofvRAkalgJD7PZ6aXeGgmC0namGHWKoc7wSQULBEspKmvffoIcp5loTIXpDBN5N
#
# Disqus App-Secret-ID:
#
# GnDDAudnA36Lyr4hCpJRKxnM85oTjudWWWbLPZF2R5sIMkIKiIt5FknL3NJHBtu0

# %% [markdown]
# ### scrape.py
# Access the news articles themselves and download the relevant data.
# Also collect the Facebook Plugin and Disqus Plugin comments.

# %%
#!/usr/bin/python
import glob, json, os, re, time
import urllib.request as urllib2
import http.client as httplib
from bs4 import BeautifulSoup
import sys

APP_ID = "495004908666220"
APP_SECRET = "72b126cb77822118f4fd073882c191ac"

DISQUS_ID = "VofvRAkalgJD7PZ6aXeGgmC0namGHWKoc7wSQULBEspKmvffoIcp5loTIXpDBN5N"
DISQUS_SECRET = "GnDDAudnA36Lyr4hCpJRKxnM85oTjudWWWbLPZF2R5sIMkIKiIt5FknL3NJHBtu0"

def scrapeAddicting(webpage):
    """scrapes important info from an Addicting Info _webpage_"""

    articleJSON, page = createPage(webpage)
    soup = BeautifulSoup(page)

    #the body text is all contained in <p> tags
    raw_text = soup.body.find_all('p')
    text = []
    for para in raw_text:
        if para.get_text():
            if not para.find('em'): #not part of the body text
                text.append(para.get_text())
                links = para.find_all('a')
                if links:
                    for link in links:
                        link_url = link['href']
                        link_text = link.get_text()
                        articleJSON['links'].append([link_url, link_text])
                        if 'https://twitter.com' in link_url:
                            if 'status' in link_url:
                                articleJSON['tweets'].append(link_url)
        #now get the pictures
        pics = para.find_all('img')
        if pics:
            for pic in pics:
                pic_url = pic['src']
                pic_text = pic.get('alt', '')
                articleJSON['pictures'].append([pic_url, pic_text])

    articleJSON['body'] = " ".join(text)
    #no Disqus or FB comments
    """
    There is no robots.txt for the Addicting Info site, and no mention
    of rate limiting. In this case, wait 30 seconds between scrapes,
    just to be safe.
    """
    time.sleep(30)
    return articleJSON

def scrapePolitico(webpage):
    """takes the url of a politi.co article and scrapes important info
    using BeautifulSoup"""
    #pictures key will have a list of tuples of image link and its caption
    #links key will be list of tuples of link and its naming
    articleJSON, page = createPage(webpage)
    soup = BeautifulSoup(page, 'html5lib')

    #first find the figures and their captions
    figures = soup.find_all('figure', class_ = 'art')
    if figures:
        for figure in figures:
            captions = figure.find_all('p', class_ = '')
            if captions:
                caption = captions[0].get_text().strip()
            else:
                caption = ""
            images = figure.find_all('img')
            if images:
                if images[0]['src']:
                    image = images[0]['src']
                else:
                    image = ""
            else:
                image = ""
            articleJSON["pictures"].append((image, caption))

    #now find the links and their text
    links = [x
             for x in soup.body.find_all('a')
             if x.parent.name == 'p']
    #the last one is just an ad
    if links:
        for link in links:
            #get rid of the ad at the bottom for some of the articles
            if not link.parent.get('class'):
                link.parent['class'] = ''
            if link.get_text() != 'POLITICO Playbook':
                if link.parent['class'] != 'category':
                    url = link['href'] if link['href'] else ""
                    text = link.get_text().strip()
                    articleJSON['links'].append((url, text))
    paras = [x
             for x in soup.body.find_all('p', class_ = "")
             if x.parent.name != "figcaption"]
    #these are the <p> tags with the body text, minus those for figs
    #and the blurbs at the bottom
    if paras:
        raw_text = [x.get_text().strip() for x in paras]
        #seems like the last <p> is just going to be an ad, delete it
        article = " ".join(raw_text[:-1])
        articleJSON["body"] = article
    #get tweets
    articleJSON['tweets'] = getTweets(soup)
    #just FB comments
    """
    The robots.txt file and Terms of Service for the Politico site
    makes no mention of rate limiting. So let's just go with the 
    standard.
    """
    time.sleep(30)
    return articleJSON

def scrapeRightWing(webpage):
    """scrapes important info from RightWingNews articles"""
    articleJSON, page = createPage(webpage)
    soup = BeautifulSoup(page, 'html5lib')
    raw_text = soup.body.find_all('p')
    #get the body text and the links
    text = []
    for para in raw_text:
        if 'main-article' in para.parent.get('class', []):  #just want content
            if para.get_text():
                text.append(para.get_text().strip())
                #get the links here too
                links = para.find_all('a')
                if links:
                    for link in links:
                        link_url = link['href']
                        link_text = link.get_text()
                        articleJSON['links'].append([link_url, link_text])
    body = " ".join(text)
    articleJSON['body'] = body
    #now scrape the pictures
    centered = soup.body.find_all('center')
    photos = soup.find_all('img', class_ = 'article-photo')
    for photo in photos:
        photo_text = photo.get_text().strip()
        photo_url = photo['src']
        articleJSON['pictures'].append([photo_text, photo_url])
    for center in centered:
        images = center.find_all('img')
        for image in images:
            image_text = image.get_text().strip()
            image_url = image['src']
            articleJSON['pictures'].append([image_url, image_text])
    articleJSON['tweets'] = getTweets(soup)
    #just FB comments
    """
    The robots.txt file for Right Wing News says there must be a
    delay of 30 seconds between scrapes, so that's what we'll do.
    There is no mention of restrictions in the Terms of Service.
    """
    time.sleep(30)
    return articleJSON

def scrapeEagle(webpage):
    """scrapes important info from Eagle Rising articles"""
    articleJSON, page = createPage(webpage)
    soup = BeautifulSoup(page)
    text = []
    raw_text = soup.article.find_all('p')
    for para in raw_text:
        if para.get_text():
            text.append(para.get_text().strip())
            #get the links
            links = para.find_all('a')
            if links:
                for link in links:
                    link_url = link['href']
                    link_text = link.get_text().strip()
                    articleJSON['links'].append([link_url, link_text])
        #get the images
        images = para.find_all('img')
        if images:
            for image in images:
                image_url = image.get('src')
                image_caption = image.get('alt').strip()
                articleJSON['pictures'].append([image_url, image_caption])
    articleJSON['body'] = " ".join(text)
    articleJSON['tweets'] = getTweets(soup)
    #has both FB and Disqus comments!
    articleJSON['DisqComm'] = getDisqComments(webpage, forum = 'eaglerising')
    """
    The robots.txt file for Eagle Rising designates the delay time to be
    10 seconds, so that's what we'll use. The Terms of Service make no mention
    of it.
    """
    time.sleep(10)
    return articleJSON

def scrapeOccupy(webpage):
    """scrapes important info from OccupyDemocrats articles"""
    articleJSON, page = createPage(webpage)
    soup = BeautifulSoup(page, 'lxml')

    #get the main article image
    main_pic = soup.find_all('img', class_ = "attachment- size- wp-post-image")
    if main_pic:
        main_url = main_pic[0]['src']
        main_caption = main_pic[0].get_text().strip()
        articleJSON['pictures'].append([main_url, main_caption])
    other_pics = soup.body.find_all('img')
    other_pics = [x
                  for x in other_pics
                  if x.parent.name == 'p']
    if other_pics:
        for other_pic in other_pics:
            other_cap = other_pic.get_text()
            other_url = other_pic['src']
            articleJSON['pictures'].append([other_url, other_cap])

    articles = soup.body.find_all('article')
    raw_text = [x
                for x in articles[0].find_all('p', class_ = '', lang='', dir='')
                if x.get_text() != ''][1:-1]
    #this removes the author blurbs and blank <p>s
    #get the body links and pics
    text = []
    for para in raw_text:
        text.append(para.get_text().strip())
        #links
        if para.find_all('a'):
            for link in para.find_all('a'):
                url = link['href']
                link_text = link.get_text().strip()
                articleJSON['links'].append([url, link_text])
        #pictures
        if para.find_all('img'):
            for pic in para.find_all('img'):
                pic_url = pic['src']
                pic_caption = pic.get_text().strip()
                articleJSON['pictures'].append([pic_url, pic_caption])

    articleJSON['body'] = " ".join(text)
    articleJSON['tweets'] = getTweets(soup)
    #just FB comments
    """
    The Occupy Democrats robot.txt makes no mention of rate-limiting,
    so we'll just use the default.
    """
    time.sleep(30)
    return articleJSON

def scrapeCNN(webpage):
    """scrapes important info from CNN articles"""
    articleJSON, page = createPage(webpage)
    soup = BeautifulSoup(page, 'lxml')

    raw_text = soup.body.find_all(class_ = 'zn-body__paragraph')
    pictures = []
    metas = soup.find_all('meta')
    for meta in metas:
        if meta:
            if 'content' in meta.attrs.keys():
                try:
                    if (meta['content'][:7] == 'http://'
                            and meta['content'][-4:] == '.jpg'):
                        pictures.append(meta['content'])
                except:
                    print("bad url!")
    #AFAIK cnn doesn't have captions on its vids
    articleJSON['pictures'] = [(pic, '') for pic in set(pictures)]
    #now get the links
    links = []
    text = []
    for para in raw_text:
        if para.get_text():
            text.append(para.get_text().strip())
        if para.find_all('a'):
            for link in para.find_all('a'):
                url = link['href']
                link_text = link.get_text().strip()
                links.append([url, link_text])
    #get the tweets, just the URLS
    articleJSON['tweets'] = getTweets(soup)
    articleJSON['body'] = " ".join(text)
    articleJSON['links'] = links
    #no comments
    """
    The robots.txt for CNN makes no mention of rate-limiting, so 
    let's just use the default value. The Terms of Service make no
    mention of it.
    """
    time.sleep(30)
    return articleJSON

def scrapeFreedom(webpage):
    """scrapes articles on Freedom Daily website"""
    articleJSON, page = createPage(webpage)
    soup = BeautifulSoup(page, 'lxml')
    text = []
    raw_text = soup.body.article.find_all('p')
    if raw_text:
        for para in soup.body.article.find_all('p'):
            #body text
            if para.get_text().strip():
                text.append(para.get_text().strip())
            #links
            if para.find_all('a'):
                for link in para.find_all('a'):
                    url = link['href']
                    link_text = link.get_text().strip()
                    articleJSON['links'].append([url, link_text])
    #get images
    images = soup.body.article.find_all('img')
    if images:
        for image in soup.body.article.find_all('img'):
            image_url = image.get('src', '')
            image_caption = image.get('title', '')
            articleJSON['pictures'].append([image_url, image_caption])

    articleJSON['tweets'] = getTweets(soup)
    articleJSON['body'] = " ".join(text)
    #just FB comments
    """
    The robots.txt for Freedom Daily makes no mention of
    rate-limiting, so let's just use the default.
    """
    time.sleep(30)
    return articleJSON

def scrape98(webpage):
    """scrapes The Other 98% pages"""
    #there are 12 Occupy Democrat articles in here, so we can just use the
    #function we already made. then there are around 75 facebook links,
    #which are just photos or videos. the actual articles are mainly
    #usuncut.com, so should make a scraper for that.

    #first take care of Occupy articles
    if 'http://occupydemocrats.com' in webpage:
        return scrapeOccupy(webpage)
    elif 'http://usuncut.com' in webpage:
        return scrapeUncut(webpage)
    else:   #facebook links, other stuff.
        return {}

def scrapeUncut(webpage):
    """scrapes the US Uncut links found in the 98% articles"""
    # this site is down??
    return {}

def scrapeABC(webpage):
    """scrape ABC News articles"""
    articleJSON, page = createPage(webpage)
    text = []
    if page:
        #check for redirect here
        if page.geturl() != "http://abcnews.go.com":
            soup = BeautifulSoup(page, 'lxml')
            raw_text = soup.body.find_all('p', itemprop = 'articleBody')
            for para in raw_text:
                if para.get_text().strip():
                    text.append(para.get_text().strip())
                #get links
                links = para.find_all('a')
                if links:
                    for link in links:
                        link_url = link.get('href', '')
                        link_text = link.get_text()
                        articleJSON['links'].append([link_url, link_text])
        pics = soup.body.find_all('picture')
        for pic in pics:
            picture = pic.find('img')
            articleJSON['pictures'].append([picture.get('src', '').strip(), picture.get('alt', '').strip()])
        articleJSON['tweets'] = getTweets(soup)
        articleJSON['body'] = " ".join(text)
        #just Disqus comments
        articleJSON['DisqComm'] = getDisqComments(webpage, 'abcnewsdotcom')
    """
    The robots.txt makes no mention of rate-limiting, so we'll use the default.
    Terms of Service makes no mention either.
    """
    time.sleep(30)
    return articleJSON


def getTweets(soup):
    """scrapes the embedded tweets on pages. they seem to be the same format on
    the different websites. takes a soup object in and gives back a list of
    tweet urls"""
    article_tweets = []
    tweets = soup.body.find_all('blockquote', class_ = 'twitter-tweet')
    if tweets:
        for tweet in tweets:
            tweet_urls = tweet.find_all('a')
            temp = [tweet['href'] for tweet in tweet_urls]
            real_urls = filter(lambda x: True if 'status' in x else False,
                                  temp)
            article_tweets.extend(real_urls)

    return article_tweets

def createPage(webpage):
    """given a _webpage_ will set up the right environment and then opens and
    returns the page using urllib2"""
    articleJSON = {
                   "body" : "",
                   "pictures" : [],
                   "links" : [],
                   "tweets" : [],
                   "comments" : [],
                   "DisqComm" : []  #keep the Disqus comments separate
                  }
    page = openPage(webpage)
    return articleJSON, page

def openPage(webpage):
    """given a webpage, opens the page in Python and returns it"""
    #to avoid 403 errors, need to make the request as a browser
    web_response = None
    hdr = {'User-agent' : 'Mozilla/5.0'}
    req = urllib2.Request(webpage, headers=hdr)
    #open the page, try to catch all exceptions
    try:
        web_response = urllib2.urlopen(req)
    except urllib2.HTTPError as e:
        print(e.fp.read())
    except urllib2.URLError as e:
        #print(e.fp.read())
        print("URL ERROR ", wepage)
    except httplib.HTTPException as e:
        #print(e.fp.read())
        print("HTTP EXCEPTION ", webpage)
    except Exception as e:
        print("other exception loading the page: ", webpage)

    return web_response

def createCommentsURL(webpage, APP_ID, APP_SECRET):
    """some of the articles have embedded facebook comments. this will create
    the correct URL to grab these comments in JSON form"""
    #to scrape fb comments on other urls first need to find the ID number
    #assigned to the page by fb
    ID_URL = 'https://graph.facebook.com/?ids='
    url = ID_URL + webpage
    web_response = openPage(url)
    if web_response:
        readable_page = web_response.read()
    else:
        return None
    try:
        data = json.loads(readable_page)
    except:
        print("problem loading comment json")
        return None

    try:
        #the graph API requires an ID number to access comments
        ID_NUM = data[webpage]['og_object']['id']

        comments_args = "/comments?access_token=" + APP_ID + "|" + APP_SECRET + \
                            "&filter=stream"
        comments_url = ("https://graph.facebook.com/v2.10/" +
                            ID_NUM + comments_args)
    except:
        print("problem assigning fb comments URL")
        comments_url = ""
    return comments_url

def getComments(webpage, n = 1):
    """fetches the embedded facebook plugin comments for the article at
    _webpage_. returns the data in a JSON. can't use the collectPosts version
    because that only works for facebook posts."""
    comments_url = createCommentsURL(webpage, APP_ID, APP_SECRET)
    data = []

    if comments_url:
        time.sleep(n)
        web_response = openPage(comments_url)
        if web_response:
            readable_page = web_response.read()
        else:
            return {}
        try:
            thisdata = json.loads(readable_page)
            data.extend(thisdata['data'])
        except:
            print("loading comment didn't work")

        if 'paging' in thisdata.keys():
            while thisdata['paging'].get('next', False):
                try:
                    time.sleep(n)
                    web_response = urllib2.urlopen(thisdata['paging']['next'])
                    if web_response:
                        thisdata = json.loads(web_response.read())
                    if thisdata['data']:
                        data.extend(thisdata['data'])
                except:
                    print("problem getting extra batches")
    return data

def createDisqURL(webpage, DISQUS_ID, DISQUS_SECRET, forum):
    """some of the articles have embedded disqus comments. this will create the
    correct URL to make API requests"""
    try:
        if forum == 'abcnewsdotcom':
            _, page = createPage(webpage)   #take care of redirects
            url = page.geturl()
            page = openPage(url)
            soup = BeautifulSoup(page)
            ID = soup.body.find('article')['data-id']   #get the ID of the article

            split = re.split('/', url[7:])   #need to reformat the link
            webpage = 'http://' + split[0] + '/' + split[1] + '/story?id=' + ID


        args = '&thread=link:' + webpage + '&forum=' + forum
        comments_url = ('https://disqus.com/api/3.0/threads/listPosts.json?api_key=' +
                            DISQUS_ID + '&api_secret=' + DISQUS_SECRET + args)
    except:
        print("problem creating Disqus URL")
        comments_url = ""
    return comments_url

def getDisqComments(webpage, forum, n = 1):
    """makes the requests to get the Disqus comments for a given _webpage_,
    also requires the _forum_ name for the page as per the API"""
    comments_url = createDisqURL(webpage, DISQUS_ID, DISQUS_SECRET, forum)
    data = []
    if comments_url:
        time.sleep(n)
        web_response = openPage(comments_url)
        if web_response:
            readable_page = web_response.read()
        else:
            return {}
        try:
            thisdata = json.loads(readable_page)
            data.extend(thisdata['response'])
        except:
            print("loading comments didn't work")
            return {}

        if 'cursor' in thisdata.keys():
            while thisdata['cursor']['hasNext']:
                """
                I'm not 100% sure what the rate limit is for the Disqus API,
                can't find it in the documentation. To be safe, just use the
                same rate we've been using for the facebook comments.
                """
                time.sleep(n)
                next_cursor = thisdata['cursor']['next']
                extra_comments_url = comments_url + '&cursor=' + next_cursor
                try:
                    web_response = openPage(extra_comments_url)
                except:
                    print("web response")
                    continue
                try:
                    readable_page = web_response.read()
                except:
                    print("readable page")
                    continue
                try:
                    thisdata = json.loads(readable_page)
                    if thisdata.get('response', False):
                        data.extend(thisdata['response'])
                except:
                    print("json load?")
                    continue

    return data

def outlet_scrape(outlet):
    """given an _outlet_ will scrape all articles contained in that folder"""
    outletDict = {
                  "Politico" : scrapePolitico,
                  "CNN_Politics" : scrapeCNN,
                  "Right_Wing_News" : scrapeRightWing,
                  "Occupy_Democrats" : scrapeOccupy,
                  "Eagle_Rising" : scrapeEagle,
                  "Addicting_Info" : scrapeAddicting,
                  "Freedom_Daily" : scrapeFreedom,
                  "The_Other_98%" : scrape98,
                  "ABC_News_Politics" : scrapeABC
                  }
    path = './dataset/' + outlet + '/'

    files = glob.glob(path + '*/posts.json')
    num = len(files)
    for i, filename in enumerate(files):
        print("working on: " + filename)
        print(str(i + 1) + " / " + str(num))
        fileJSON = {}
        with open(filename, 'r') as f:
            postJson = json.load(f)

        if "link" not in postJson.keys():
            print("no link!", filename)
            continue    #if the link is missing, skip
        if "type" not in postJson.keys():
            print("no type! ", filename)
        #for now just skip video and pic posts
        if postJson.get('type') == 'video':
            fileJSON = {
                        "body" : postJson.get('message', ''),
                        "links" : [postJson.get('source', ''), ''],
                        "pictures" : [postJson.get('picture', ''), postJson.get('name', '')]
                       }
        elif postJson.get('type') == 'photo':
            fileJSON = {
                        "body" : '',
                        "links" : [postJson.get('link', ''), postJson.get('story', '')],
                        "pictures" : [postJson.get('picture', ''), postJson.get('name', '')]
                       }
        else:
            #if the post is an article, scrape it
            if 'link' not in postJson.keys():
                print("no link!")
                continue
            webpage = postJson["link"]
            if outlet == "The_Other_98%":
                #The Other 98% seems to have NO first party articles, so handle
                #this case separately
                try:
                    fileJSON = scrape98(webpage)
                except:
                    print("scraping didn't work! ", webpage)
                fileJSON['comments'] = getComments(webpage)

            else:
                #these scrapers are only useful for first party articles
                if postJson["first_party"]:
                    try:
                        fileJSON = outletDict[outlet](webpage)
                    except:
                        print("scraping didn't work! ", webpage)
                    fileJSON['comments'] = getComments(webpage)


        #chop off the posts.json of the filename and add scraped.json
        new_filename = filename[:-10] + 'scraped.json'
        #now dump the scraped JSONs in the same folder
        with open(new_filename, 'w') as f2:
            json.dump(fileJSON, f2, indent = 4, sort_keys = True)

if __name__ == '__main__':
    outlets = ['ABC_News_Politics',
               'Addicting_Info',
               'CNN_Politics',
               'Eagle_Rising',
               'Freedom_Daily',
               'Occupy_Democrats',
               'Politico',
               'Right_Wing_News',
                'The_Other_98%']
    for outlet in outlets:
        if os.path.isdir('./dataset/' + outlet):
            outlet_scrape(outlet)
# Out:
# working on: ./dataset/ABC_News_Politics\1035057923259100\posts.json
# 1 / 200
# no link! ./dataset/ABC_News_Politics\1035057923259100\posts.json
# working on: ./dataset/ABC_News_Politics\1035269309904628\posts.json
# 2 / 200
# no link! ./dataset/ABC_News_Politics\1035269309904628\posts.json
# 194 / 200
# no link! ./dataset/ABC_News_Politics\1042236372541255\posts.json
# working on: ./dataset/ABC_News_Politics\1042250705873155\posts.json
# 195 / 200
# no link! ./dataset/ABC_News_Politics\1042250705873155\posts.json
# working on: ./dataset/ABC_News_Politics\1042266479204911\posts.json
# 196 / 200
# no link! ./dataset/ABC_News_Politics\1042266479204911\posts.json
# working on: ./dataset/ABC_News_Politics\1042295002535392\posts.json
# 197 / 200
# no link! ./dataset/ABC_News_Politics\1042295002535392\posts.json
# working on: ./dataset/ABC_News_Politics\1042315892533303\posts.json
# 198 / 200
# no link! ./dataset/ABC_News_Politics\1042315892533303\posts.json
# working on: ./dataset/ABC_News_Politics\1042353372529555\posts.json
# 199 / 200
# no link! ./dataset/ABC_News_Politics\1042353372529555\posts.json
# working on: ./dataset/ABC_News_Politics\1042362422528650\posts.json
# 200 / 200
# no link! ./dataset/ABC_News_Politics\1042362422528650\posts.json
# working on: ./dataset/Addicting_Info\1446522352054899\posts.json
# 1 / 140
# no link! ./dataset/Addicting_Info\1446522352054899\posts.json
# working on: ./dataset/Addicting_Info\1446620375378430\posts.json
# 2 / 140
# no link! ./dataset/Addicting_Info\1446620375378430\posts.json
# working on: ./dataset/Addicting_Info\1446625628711238\posts.json
# 3 / 140
# no link! ./dataset/Addicting_Info\1446625628711238\posts.json
# working on: ./dataset/Addicting_Info\1446671962039938\posts.json
# 4 / 140
# no link! ./dataset/Addicting_Info\1446671962039938\posts.json
# working on: ./dataset/Addicting_Info\1446692758704525\posts.json
# 5 / 140
# no link! ./dataset/Addicting_Info\1446692758704525\posts.json
# working on: ./dataset/Addicting_Info\1446693125371155\posts.json
# 6 / 140
# no link! ./dataset/Addicting_Info\1446693125371155\posts.json
# working on: ./dataset/Addicting_Info\1446716095368858\posts.json
# 7 / 140
# no link! ./dataset/Addicting_Info\1446716095368858\posts.json
# working on: ./dataset/Addicting_Info\1446717032035431\posts.json
# 8 / 140
# no link! ./dataset/Addicting_Info\1446717032035431\posts.json
# working on: ./dataset/Addicting_Info\1446984445342023\posts.json
# 9 / 140
# no link! ./dataset/Addicting_Info\1446984445342023\posts.json
# working on: ./dataset/Addicting_Info\1447242135316254\posts.json
# 10 / 140
# no link! ./dataset/Addicting_Info\1447242135316254\posts.json
# working on: ./dataset/Addicting_Info\1447249158648885\posts.json
# 11 / 140
# no link! ./dataset/Addicting_Info\1447249158648885\posts.json
# working on: ./dataset/Addicting_Info\1447270141980120\posts.json
# 12 / 140
# no link! ./dataset/Addicting_Info\1447270141980120\posts.json
# working on: ./dataset/Addicting_Info\1447381958635605\posts.json
# 13 / 140
# no link! ./dataset/Addicting_Info\1447381958635605\posts.json
# working on: ./dataset/Addicting_Info\1447394558634345\posts.json
# 14 / 140
# no link! ./dataset/Addicting_Info\1447394558634345\posts.json
# working on: ./dataset/Addicting_Info\1447438628629938\posts.json
# 15 / 140
# no link! ./dataset/Addicting_Info\1447438628629938\posts.json
# working on: ./dataset/Addicting_Info\1447449521962182\posts.json
# 16 / 140
# no link! ./dataset/Addicting_Info\1447449521962182\posts.json
# working on: ./dataset/Addicting_Info\1447486135291854\posts.json
# 17 / 140
# no link! ./dataset/Addicting_Info\1447486135291854\posts.json
# working on: ./dataset/Addicting_Info\1447567931950341\posts.json
# 18 / 140
# no link! ./dataset/Addicting_Info\1447567931950341\posts.json
# working on: ./dataset/Addicting_Info\1447573508616450\posts.json
# 19 / 140
# no link! ./dataset/Addicting_Info\1447573508616450\posts.json
# working on: ./dataset/Addicting_Info\1447680388605762\posts.json
# 20 / 140
# no link! ./dataset/Addicting_Info\1447680388605762\posts.json
# working on: ./dataset/Addicting_Info\1447682791938855\posts.json
# 21 / 140
# no link! ./dataset/Addicting_Info\1447682791938855\posts.json
# working on: ./dataset/Addicting_Info\1447689015271566\posts.json
# 22 / 140
# no link! ./dataset/Addicting_Info\1447689015271566\posts.json
# working on: ./dataset/Addicting_Info\1447692541937880\posts.json
# 23 / 140
# no link! ./dataset/Addicting_Info\1447692541937880\posts.json
# working on: ./dataset/Addicting_Info\1447875271919607\posts.json
# 24 / 140
# no link! ./dataset/Addicting_Info\1447875271919607\posts.json
# working on: ./dataset/Addicting_Info\1447947468579054\posts.json
# 25 / 140
# no link! ./dataset/Addicting_Info\1447947468579054\posts.json
# working on: ./dataset/Addicting_Info\1447950298578771\posts.json
# 26 / 140
# no link! ./dataset/Addicting_Info\1447950298578771\posts.json
# working on: ./dataset/Addicting_Info\1447952351911899\posts.json
# 27 / 140
# no link! ./dataset/Addicting_Info\1447952351911899\posts.json
# working on: ./dataset/Addicting_Info\1447953895245078\posts.json
# 28 / 140
# no link! ./dataset/Addicting_Info\1447953895245078\posts.json
# working on: ./dataset/Addicting_Info\1447962805244187\posts.json
# 29 / 140
# no link! ./dataset/Addicting_Info\1447962805244187\posts.json
# working on: ./dataset/Addicting_Info\1447987088575092\posts.json
# 30 / 140
# no link! ./dataset/Addicting_Info\1447987088575092\posts.json
# working on: ./dataset/Addicting_Info\1447988215241646\posts.json
# 31 / 140
# no link! ./dataset/Addicting_Info\1447988215241646\posts.json
# working on: ./dataset/Addicting_Info\1447990211908113\posts.json
# 32 / 140
# no link! ./dataset/Addicting_Info\1447990211908113\posts.json
# working on: ./dataset/Addicting_Info\1448025148571286\posts.json
# 33 / 140
# no link! ./dataset/Addicting_Info\1448025148571286\posts.json
# working on: ./dataset/Addicting_Info\1448154985224969\posts.json
# 34 / 140
# no link! ./dataset/Addicting_Info\1448154985224969\posts.json
# working on: ./dataset/Addicting_Info\1448516865188781\posts.json
# 35 / 140
# no link! ./dataset/Addicting_Info\1448516865188781\posts.json
# working on: ./dataset/Addicting_Info\1448517158522085\posts.json
# 36 / 140
# no link! ./dataset/Addicting_Info\1448517158522085\posts.json
# working on: ./dataset/Addicting_Info\1448608135179654\posts.json
# 37 / 140
# no link! ./dataset/Addicting_Info\1448608135179654\posts.json
# working on: ./dataset/Addicting_Info\1448695945170873\posts.json
# 38 / 140
# no link! ./dataset/Addicting_Info\1448695945170873\posts.json
# working on: ./dataset/Addicting_Info\1448729105167557\posts.json
# 39 / 140
# no link! ./dataset/Addicting_Info\1448729105167557\posts.json
# working on: ./dataset/Addicting_Info\1448730725167395\posts.json
# 40 / 140
# no link! ./dataset/Addicting_Info\1448730725167395\posts.json
# working on: ./dataset/Addicting_Info\1448881151819019\posts.json
# 41 / 140
# no link! ./dataset/Addicting_Info\1448881151819019\posts.json
# working on: ./dataset/Addicting_Info\1448886951818439\posts.json
# 42 / 140
# no link! ./dataset/Addicting_Info\1448886951818439\posts.json
# working on: ./dataset/Addicting_Info\1448909408482860\posts.json
# 43 / 140
# no link! ./dataset/Addicting_Info\1448909408482860\posts.json
# working on: ./dataset/Addicting_Info\1448968271810307\posts.json
# 44 / 140
# no link! ./dataset/Addicting_Info\1448968271810307\posts.json
# working on: ./dataset/Addicting_Info\1449001875140280\posts.json
# 45 / 140
# no link! ./dataset/Addicting_Info\1449001875140280\posts.json
# working on: ./dataset/Addicting_Info\1449004081806726\posts.json
# 46 / 140
# no link! ./dataset/Addicting_Info\1449004081806726\posts.json
# working on: ./dataset/Addicting_Info\1449388441768290\posts.json
# 47 / 140
# no link! ./dataset/Addicting_Info\1449388441768290\posts.json
# working on: ./dataset/Addicting_Info\1449502221756912\posts.json
# 48 / 140
# no link! ./dataset/Addicting_Info\1449502221756912\posts.json
# working on: ./dataset/Addicting_Info\1449551611751973\posts.json
# 49 / 140
# no link! ./dataset/Addicting_Info\1449551611751973\posts.json
# working on: ./dataset/Addicting_Info\1449600481747086\posts.json
# 50 / 140
# no link! ./dataset/Addicting_Info\1449600481747086\posts.json
# working on: ./dataset/Addicting_Info\1449601135080354\posts.json
# 51 / 140
# no link! ./dataset/Addicting_Info\1449601135080354\posts.json
# working on: ./dataset/Addicting_Info\1449628885077579\posts.json
# 52 / 140
# no link! ./dataset/Addicting_Info\1449628885077579\posts.json
# working on: ./dataset/Addicting_Info\1449772355063232\posts.json
# 53 / 140
# no link! ./dataset/Addicting_Info\1449772355063232\posts.json
# working on: ./dataset/Addicting_Info\1449777868396014\posts.json
# 54 / 140
# no link! ./dataset/Addicting_Info\1449777868396014\posts.json
# working on: ./dataset/Addicting_Info\1449942021712932\posts.json
# 55 / 140
# no link! ./dataset/Addicting_Info\1449942021712932\posts.json
# working on: ./dataset/Addicting_Info\1449944418379359\posts.json
# 56 / 140
# no link! ./dataset/Addicting_Info\1449944418379359\posts.json
# working on: ./dataset/Addicting_Info\1449993025041165\posts.json
# 57 / 140
# no link! ./dataset/Addicting_Info\1449993025041165\posts.json
# working on: ./dataset/Addicting_Info\1449996281707506\posts.json
# 58 / 140
# no link! ./dataset/Addicting_Info\1449996281707506\posts.json
# working on: ./dataset/Addicting_Info\1450020218371779\posts.json
# 59 / 140
# no link! ./dataset/Addicting_Info\1450020218371779\posts.json
# working on: ./dataset/Addicting_Info\1450069728366828\posts.json
# 60 / 140
# no link! ./dataset/Addicting_Info\1450069728366828\posts.json
# working on: ./dataset/Addicting_Info\1450081075032360\posts.json
# 61 / 140
# no link! ./dataset/Addicting_Info\1450081075032360\posts.json
# working on: ./dataset/Addicting_Info\1450101585030309\posts.json
# 62 / 140
# no link! ./dataset/Addicting_Info\1450101585030309\posts.json
# working on: ./dataset/Addicting_Info\1450101775030290\posts.json
# 63 / 140
# no link! ./dataset/Addicting_Info\1450101775030290\posts.json
# working on: ./dataset/Addicting_Info\1450286118345189\posts.json
# 64 / 140
# no link! ./dataset/Addicting_Info\1450286118345189\posts.json
# working on: ./dataset/Addicting_Info\1450487488325052\posts.json
# 65 / 140
# no link! ./dataset/Addicting_Info\1450487488325052\posts.json
# working on: ./dataset/Addicting_Info\1450622854978182\posts.json
# 66 / 140
# no link! ./dataset/Addicting_Info\1450622854978182\posts.json
# working on: ./dataset/Addicting_Info\1450628841644250\posts.json
# 67 / 140
# no link! ./dataset/Addicting_Info\1450628841644250\posts.json
# working on: ./dataset/Addicting_Info\1450664601640674\posts.json
# 68 / 140
# no link! ./dataset/Addicting_Info\1450664601640674\posts.json
# working on: ./dataset/Addicting_Info\1450712398302561\posts.json
# 69 / 140
# no link! ./dataset/Addicting_Info\1450712398302561\posts.json
# working on: ./dataset/Addicting_Info\1450737838300017\posts.json
# 70 / 140
# no link! ./dataset/Addicting_Info\1450737838300017\posts.json
# working on: ./dataset/Addicting_Info\1450805958293205\posts.json
# 71 / 140
# no link! ./dataset/Addicting_Info\1450805958293205\posts.json
# working on: ./dataset/Addicting_Info\1450845401622594\posts.json
# 72 / 140
# no link! ./dataset/Addicting_Info\1450845401622594\posts.json
# working on: ./dataset/Addicting_Info\1450853194955148\posts.json
# 73 / 140
# no link! ./dataset/Addicting_Info\1450853194955148\posts.json
# working on: ./dataset/Addicting_Info\1450910671616067\posts.json
# 74 / 140
# no link! ./dataset/Addicting_Info\1450910671616067\posts.json
# working on: ./dataset/Addicting_Info\1450995121607622\posts.json
# 75 / 140
# no link! ./dataset/Addicting_Info\1450995121607622\posts.json
# working on: ./dataset/Addicting_Info\1451123788261422\posts.json
# 76 / 140
# no link! ./dataset/Addicting_Info\1451123788261422\posts.json
# working on: ./dataset/Addicting_Info\1451126608261140\posts.json
# 77 / 140
# no link! ./dataset/Addicting_Info\1451126608261140\posts.json
# working on: ./dataset/Addicting_Info\1451127358261065\posts.json
# 78 / 140
# no link! ./dataset/Addicting_Info\1451127358261065\posts.json
# working on: ./dataset/Addicting_Info\1451200324920435\posts.json
# 79 / 140
# no link! ./dataset/Addicting_Info\1451200324920435\posts.json
# working on: ./dataset/Addicting_Info\1451202248253576\posts.json
# 80 / 140
# no link! ./dataset/Addicting_Info\1451202248253576\posts.json
# working on: ./dataset/Addicting_Info\1451258538247947\posts.json
# 81 / 140
# no link! ./dataset/Addicting_Info\1451258538247947\posts.json
# working on: ./dataset/Addicting_Info\1451262898247511\posts.json
# 82 / 140
# no link! ./dataset/Addicting_Info\1451262898247511\posts.json
# working on: ./dataset/Addicting_Info\1451262981580836\posts.json
# 83 / 140
# no link! ./dataset/Addicting_Info\1451262981580836\posts.json
# working on: ./dataset/Addicting_Info\1451263971580737\posts.json
# 84 / 140
# no link! ./dataset/Addicting_Info\1451263971580737\posts.json
# working on: ./dataset/Addicting_Info\1451304671576667\posts.json
# 85 / 140
# no link! ./dataset/Addicting_Info\1451304671576667\posts.json
# working on: ./dataset/Addicting_Info\1451600428213758\posts.json
# 86 / 140
# no link! ./dataset/Addicting_Info\1451600428213758\posts.json
# working on: ./dataset/Addicting_Info\1451738378199963\posts.json
# 87 / 140
# no link! ./dataset/Addicting_Info\1451738378199963\posts.json
# working on: ./dataset/Addicting_Info\1451779101529224\posts.json
# 88 / 140
# no link! ./dataset/Addicting_Info\1451779101529224\posts.json
# working on: ./dataset/Addicting_Info\1451804061526728\posts.json
# 89 / 140
# no link! ./dataset/Addicting_Info\1451804061526728\posts.json
# working on: ./dataset/Addicting_Info\1451890218184779\posts.json
# 90 / 140
# no link! ./dataset/Addicting_Info\1451890218184779\posts.json
# working on: ./dataset/Addicting_Info\1451956254844842\posts.json
# 91 / 140
# no link! ./dataset/Addicting_Info\1451956254844842\posts.json
# working on: ./dataset/Addicting_Info\1451961101511024\posts.json
# 92 / 140
# no link! ./dataset/Addicting_Info\1451961101511024\posts.json
# working on: ./dataset/Addicting_Info\1451988724841595\posts.json
# 93 / 140
# no link! ./dataset/Addicting_Info\1451988724841595\posts.json
# working on: ./dataset/Addicting_Info\1452012371505897\posts.json
# 94 / 140
# no link! ./dataset/Addicting_Info\1452012371505897\posts.json
# working on: ./dataset/Addicting_Info\1452117881495346\posts.json
# 95 / 140
# no link! ./dataset/Addicting_Info\1452117881495346\posts.json
# working on: ./dataset/Addicting_Info\1452127004827767\posts.json
# 96 / 140
# no link! ./dataset/Addicting_Info\1452127004827767\posts.json
# working on: ./dataset/Addicting_Info\1452159774824490\posts.json
# 97 / 140
# no link! ./dataset/Addicting_Info\1452159774824490\posts.json
# working on: ./dataset/Addicting_Info\1452308554809612\posts.json
# 98 / 140
# no link! ./dataset/Addicting_Info\1452308554809612\posts.json
# working on: ./dataset/Addicting_Info\1452319888141812\posts.json
# 99 / 140
# no link! ./dataset/Addicting_Info\1452319888141812\posts.json
# working on: ./dataset/Addicting_Info\1452406928133108\posts.json
# 100 / 140
# no link! ./dataset/Addicting_Info\1452406928133108\posts.json
# working on: ./dataset/Addicting_Info\1454798624560605\posts.json
# 101 / 140
# no link! ./dataset/Addicting_Info\1454798624560605\posts.json
# working on: ./dataset/Addicting_Info\1454806031226531\posts.json
# 102 / 140
# no link! ./dataset/Addicting_Info\1454806031226531\posts.json
# working on: ./dataset/Addicting_Info\1454868161220318\posts.json
# 103 / 140
# no link! ./dataset/Addicting_Info\1454868161220318\posts.json
# working on: ./dataset/Addicting_Info\1454906627883138\posts.json
# 104 / 140
# no link! ./dataset/Addicting_Info\1454906627883138\posts.json
# working on: ./dataset/Addicting_Info\1454907001216434\posts.json
# 105 / 140
# no link! ./dataset/Addicting_Info\1454907001216434\posts.json
# working on: ./dataset/Addicting_Info\1455250911182043\posts.json
# 106 / 140
# no link! ./dataset/Addicting_Info\1455250911182043\posts.json
# working on: ./dataset/Addicting_Info\1455551614485306\posts.json
# 107 / 140
# no link! ./dataset/Addicting_Info\1455551614485306\posts.json
# working on: ./dataset/Addicting_Info\1455558234484644\posts.json
# 108 / 140
# no link! ./dataset/Addicting_Info\1455558234484644\posts.json
# working on: ./dataset/Addicting_Info\1455568094483658\posts.json
# 109 / 140
# no link! ./dataset/Addicting_Info\1455568094483658\posts.json
# working on: ./dataset/Addicting_Info\1455575034482964\posts.json
# 110 / 140
# no link! ./dataset/Addicting_Info\1455575034482964\posts.json
# working on: ./dataset/Addicting_Info\1455674111139723\posts.json
# 111 / 140
# no link! ./dataset/Addicting_Info\1455674111139723\posts.json
# working on: ./dataset/Addicting_Info\1455844117789389\posts.json
# 112 / 140
# no link! ./dataset/Addicting_Info\1455844117789389\posts.json
# working on: ./dataset/Addicting_Info\1455922947781506\posts.json
# 113 / 140
# no link! ./dataset/Addicting_Info\1455922947781506\posts.json
# working on: ./dataset/Addicting_Info\1456040647769736\posts.json
# 114 / 140
# no link! ./dataset/Addicting_Info\1456040647769736\posts.json
# working on: ./dataset/Addicting_Info\1456117054428762\posts.json
# 115 / 140
# no link! ./dataset/Addicting_Info\1456117054428762\posts.json
# working on: ./dataset/Addicting_Info\1456140261093108\posts.json
# 116 / 140
# no link! ./dataset/Addicting_Info\1456140261093108\posts.json
# working on: ./dataset/Addicting_Info\1456154251091709\posts.json
# 117 / 140
# no link! ./dataset/Addicting_Info\1456154251091709\posts.json
# working on: ./dataset/Addicting_Info\1456154411091693\posts.json
# 118 / 140
# no link! ./dataset/Addicting_Info\1456154411091693\posts.json
# working on: ./dataset/Addicting_Info\1456173967756404\posts.json
# 119 / 140
# no link! ./dataset/Addicting_Info\1456173967756404\posts.json
# working on: ./dataset/Addicting_Info\1456211731085961\posts.json
# 120 / 140
# no link! ./dataset/Addicting_Info\1456211731085961\posts.json
# working on: ./dataset/Addicting_Info\1456214201085714\posts.json
# 121 / 140
# no link! ./dataset/Addicting_Info\1456214201085714\posts.json
# working on: ./dataset/Addicting_Info\1456218721085262\posts.json
# 122 / 140
# no link! ./dataset/Addicting_Info\1456218721085262\posts.json
# working on: ./dataset/Addicting_Info\1456237357750065\posts.json
# 123 / 140
# no link! ./dataset/Addicting_Info\1456237357750065\posts.json
# working on: ./dataset/Addicting_Info\1456244677749333\posts.json
# 124 / 140
# no link! ./dataset/Addicting_Info\1456244677749333\posts.json
# working on: ./dataset/Addicting_Info\1456259001081234\posts.json
# 125 / 140
# no link! ./dataset/Addicting_Info\1456259001081234\posts.json
# working on: ./dataset/Addicting_Info\1456274954412972\posts.json
# 126 / 140
# no link! ./dataset/Addicting_Info\1456274954412972\posts.json
# working on: ./dataset/Addicting_Info\1456275241079610\posts.json
# 127 / 140
# no link! ./dataset/Addicting_Info\1456275241079610\posts.json
# working on: ./dataset/Addicting_Info\1456673304373137\posts.json
# 128 / 140
# no link! ./dataset/Addicting_Info\1456673304373137\posts.json
# working on: ./dataset/Addicting_Info\1456727697701031\posts.json
# 129 / 140
# no link! ./dataset/Addicting_Info\1456727697701031\posts.json
# working on: ./dataset/Addicting_Info\1456768787696922\posts.json
# 130 / 140
# no link! ./dataset/Addicting_Info\1456768787696922\posts.json
# working on: ./dataset/Addicting_Info\1456866627687138\posts.json
# 131 / 140
# no link! ./dataset/Addicting_Info\1456866627687138\posts.json
# working on: ./dataset/Addicting_Info\1456879957685805\posts.json
# 132 / 140
# no link! ./dataset/Addicting_Info\1456879957685805\posts.json
# working on: ./dataset/Addicting_Info\1456923867681414\posts.json
# 133 / 140
# no link! ./dataset/Addicting_Info\1456923867681414\posts.json
# working on: ./dataset/Addicting_Info\1456984601008674\posts.json
# 134 / 140
# no link! ./dataset/Addicting_Info\1456984601008674\posts.json
# working on: ./dataset/Addicting_Info\1457086207665180\posts.json
# 135 / 140
# no link! ./dataset/Addicting_Info\1457086207665180\posts.json
# working on: ./dataset/Addicting_Info\1457100920997042\posts.json
# 136 / 140
# no link! ./dataset/Addicting_Info\1457100920997042\posts.json
# working on: ./dataset/Addicting_Info\1457164467657354\posts.json
# 137 / 140
# no link! ./dataset/Addicting_Info\1457164467657354\posts.json
# working on: ./dataset/Addicting_Info\1457178897655911\posts.json
# 138 / 140
# no link! ./dataset/Addicting_Info\1457178897655911\posts.json
# working on: ./dataset/Addicting_Info\1457297090977425\posts.json
# 139 / 140
# no link! ./dataset/Addicting_Info\1457297090977425\posts.json
# working on: ./dataset/Addicting_Info\1457326974307770\posts.json
# 140 / 140
# no link! ./dataset/Addicting_Info\1457326974307770\posts.json
# working on: ./dataset/CNN_Politics\1281392611902569\posts.json
# 1 / 409
# no link! ./dataset/CNN_Politics\1281392611902569\posts.json
# working on: ./dataset/CNN_Politics\1281494028559094\posts.json
# 2 / 409
# no link! ./dataset/CNN_Politics\1281494028559094\posts.json
# working on: ./dataset/CNN_Politics\1281555051886325\posts.json
# 3 / 409
# no link! ./dataset/CNN_Politics\1281555051886325\posts.json
# ...
# 188 / 286
# no link! ./dataset/Eagle_Rising\553002894903223\posts.json
# working on: ./dataset/Eagle_Rising\553002968236549\posts.json
# 189 / 286
# no link! ./dataset/Eagle_Rising\553002968236549\posts.json
# working on: ./dataset/Eagle_Rising\553010974902415\posts.json
# 190 / 286
# no link! ./dataset/Eagle_Rising\553010974902415\posts.json
# working on: ./dataset/Eagle_Rising\553010994902413\posts.json
# 191 / 286
# no link! ./dataset/Eagle_Rising\553010994902413\posts.json
# working on: ./dataset/Eagle_Rising\553011548235691\posts.json
# 192 / 286
# no link! ./dataset/Eagle_Rising\553011548235691\posts.json
# working on: ./dataset/Eagle_Rising\553011611569018\posts.json
# 193 / 286
# no link! ./dataset/Eagle_Rising\553011611569018\posts.json
# working on: ./dataset/Eagle_Rising\553011714902341\posts.json
# 194 / 286
# no link! ./dataset/Eagle_Rising\553011714902341\posts.json
# working on: ./dataset/Eagle_Rising\553011734902339\posts.json
# 195 / 286
# no link! ./dataset/Eagle_Rising\553011734902339\posts.json
# no link! ./dataset/Eagle_Rising\553592784844234\posts.json
# working on: ./dataset/Eagle_Rising\553592831510896\posts.json
# 219 / 286
# no link! ./dataset/Eagle_Rising\553592831510896\posts.json
# working on: ./dataset/Eagle_Rising\553592881510891\posts.json
# 220 / 286
# no link! ./dataset/Eagle_Rising\553592881510891\posts.json
# working on: ./dataset/Eagle_Rising\553592928177553\posts.json
# 221 / 286
# no link! ./dataset/Eagle_Rising\553592928177553\posts.json
# working on: ./dataset/Eagle_Rising\553592988177547\posts.json
# 222 / 286
# no link! ./dataset/Eagle_Rising\553592988177547\posts.json
# working on: ./dataset/Eagle_Rising\553734261496753\posts.json
# 223 / 286
# no link! ./dataset/Eagle_Rising\553734261496753\posts.json
# working on: ./dataset/Eagle_Rising\554123321457847\posts.json
# 224 / 286
# no link! ./dataset/Eagle_Rising\554123321457847\posts.json
# working on: ./dataset/Eagle_Rising\554123384791174\posts.json
# 225 / 286
# no link! ./dataset/Eagle_Rising\554123384791174\posts.json
# working on: ./dataset/Eagle_Rising\554123541457825\posts.json
# 226 / 286
# no link! ./dataset/Eagle_Rising\554123541457825\posts.json
# working on: ./dataset/Eagle_Rising\554123694791143\posts.json
# 227 / 286
# no link! ./dataset/Eagle_Rising\554123694791143\posts.json
# working on: ./dataset/Eagle_Rising\554123748124471\posts.json
# 228 / 286
# no link! ./dataset/Eagle_Rising\554123748124471\posts.json
# working on: ./dataset/Eagle_Rising\554123798124466\posts.json
# 229 / 286
# no link! ./dataset/Eagle_Rising\554123798124466\posts.json
# working on: ./dataset/Eagle_Rising\554123948124451\posts.json
# 230 / 286
# no link! ./dataset/Eagle_Rising\554123948124451\posts.json
# working on: ./dataset/Eagle_Rising\554124058124440\posts.json
# 231 / 286
# no link! ./dataset/Eagle_Rising\554124058124440\posts.json
# working on: ./dataset/Eagle_Rising\554125088124337\posts.json
# 232 / 286
# no link! ./dataset/Eagle_Rising\554125088124337\posts.json
# working on: ./dataset/Eagle_Rising\554126961457483\posts.json
# 233 / 286
# no link! ./dataset/Eagle_Rising\554126961457483\posts.json
# working on: ./dataset/Eagle_Rising\554127194790793\posts.json
# 234 / 286
# no link! ./dataset/Eagle_Rising\554127194790793\posts.json
# working on: ./dataset/Eagle_Rising\554127358124110\posts.json
# 235 / 286
# no link! ./dataset/Eagle_Rising\554127358124110\posts.json
# working on: ./dataset/Eagle_Rising\554127454790767\posts.json
# 236 / 286
# no link! ./dataset/Eagle_Rising\554127454790767\posts.json
# working on: ./dataset/Eagle_Rising\554127778124068\posts.json
# 237 / 286
# no link! ./dataset/Eagle_Rising\554127778124068\posts.json
# working on: ./dataset/Eagle_Rising\554241688112677\posts.json
# 238 / 286
# no link! ./dataset/Eagle_Rising\554241688112677\posts.json
# working on: ./dataset/Eagle_Rising\554261528110693\posts.json
# 239 / 286
# no link! ./dataset/Eagle_Rising\554261528110693\posts.json
# working on: ./dataset/Eagle_Rising\554277404775772\posts.json
# 240 / 286
# no link! ./dataset/Eagle_Rising\554277404775772\posts.json
# working on: ./dataset/Eagle_Rising\554307944772718\posts.json
# 241 / 286
# no link! ./dataset/Eagle_Rising\554307944772718\posts.json
# working on: ./dataset/Eagle_Rising\554325304770982\posts.json
# 242 / 286
# no link! ./dataset/Eagle_Rising\554325304770982\posts.json
# working on: ./dataset/Eagle_Rising\554342468102599\posts.json
# 243 / 286
# no link! ./dataset/Eagle_Rising\554342468102599\posts.json
# working on: ./dataset/Eagle_Rising\554360488100797\posts.json
# 244 / 286
# no link! ./dataset/Eagle_Rising\554360488100797\posts.json
# working on: ./dataset/Eagle_Rising\554371828099663\posts.json
# 245 / 286
# no link! ./dataset/Eagle_Rising\554371828099663\posts.json
# working on: ./dataset/Eagle_Rising\554402708096575\posts.json
# 246 / 286
# no link! ./dataset/Eagle_Rising\554402708096575\posts.json
# working on: ./dataset/Eagle_Rising\554416098095236\posts.json
# 247 / 286
# no link! ./dataset/Eagle_Rising\554416098095236\posts.json
# working on: ./dataset/Eagle_Rising\554477861422393\posts.json
# 248 / 286
# no link! ./dataset/Eagle_Rising\554477861422393\posts.json
# working on: ./dataset/Eagle_Rising\554490431421136\posts.json
# 249 / 286
# no link! ./dataset/Eagle_Rising\554490431421136\posts.json
# working on: ./dataset/Eagle_Rising\554502851419894\posts.json
# 250 / 286
# no link! ./dataset/Eagle_Rising\554502851419894\posts.json
# working on: ./dataset/Eagle_Rising\554502974753215\posts.json
# 251 / 286
# no link! ./dataset/Eagle_Rising\554502974753215\posts.json
# working on: ./dataset/Eagle_Rising\554503008086545\posts.json
# 252 / 286
# no link! ./dataset/Eagle_Rising\554503008086545\posts.json
# working on: ./dataset/Eagle_Rising\554503064753206\posts.json
# 253 / 286
# no link! ./dataset/Eagle_Rising\554503064753206\posts.json
# working on: ./dataset/Eagle_Rising\554504311419748\posts.json
# 254 / 286
# no link! ./dataset/Eagle_Rising\554504311419748\posts.json
# working on: ./dataset/Eagle_Rising\554504451419734\posts.json
# 255 / 286
# no link! ./dataset/Eagle_Rising\554504451419734\posts.json
# working on: ./dataset/Eagle_Rising\554504534753059\posts.json
# 256 / 286
# no link! ./dataset/Eagle_Rising\554504534753059\posts.json
# working on: ./dataset/Eagle_Rising\554504641419715\posts.json
# 257 / 286
# no link! ./dataset/Eagle_Rising\554504641419715\posts.json
# working on: ./dataset/Eagle_Rising\554504701419709\posts.json
# 258 / 286
# no link! ./dataset/Eagle_Rising\554504701419709\posts.json
# working on: ./dataset/Eagle_Rising\554504831419696\posts.json
# 259 / 286
# no link! ./dataset/Eagle_Rising\554504831419696\posts.json
# working on: ./dataset/Eagle_Rising\554505034753009\posts.json
# 260 / 286
# no link! ./dataset/Eagle_Rising\554505034753009\posts.json
# working on: ./dataset/Eagle_Rising\554505101419669\posts.json
# 261 / 286
# no link! ./dataset/Eagle_Rising\554505101419669\posts.json
# working on: ./dataset/Eagle_Rising\554505178086328\posts.json
# 262 / 286
# no link! ./dataset/Eagle_Rising\554505178086328\posts.json
# working on: ./dataset/Eagle_Rising\554505344752978\posts.json
# 263 / 286
# no link! ./dataset/Eagle_Rising\554505344752978\posts.json
# working on: ./dataset/Eagle_Rising\554509488085897\posts.json
# 264 / 286
# no link! ./dataset/Eagle_Rising\554509488085897\posts.json
# working on: ./dataset/Eagle_Rising\554509564752556\posts.json
# 265 / 286
# no link! ./dataset/Eagle_Rising\554509564752556\posts.json
# working on: ./dataset/Eagle_Rising\554510084752504\posts.json
# 266 / 286
# no link! ./dataset/Eagle_Rising\554510084752504\posts.json
# working on: ./dataset/Eagle_Rising\554510241419155\posts.json
# 267 / 286
# no link! ./dataset/Eagle_Rising\554510241419155\posts.json
# working on: ./dataset/Eagle_Rising\554510431419136\posts.json
# 268 / 286
# no link! ./dataset/Eagle_Rising\554510431419136\posts.json
# working on: ./dataset/Eagle_Rising\554510524752460\posts.json
# 269 / 286
# no link! ./dataset/Eagle_Rising\554510524752460\posts.json
# working on: ./dataset/Eagle_Rising\554510678085778\posts.json
# 270 / 286
# no link! ./dataset/Eagle_Rising\554510678085778\posts.json
# working on: ./dataset/Eagle_Rising\554510764752436\posts.json
# 271 / 286
# no link! ./dataset/Eagle_Rising\554510764752436\posts.json
# working on: ./dataset/Eagle_Rising\554510794752433\posts.json
# 272 / 286
# no link! ./dataset/Eagle_Rising\554510794752433\posts.json
# working on: ./dataset/Eagle_Rising\554510844752428\posts.json
# 273 / 286
# no link! ./dataset/Eagle_Rising\554510844752428\posts.json
# working on: ./dataset/Eagle_Rising\554510938085752\posts.json
# 274 / 286
# no link! ./dataset/Eagle_Rising\554510938085752\posts.json
# working on: ./dataset/Eagle_Rising\554597891410390\posts.json
# 275 / 286
# no link! ./dataset/Eagle_Rising\554597891410390\posts.json
# working on: ./dataset/Eagle_Rising\554612978075548\posts.json
# 276 / 286
# no link! ./dataset/Eagle_Rising\554612978075548\posts.json
# working on: ./dataset/Eagle_Rising\554629948073851\posts.json
# 277 / 286
# no link! ./dataset/Eagle_Rising\554629948073851\posts.json
# working on: ./dataset/Eagle_Rising\554657358071110\posts.json
# 278 / 286
# no link! ./dataset/Eagle_Rising\554657358071110\posts.json
# working on: ./dataset/Eagle_Rising\554677078069138\posts.json
# 279 / 286
# no link! ./dataset/Eagle_Rising\554677078069138\posts.json
# working on: ./dataset/Eagle_Rising\554690588067787\posts.json
# 280 / 286
# no link! ./dataset/Eagle_Rising\554690588067787\posts.json
# working on: ./dataset/Eagle_Rising\554703414733171\posts.json
# 281 / 286
# no link! ./dataset/Eagle_Rising\554703414733171\posts.json
# working on: ./dataset/Eagle_Rising\554716558065190\posts.json
# 282 / 286
# no link! ./dataset/Eagle_Rising\554716558065190\posts.json
# working on: ./dataset/Eagle_Rising\554737894729723\posts.json
# 283 / 286
# no link! ./dataset/Eagle_Rising\554737894729723\posts.json
# working on: ./dataset/Eagle_Rising\554769691393210\posts.json
# 284 / 286
# no link! ./dataset/Eagle_Rising\554769691393210\posts.json
# working on: ./dataset/Eagle_Rising\554779854725527\posts.json
# 285 / 286
# no link! ./dataset/Eagle_Rising\554779854725527\posts.json
# working on: ./dataset/Freedom_Daily\1246596238735824\posts.json
# 22 / 23
# no link! ./dataset/Freedom_Daily\1246596238735824\posts.json
# working on: ./dataset/Freedom_Daily\1246873882041393\posts.json
# 23 / 23
# no link! ./dataset/Freedom_Daily\1246873882041393\posts.json

# %% [markdown]
# ### collectPosts.py
# A Python script which goes through all the Facebook posts in the BuzzFeed set and obtains their metadata, comments, and attachments. Dumps this data into posts.json, comments.json, and attach.json files, respectively.

# %%
#!/usr/bin/python

import urllib.request as urllib2
import json
import os, re, csv
import time
import sys

def createFeedUrl(username, APP_ID, APP_SECRET, limit):
    post_args = "/feed?access_token=" + APP_ID + "|" + APP_SECRET + \
                "&fields=attachments,created_time,message&limit=" + str(limit)
    post_url = "https://graph.facebook.com/v3.0/" + username + post_args
    return post_url

def createPostUrl(USER_ID,POST_ID, APP_ID, APP_SECRET):
    post_args = "?access_token=" + APP_ID + "|" + APP_SECRET + \
                    "&fields=link,message,created_time,name,story,caption,description,picture,place,shares,source,updated_time"
    post_url = "https://graph.facebook.com/v3.0/" + USER_ID + "_" + POST_ID + post_args
    return post_url

def createPostCommentsUrl(USER_ID, POST_ID, APP_ID, APP_SECRET):
    comments_args = "/comments?access_token=" + APP_ID + "|" + APP_SECRET + \
                    "&order=chronological&limit=1000"
    comments_url = ("https://graph.facebook.com/v3.0/" + USER_ID + "_" +
                        POST_ID + comments_args)
    return comments_url

def createPostAttachmentsUrl(USER_ID,POST_ID, APP_ID, APP_SECRET):
    attachments_args = "/attachments?access_token=" + APP_ID + "|" + APP_SECRET
    attachments_url = ("https://graph.facebook.com/v3.0/" + USER_ID + "_" +
                        POST_ID + attachments_args)
    return attachments_url

def createPostReactionsUrl(USER_ID,POST_ID, APP_ID, APP_SECRET):
    reactions_args = "/reactions?access_token=" + APP_ID + "|" + APP_SECRET + \
                    "&limit=1000"  
    reactions_url = ("https://graph.facebook.com/v3.0/" + USER_ID + "_" + POST_ID +
                        reactions_args)
    return reactions_url

def new_createPostReactionsUrl(USER_ID, POST_ID, APP_ID, APP_SECRET):
    reactions_args = "/reactions?access_token=" + APP_ID + "|" + APP_SECRET + \
            "&summary=total_count"
    reactions_url = "https://graph.facebook.com/v3.0/" + USER_ID + "_" + POST_ID + \
            reactions_args
    return reactions_url

def getUserFeed(username, limit):
    post_url = createPostUrl(username, APP_ID, APP_SECRET, limit)
    web_response = urllib2.urlopen(post_url)
    readable_page = web_response.read()
    return json.loads(readable_page)

def getPost(USER_ID, POST_ID):
    ## have this build urls for the comments, reactions, and attachments
    post_url = createPostUrl(USER_ID, POST_ID, APP_ID, APP_SECRET)
    print("generated post url:", post_url)
    web_response = urllib2.urlopen(post_url)
    readable_page = web_response.read()
    return json.loads(readable_page)

def getPostReactions(USER_ID, POST_ID):
    """returns a JSON of a post's reactions"""
    ###############################################
    # This code is deprecated! Facebook changed the
    # API on Feb 5, 2018, so now none of this works.
    ###############################################
    """
    data = []
    post_url = createPostReactionsUrl(USER_ID, POST_ID, APP_ID, APP_SECRET)
    opener = urllib2.build_opener()
    opener.addheaders = [('User-agent', 'Mozilla/5.0')]
    urllib2.install_opener(opener)
    batchnum = 1
    time.sleep(1)

    try:
        web_response = urllib2.urlopen(post_url)
        readable_page = web_response.read()
        thisdata = json.loads(readable_page)
        data.extend(thisdata['data'])
    except:
        print("reacts didn't work at all!")
        #just return an empty dict here
        return {}

    if 'paging' in thisdata.keys():
        while thisdata['paging'].get('next', False):
            time.sleep(1)
            batchnum += 1
            print("reacts batch: ", batchnum)
            try:
                web_response = urllib2.urlopen(thisdata['paging']['next'])
                thisdata = json.loads(web_response.read())
                if thisdata['data']:
                    data.extend(thisdata['data'])
            except:
                print("problem getting extra batches")
    reacts = {'data' : data}
    return reacts
    """
    post_url = new_createPostReactionsUrl(USER_ID, POST_ID, APP_ID, APP_SECRET)
    opener = urllib2.build_opener()
    opener.addheaders = [('User-agent', 'Mozilla/5.0')]
    urllib2.install_opener(opener)
#     print("post_url", post_url)
    try:
        web_response = urllib2.urlopen(post_url)
        readable_page = web_response.read()
        thisdata = json.loads(readable_page)
    except:
        print("reacts didn't work at all!")
        return None

    return thisdata['summary']['total_count']

def getPostComments(USER_ID, POST_ID, n = 1):
    """returns a JSON of a post's comments"""
    data = []
    post_url = createPostCommentsUrl(USER_ID, POST_ID, APP_ID, APP_SECRET)
    opener = urllib2.build_opener()
    opener.addheaders = [('User-agent', 'Mozilla/5.0')]
    urllib2.install_opener(opener)
    batchnum = 1
    time.sleep(n)

    try:
        web_response = urllib2.urlopen(post_url)
        readable_page = web_response.read()
        thisdata = json.loads(readable_page)
        data.extend(thisdata['data'])
    except:
        print("comments didn't work at all!")
        #in this case, just return an empty dict
        return {}

    if 'paging' in thisdata.keys():
        while thisdata['paging'].get('next', False):
            time.sleep(n)
            batchnum += 1
            print("comments batch: ", batchnum)
            try:
                web_response = urllib2.urlopen(thisdata['paging']['next'])
                thisdata = json.loads(web_response.read())
                if thisdata['data']:
                    data.extend(thisdata['data'])
            except:
                print("problem getting extra batches")
    comments = {"data" : data}
    return comments

def getPostAttachments(USER_ID, POST_ID, n = 1):
    """returns a JSON of a post's attachments"""
    post_url = createPostAttachmentsUrl(USER_ID, POST_ID, APP_ID, APP_SECRET)
    time.sleep(n)
    web_response = urllib2.urlopen(post_url)
    readable_page = web_response.read()
    return json.loads(readable_page)



APP_ID = "495004908666220"
APP_SECRET = "72b126cb77822118f4fd073882c191ac"

buzzfeed = []
# If you like, you can change how long the program waits after
# each API call here by setting n = (number of seconds). To be
# safe and follow Facebook's conditions, we set n = 1 by default.
# Change at your own risk.
#
# NOTE: This has been changed from 1 to 20 due to ANOTHER change in
# the Facebook Graph API.
n = 20

#make a dict to relate outlet names to their url repn's
outlet_urls = {"ABC_News_Politics" : 'abc',
           "Addicting_Info" : 'addictinginfo',
           "CNN_Politics" : "cnn",
           "Eagle_Rising" : "eaglerising",
           "Freedom_Daily" : "freedomdaily",
           "Occupy_Democrats" : "occupydemocrats",
           "Politico" : "politi.co",
           "Right_Wing_News" : "rightwingnews",
           "The_Other_98%" : "TheOther98" }

#first load the buzzfeed data
buzzfeed_file = 'facebook-fact-check.csv'
with open(buzzfeed_file, 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        buzzfeed.append(row)

del buzzfeed[0]
#now go thru each article
for article in buzzfeed:
    if article:
        print("Article: ", article)
        USER_ID = article[0]
        POST_ID = article[1]
        url = article[4]
        outlet = article[3].replace(" ", "_")
        article_type = article[6]

        print("working on " + POST_ID)
        #get post
#         time.sleep(n)
#         postJson = getPost(USER_ID, POST_ID)
#         print("postJson: ", postJson)
        try:
            time.sleep(n)
            postJson = getPost(USER_ID, POST_ID)
            print("postJson: ", postJson)
            postJson['type'] = article_type
            first_party = True if outlet_urls[outlet] in postJson.get('link') else False
            postJson['first_party'] = first_party
        except:
            print("post error")
            postJson = {}
        #get number of reactions
#         postJson['reacts'] = getPostReactions(USER_ID, POST_ID)
        #get comments and reacts
#         time.sleep(n)
#         commentJson = getPostComments(USER_ID, POST_ID, n)

#         #get attachments
#         try:
#             attachJson = getPostAttachments(USER_ID, POST_ID, n)
#         except:
#             print("attach")
#             attachJson = {}

        wd = 'dataset/'
        if not os.path.isdir('./dataset/'):
            os.mkdir('dataset')
        postfile = wd + outlet + '/' + POST_ID + '/posts.json'
        commentfile = wd + outlet + '/' + POST_ID + '/comments.json'
        attachfile = wd + outlet + '/' + POST_ID + '/attach.json'
#             print(wd + outlet + '/' + POST_ID + '/posts.json')
        os.makedirs(wd + outlet + '/' + POST_ID)
#             os.makedirs(commentfile)
#             os.makedirs(attachfile)
#             os.system('touch ' + postfile)
#             os.system('touch ' + commentfile)
#             os.system('touch ' + attachfile)

        with open(postfile, 'w') as f:
            json.dump(postJson, f, indent = 4, sort_keys = True)

#         with open(commentfile, 'w') as f2:
#             json.dump(commentJson, f2, indent = 4, sort_keys = True)

#         with open(attachfile, 'w') as f4:
#             json.dump(attachJson, f4, indent = 4, sort_keys = True)
# Out:
# Article:  ['184096565021911', '1035057923259100', 'mainstream', 'ABC News Politics', 'https://www.facebook.com/ABCNewsPolitics/posts/1035057923259100', '2016-09-19', 'video', 'no factual content', '', '', '146', '15']
# working on 1035057923259100
# generated post url: https://graph.facebook.com/v3.0/184096565021911_1035057923259100?access_token=495004908666220|72b126cb77822118f4fd073882c191ac&fields=link,message,created_time,name,story,caption,description,picture,place,shares,source,updated_time
# post error
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-2-1ce30f3c3bff> in <module>
#     237         attachfile = wd + outlet + '/' + POST_ID + '/attach.json'
#     238 #             print(wd + outlet + '/' + POST_ID + '/posts.json')
# --> 239         os.makedirs(wd + outlet + '/' + POST_ID)
#     240 #             os.makedirs(commentfile)
#     241 #             os.makedirs(attachfile)
#
# ~\anaconda3\envs\cai\lib\os.py in makedirs(name, mode, exist_ok)
#     221             return
#     222     try:
# --> 223         mkdir(name, mode)
#     224     except OSError:
#     225         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'dataset/ABC_News_Politics/1035057923259100'

# %% [markdown]
# ## Results
#
# As it turns out, dealing with the facebook API has advanced within those 4 years. Additionally, many of the posts which are being scraped, have been removed already, which seems to affect a larger part of the already underrepresented posts of the "mostly fake" type.
#
# Conclusion: The "BuzzFeed-Webis Fake News Corpus 2016" should be prefered over the BuzzFace dataset.
